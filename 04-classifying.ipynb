# %% [markdown]
# # Predict match winners: Poisson

# %% [markdown]
# https://www.kdnuggets.com/2023/01/python-machine-learning-predict-football-match-winners.html

# %%
import pickle
from operator import itemgetter

import numpy as np
import pandas as pd
from scipy.stats import poisson

# %%
training_set = pd.read_parquet("datasets/processed/training_set_processed.parquet")
training_set
# Out:
#           Sea   Lge       Date                        HT                  AT  \
# 7102    00-01  CHN1 2000-03-19           Dalian Haichang       Beijing Guoan
# 7103    00-01  CHN1 2000-03-19                   Qingdao  Shanghai Greenland
# 7108    00-01  CHN1 2000-03-19             Xiamen Xiaxin            Liaoning
# 7106    00-01  CHN1 2000-03-19               Shenzhen FC   Sichuan Guancheng
# 7105    00-01  CHN1 2000-03-19  Guangzhou Rich and Force     Chongqing Lifan
# ...       ...   ...        ...                       ...                 ...
# 299041  22-23  TUN1 2023-02-08            EO Sidi Bouzid         ES Metlaoui
# 299040  22-23  TUN1 2023-02-08                  ES Sahel         CA Bizertin
# 299039  22-23  TUN1 2023-02-08           US Ben Guerdane             Soliman
# 299037  22-23  TUN1 2023-02-08            Stade Tunisien        US Tataouine
# 299044  22-23  TUN1 2023-02-08      Club Sportif Sfaxien              Chebba
#
#         HS  AS  GD WDL  Goals
# 7102     2   0   2   W      2
# 7103     1   1   0   D      2
# 7108     3   0   3   W      3
# 7106     0   0   0   D      0
# 7105     0   0   0   D      0
# ...     ..  ..  ..  ..    ...
# 299041   3   4  -1   L      7
# 299040   0   2  -2   L      2
# 299039   2   2   0   D      4
# 299037   2   1   1   W      3
# 299044   2   0   2   W      2
#
# [299207 rows x 10 columns]

# %%
with open("teams.pickle", "rb") as f:
    teams = pickle.load(f)
#teams_stats_dict

# %%
def predict_game(home_team: str, away_team: str):
    ''' Predicts game outcome in terms of exact scores (HS/AS) and 
    also WDL probabilities, given two teams in training set (team stats 
    should be available to compute game prediction).
    '''

    # Calculate the value of lambda (λ) for both Home Team and Away Team.
    ht_stats_dict = [t for t in teams if t["name"] == home_team][0]
    at_stats_dict = [t for t in teams if t["name"] == away_team][0]
    
    avg_ht_scored = ht_stats_dict["avg_goals_scored"]
    avg_ht_conceded = ht_stats_dict["avg_goals_against"]
    avg_at_scored = at_stats_dict["avg_goals_scored"]
    avg_at_conceded = at_stats_dict["avg_goals_against"]
    
    lambda_home_team = avg_ht_scored * avg_at_conceded
    lambda_away_team = avg_at_scored * avg_ht_conceded
    
    pr_home, pr_away, pr_draw = 0, 0, 0
    result_probs = list()
    
    for x in range(0,14): #number of goals home team (max14)
        for y in range(0, 14): #number of goals away team (max14)
            p = poisson.pmf(x, lambda_home_team) * poisson.pmf(y, lambda_away_team)
            result_probs.append((x,y,p))
            # if p > 0.01: print(f"Result: {x}-{y}, Prob: {p}") 
            if x == y:
                pr_draw += p
            elif x > y:
                pr_home += p
            else:
                pr_away += p
    (print(home_team, away_team)) if max(pr_draw, pr_home, pr_away)==pr_draw else 0
    
    HS, AS, P = max(result_probs, key=itemgetter(2))           
    # print(f"{home_team}: {pr_home}")
    # print(f"Draw: {pr_draw}")
    # print(f"{away_team}: {pr_away}")
    # print(f"Most probable result: {HS}-{AS} ({P})")
                 
    # print(lambda_home_team, lambda_away_team)
    points_home_team = 3 * pr_home + pr_draw
    points_away_team = 3 * pr_away + pr_draw
    
    return HS, AS, pr_home, pr_draw, pr_away

def fill_predictions(test_set: pd.DataFrame):
    ''' Fills pd.DF with games as rows in terms of predicted exact 
    scores (pr_HS/prd_AS) and prd_WDL probabilities.
    '''
    for i, game in test_set.iterrows():
        
        home_team = game.HT
        away_team = game.AT
        try:
            HS, AS, W, D, L = predict_game(home_team, away_team)
        except:
            continue #ignore games with teams not present in training set
        
        test_set.at[i,"pr_HS"] = HS
        test_set.at[i,"prd_AS"] = AS
        
        test_set.at[i, "prd_W"] = W
        test_set.at[i, "prd_D"] = D
        test_set.at[i, "prd_L"] = L
        #print(HS, AS, W, D, L)
        
    return test_set

# %%
HS, AS, W, D, L = predict_game("Real Sociedad", "Elche")
print(HS, AS, W, D, L)
# Out:
# 1 1 0.4285002255616886 0.2340073026753857 0.337492467286655

# %% [markdown]
# ### Fill predictions in Prediction Set

# %%
test_set = pd.read_excel("datasets/raw/PredictionSet_2023_01_31.xlsx")
test_set
# Out:
#       Lge    Sea        Date                            HT  \
# 0    ARG1  23-24  16/04/2023                   CA Banfield
# 1    ARG1  23-24  16/04/2023            Defensa y Justicia
# 2    ARG1  23-24  16/04/2023               Velez Sarsfield
# 3    ARG1  23-24  16/04/2023                      Platense
# 4    ARG1  23-24  16/04/2023              Talleres Cordoba
# ..    ...    ...         ...                           ...
# 625  ZAF1  22-23  28/04/2023               Moroka Swallows
# 626  ZAF1  22-23  29/04/2023  Tshakhuma Tsha Madzivhandila
# 627  ZAF1  22-23  29/04/2023                  Stellenbosch
# 628  ZAF1  22-23  29/04/2023             Mamelodi Sundowns
# 629  ZAF1  22-23  29/04/2023                       AmaZulu
#
#                        AT  HS  AS  GD WDL  pr_HS  prd_AS  prd_W  prd_D  prd_L
# 0         Central Cordoba  -1  -1   0   D     -1      -1      0      0      0
# 1    Instituto de Córdoba  -1  -1   0   D     -1      -1      0      0      0
# 2        Barracas Central  -1  -1   0   D     -1      -1      0      0      0
# 3                CA Colon  -1  -1   0   D     -1      -1      0      0      0
# 4             San Lorenzo  -1  -1   0   D     -1      -1      0      0      0
# ..                    ...  ..  ..  ..  ..    ...     ...    ...    ...    ...
# 625     Maritzburg United  -1  -1   0   D     -1      -1      0      0      0
# 626     SuperSport United  -1  -1   0   D     -1      -1      0      0      0
# 627         Golden Arrows  -1  -1   0   D     -1      -1      0      0      0
# 628       Richards Bay FC  -1  -1   0   D     -1      -1      0      0      0
# 629     Sekhukhune United  -1  -1   0   D     -1      -1      0      0      0
#
# [630 rows x 14 columns]

# %%
def fill_predictions(test_set):
    for i, game in test_set.iterrows():
        
        home_team = game.HT
        away_team = game.AT
        try:
            HS, AS, W, D, L = predict_game(home_team, away_team)
        except:
            continue #ignore games with teams not present in training set
        
        test_set.at[i,"pr_HS"] = HS
        test_set.at[i,"prd_AS"] = AS
        
        test_set.at[i, "prd_W"] = W
        test_set.at[i, "prd_D"] = D
        test_set.at[i, "prd_L"] = L
        #print(HS, AS, W, D, L)
        
    return test_set

# %%
fill_predictions(test_set)
# Out:
#       Lge    Sea        Date                            HT  \
# 0    ARG1  23-24  16/04/2023                   CA Banfield
# 1    ARG1  23-24  16/04/2023            Defensa y Justicia
# 2    ARG1  23-24  16/04/2023               Velez Sarsfield
# 3    ARG1  23-24  16/04/2023                      Platense
# 4    ARG1  23-24  16/04/2023              Talleres Cordoba
# ..    ...    ...         ...                           ...
# 625  ZAF1  22-23  28/04/2023               Moroka Swallows
# 626  ZAF1  22-23  29/04/2023  Tshakhuma Tsha Madzivhandila
# 627  ZAF1  22-23  29/04/2023                  Stellenbosch
# 628  ZAF1  22-23  29/04/2023             Mamelodi Sundowns
# 629  ZAF1  22-23  29/04/2023                       AmaZulu
#
#                        AT  HS  AS  GD WDL  pr_HS  prd_AS     prd_W     prd_D  \
# 0         Central Cordoba  -1  -1   0   D      1       1  0.456825  0.245911
# 1    Instituto de Córdoba  -1  -1   0   D      0       0  0.000000  0.367879
# 2        Barracas Central  -1  -1   0   D      1       1  0.511057  0.226284
# 3                CA Colon  -1  -1   0   D      1       1  0.392273  0.253332
# 4             San Lorenzo  -1  -1   0   D      1       1  0.330920  0.244354
# ..                    ...  ..  ..  ..  ..    ...     ...       ...       ...
# 625     Maritzburg United  -1  -1   0   D      1       1  0.411401  0.268286
# 626     SuperSport United  -1  -1   0   D      0       1  0.195545  0.284021
# 627         Golden Arrows  -1  -1   0   D      1       1  0.372532  0.280040
# 628       Richards Bay FC  -1  -1   0   D      0       0  0.391319  0.358574
# 629     Sekhukhune United  -1  -1   0   D      0       0  0.329040  0.334805
#
#         prd_L
# 0    0.297264
# 1    0.632121
# 2    0.262659
# 3    0.354395
# 4    0.424726
# ..        ...
# 625  0.320313
# 626  0.520434
# 627  0.347427
# 628  0.250107
# 629  0.336155
#
# [630 rows x 14 columns]

# %%
print(predict_game("Valladolid", "Athletic Bilbao"))
print(predict_game("Almeria", "Cadiz"))
print(predict_game("Vallecano", "Girona"))
print(predict_game("Espanyol Barcelona", "Celta de Vigo"))
print(predict_game("Athletico Madrid", "Valencia"))
print(predict_game("Real Betis", "Mallorca"))
print(predict_game("Osasuna", "Villarreal"))
print(predict_game("Real Sociedad", "Elche"))
print(predict_game("Getafe", "Sevilla FC"))
print(predict_game("FC Barcelona", "Real Madrid"))
# Out:
# (1, 1, 0.38062116877455004, 0.2305995728709916, 0.38877925304683375)
# (1, 1, 0.3640946156100736, 0.25268029495124505, 0.3832250887303924)
# (1, 1, 0.3153525923616397, 0.2233038085036607, 0.46134358509850815)
# (1, 1, 0.33151592540621877, 0.22913394249755192, 0.4393501247202423)
# (1, 1, 0.45261263946263003, 0.22812392354308272, 0.31926342830929005)
# (1, 1, 0.4319115160173203, 0.22786159296718142, 0.3402268830547751)
# (1, 1, 0.2614570357226383, 0.22651639185456282, 0.512026560179152)
# (1, 1, 0.4285002255616886, 0.2340073026753857, 0.337492467286655)
# (1, 1, 0.26715617756721016, 0.22486231019715744, 0.5079814981580819)
# (2, 2, 0.4254376154420775, 0.19771185588540796, 0.37685036285361084)

# %% [markdown]
# # Evaluate predictions

# %% [markdown]
# HS, AS: with RMSE
#
# W, D, L probs: ranked probability score (RPS)

# %%
def rps_func(probs, actual):
    cum_probs = np.cumsum(probs)
    cum_actual = np.cumsum(actual)
    
    sum_rps = 0
    for i in range(len(actual)):         
        sum_rps+= (cum_probs[i] - cum_actual[i])**2
    
    return sum_rps/(len(actual)-1)

# %%
# df = validation_df_with_predictions
def evaluate_validation(df: pd.DataFrame):
    
    for i, game in df.iterrows():
        # Evaluate individually exact score predicted with RMSE
        rmse = (game.HS - game.pr_HS)**2 + (game.AS - game.prd_AS)**2
        df.at[i,"RMSE"] = rmse
        
        # Evaluate individually WDL predictions probabilities with RPS
        if game.WDL == "W":
            actual_probs = [1, 0, 0]
        elif game.WDL == "D":
            actual_probs = [0, 1, 0]
        elif game.WDL == "L":
            actual_probs = [0, 0, 1]
        pred_probs = [game.prd_W, game.prd_D, game.prd_L]
        rps_v = rps_func(pred_probs, actual_probs)
        df.at[i, "RPS"] = rps_v

    RMSE = np.sqrt(sum(df["RMSE"].values) / df.shape[0]) 
    RPS_avg = sum(df["RPS"].values) / df.shape[0] 
    
    return df, RMSE, RPS_avg

# %%
training = training_set[50:100].copy()
training_prd = fill_predictions(training)
df, RMSE, RPS = evaluate_validation(training_prd)
print(RMSE, RPS)
df
# Out:
# 1.9183326093250879 0.2381666823619057
#         Sea   Lge       Date                         HT  \
# 7126  00-01  CHN1 2000-04-09                Shenzhen FC
# 7127  00-01  CHN1 2000-04-09          Sichuan Guancheng
# 7128  00-01  CHN1 2000-04-09              Xiamen Xiaxin
# 7123  00-01  CHN1 2000-04-09            Chongqing Lifan
# 7627  00-01  SWE1 2000-04-09             Trelleborgs FF
# 7631  00-01  SWE1 2000-04-10                     Hacken
# 7630  00-01  SWE1 2000-04-10                Hammarby IF
# 7632  00-01  SWE1 2000-04-10                IF Elfsborg
# 6892  00-01  RUS1 2000-04-15           Lokomotiv Moscow
# 6891  00-01  RUS1 2000-04-15             Krylia Sovetov
# 6890  00-01  RUS1 2000-04-15             Torpedo Moscow
# 6889  00-01  RUS1 2000-04-15        Zenit St Petersburg
# 7632                  AIK Solna   1   2  -1   L      3    1.0     1.0
# 6892             Fakel Voronezh   1   0   1   W      1    1.0     0.0
# 6891             Spartak Moscow   1   2  -1   L      3    1.0     1.0
# 6890                  FK Saturn   2   0   2   W      2    1.0     1.0
# 6889              Dinamo Moscow   0   1  -1   L      1    2.0     1.0
# 6888  Lokomotiv Nizhni Novgorod   0   0   0   D      0    1.0     0.0
# 6887          Anzhi Makhachkala   2   3  -1   L      5    1.0     1.0
# 6886            Rotor Volgograd   2   0   2   W      2    1.0     1.0
# 6885   Chernomorets Novorossisk   0   3  -3   L      3    2.0     0.0
# 7131   Guangzhou Rich and Force   1   1   0   D      2    2.0     1.0
# 7633             Trelleborgs FF   0   1  -1   L      1    1.0     2.0
# 7132                Shenzhen FC   0   1  -1   L      1    1.0     1.0
# 7133            Shandong Luneng   1   0   1   W      1    1.0     2.0
# 7134                   Liaoning   1   0   1   W      1    1.0     1.0
# 7135            Chongqing Lifan   4   0   4   W      4    1.0     1.0
# 7130              Yunnan Hongta   2   1   1   W      3    1.0     1.0
# 7634                  Orebro SK   2   2   0   D      4    1.0     1.0
# 7136              Xiamen Xiaxin   2   1   1   W      3    2.0     1.0
# 7635                Hammarby IF   0   0   0   D      0    2.0     2.0
# 7636                 Orgryte IS   2   0   2   W      2    2.0     1.0
# 7637                     Hacken   1   1   0   D      2    1.0     1.0
# 7638              GAIS Goteborg   3   0   3   W      3    2.0     1.0
# 7138              Yunnan Hongta   4   1   3   W      5    1.0     1.0
# 7143         Shanghai Greenland   1   1   0   D      2    0.0     2.0
# 7137                Shenzhen FC   3   0   3   W      3    1.0     1.0
# 7139            Shandong Luneng   5   0   5   W      5    1.0     1.0
# 7140                    Qingdao   1   1   0   D      2    1.0     1.0
# 7142               Tianjin Teda   5   1   4   W      6    1.0     1.0
# 7141          Sichuan Guancheng   0   1  -1   L      1    1.0     1.0
# 7640                  AIK Solna   4   0   4   W      4    1.0     1.0
# 7643            Vastra Frolunda   6   0   6   W      6    3.0     0.0
# 7642             IFK Norrkoping   2   0   2   W      2    1.0     2.0
# 7641            Helsingborgs IF   2   3  -1   L      5    2.0     1.0
# 7639               IFK Goteborg   1   1   0   D      2    1.0     2.0
# 6899           Lokomotiv Moscow   0   4  -4   L      4    0.0     1.0
# 6900             Krylia Sovetov   3   2   1   W      5    1.0     1.0
# 6897              Uralan Elista   2   1   1   W      3    1.0     0.0
# 6894        Zenit St Petersburg   1   0   1   W      1    1.0     1.0
# 6896         Alania Vladikavkaz   1   1   0   D      2    0.0     1.0
# 6895         Rostselmash Rostov   0   0   0   D      0    1.0     1.0
# 6893             Torpedo Moscow   1   0   1   W      1    1.0     1.0
# 7644              GAIS Goteborg   2   1   1   W      3    2.0     1.0
# 6898                CSKA Moscow   1   0   1   W      1    1.0     1.0
#
#          prd_W     prd_D     prd_L  RMSE       RPS
