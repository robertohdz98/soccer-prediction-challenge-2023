# %%
import pandas as pd

# %% [markdown]
# # Compare training set and prediction set

# %%
test_set = pd.read_excel("datasets/raw/PredictionSet_2023_01_31.xlsx")
test_set
# Out:
#       Lge    Sea        Date                            HT  \
# 0    ARG1  23-24  16/04/2023                   CA Banfield
# 1    ARG1  23-24  16/04/2023            Defensa y Justicia
# 2    ARG1  23-24  16/04/2023               Velez Sarsfield
# 3    ARG1  23-24  16/04/2023                      Platense
# 4    ARG1  23-24  16/04/2023              Talleres Cordoba
# ..    ...    ...         ...                           ...
# 625  ZAF1  22-23  28/04/2023               Moroka Swallows
# 626  ZAF1  22-23  29/04/2023  Tshakhuma Tsha Madzivhandila
# 627  ZAF1  22-23  29/04/2023                  Stellenbosch
# 628  ZAF1  22-23  29/04/2023             Mamelodi Sundowns
# 629  ZAF1  22-23  29/04/2023                       AmaZulu
#
#                        AT  HS  AS  GD WDL  pr_HS  prd_AS  prd_W  prd_D  prd_L
# 0         Central Cordoba  -1  -1   0   D     -1      -1      0      0      0
# 1    Instituto de Córdoba  -1  -1   0   D     -1      -1      0      0      0
# ...

# %%
home_teams_list = test_set["HT"].unique().tolist()
away_teams_list = test_set["AT"].unique().tolist()
teams_list = list(set(home_teams_list + away_teams_list))
print("Number of teams in training set:",len(teams_list))
# Out:
# Number of teams in training set: 633

# %%
teams_list
# Out:
# ['Leverkusen',
#  'Bradford',
#  'Chaves',
#  'Fleetwood Town',
#  'CD Huachipato',
#  'Boreham Wood',
#  'Kilmarnock',
#  'FC Sion',
#  'Albacete',
#  'Stranraer',
#  'Maritimo',
#  'Kalmar FF',
#  'Altrincham',
#  'Groningen',
#  'Valerenga IF',
#  'Genoa',
#  'Oviedo',
#  'Atletico Tucuman',
#  'Bodo/Glimt',
#  'FC Metz',
#  'CSKA Moscow',
#  'Crystal Palace',
#  'Bonnyrigg Rose',
#  'River Plate',
#  'Southampton',
#  'Adelaide United',
#  'Real Madrid',
#  'FK Ural',
#  'Tigre',
#  'FC Martigues',
#  'Huracan',
#  'Pisa',
#  'Edinburgh City',
#  'Ross County',
#  'FC St Gallen',
#  'Leicester City',
#  'Queens Park',
#  'Eibar',
#  'Arsenal',
#  'Kaiserslautern',
#  'AC Milan',
#  'Newells Old Boys',
#  'US Concarneau',
#  'Club Necaxa',
#  'Zenit St Petersburg',
#  'USM Alger',
#  'Platense',
#  'Grenoble',
#  'Andorra',
#  'Tranmere',
#  'Havre AC',
#  'FUS de Rabat',
#  'IFK Norrkoping',
#  'Cardiff City',
#  'FC Volgar Astrakhan',
#  'St Johnstone',
#  'Sevilla FC',
# ...

# %%
test_set["HT"].value_counts()
# Out:
# Everton            3
# Gillingham         2
# Ittihad Tanger     2
# Crawley Town       2
# Crewe Alexandra    2
#                   ..
# Laval              1
# Amiens SC          1
# FC Pau             1
# Paris FC           1
# AmaZulu            1
# Name: HT, Length: 569, dtype: int64

# %%
test_set["AT"].value_counts()
# Out:
# Walsall                2
# Sheffield Wednesday    2
# Plymouth Argyle        2
# Wycombe Wanderers      2
# FC Sion                2
#                       ..
# Sochaux                1
# Valenciennes           1
# Guingamp               1
# Nimes Olympique        1
# Sekhukhune United      1
# Name: AT, Length: 571, dtype: int64
