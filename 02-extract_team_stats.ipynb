# %% [markdown]
# # 02. Extract team statistics

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load processed training dataset

# %%
training_set = pd.read_parquet("datasets/processed/training_set_processed.parquet")

# %% [markdown]
# ### Extract all teams in training set

# %%
home_teams_list = training_set["HT"].unique().tolist()
away_teams_list = training_set["AT"].unique().tolist()
teams_list = list(set(home_teams_list + away_teams_list))
print("Number of teams in training set:",len(teams_list))
# Out:
# Number of teams in training set: 1637

# %%
teams_list
# Out:
# ['Barcelona SC',
#  'YoungHeart Manawatu',
#  'Ironi Ramat HaSharon',
#  'Icasa',
#  'Albacete',
#  'Virtus Lanciano',
#  'FK Rostov',
#  'Napoli',
#  'ES Metlaoui',
#  'Perugia',
#  'Kataller Toyama',
#  'Valladolid',
#  'Tianjin Teda',
#  'Droylsden',
#  'Sevilla FC B',
#  'Confianca',
#  'DRB Tadjenanet',
#  'Degerfors',
#  'FK Ural',
#  'Villarreal B',
#  'Tokushima Vortis',
#  'Mouloudia Oujda',
#  'Wolfsburg',
#  'Roasso Kumamoto',
#  'Nublense',
#  'Gainare Tottori',
#  'Chemnitzer FC',
#  'IF Elfsborg',
#  'Jahn Regensburg',
#  'Toulouse',
#  'Dundee United',
#  'Portland Timbers',
#  'Vejle',
#  'Macclesfield',
#  'Tampa Bay Rowdies',
#  'FK Khimki',
#  'KAC de Kenitra',
#  'Alloa Athletic',
#  'Coquimbo Unido',
#  'Penafiel',
#  'Dumbarton',
#  'Mainz 05 II',
#  'Perth Glory',
#  'Jokerit Helsinki',
#  'Seongnam FC',
#  'Granada 74',
#  'Fluminense Rio de Janeiro',
#  'Kashima Antlers',
#  'TP47 Tornio',
#  'Rosenborg Trondheim',
#  'Sport Club Recife',
#  'Maccabi Netanya',
#  'Eastbourne Borough',
#  'Zweigen',
#  'Kotkan Tyovaen Palloilijat',
#  'FC Superfund',
#  'Sao Bento',
#  'Penn FC',
#  'Vitesse',
#  'Busan IPark',
#  'Alemannia Aachen',
#  'Toulon',
#  'Tacoma Defiance',
#  'HollyHock',
#  'Manning Rangers',
#  'Elversberg',
#  'Larisa',
#  'Viktoria Berlin',
#  'SuperSport United',
#  'Fuerza Amarilla Machala',
#  'Bucheon SK',
#  'Corinthians Paulista',
#  'Club Leon',
#  'Pistoiese',
#  'San Martin Tucuman',
#  'Akademisk',
#  'CA Temperley',
#  'Badajoz',
#  'Ibiza',
#  'Amiens SC',
#  'Como',
#  'Kettering Town',
#  'Roeselare',
#  'Swope Park Rangers',
#  'FC Dallas',
#  'Sete',
#  'Lecce',
#  'Instituto Cordoba',
#  'Nanchang Hengyuan',
#  'Leverkusen',
#  'Sparta Rotterdam',
#  'USM El Harrach',
#  'Independiente',
#  'NAC Breda',
#  'Hull City',
#  'CS Constantine',
#  'Eastern Pride',
#  'Mainz 05',
#  'America RN',
#  'Kelty Hearts',
#  'Willem II',
#  'Jeonnam Dragons',
#  'Orgryte IS',
#  'Chabab Atlas Khenifra',
#  'Oostende',
#  'Huesca',
#  'Haka Valkeakoski',
#  'Ingolstadt',
#  'Stockport County',
#  'Farsley',
#  'Granada',
#  'Sangju Sangmu',
#  'CA Lanus',
#  'Baroka FC',
#  'Arouca',
#  'Evian Thonon Gaillard',
#  'Goias Esporte Clube',
#  'FC Wil',
#  'Maghrib de Fes',
#  'Carlisle',
#  'Havre AC',
#  'Scunthorpe United',
#  'Jiangsu Suning',
#  'Monchengladbach',
#  'Salisbury',
#  'Genoa',
#  'Delfin SC',
#  'Forest Green',
#  'Magra',
#  'Union Espanola',
#  'FC Istres',
#  'Las Palmas',
#  'Leeds United',
#  'Sarpsborg 08',
#  'Sochaux',
#  'Tampere United',
#  'OFI Heraklion',
#  'Southern United',
#  'SV Meppen',
#  'Aalesunds FK',
#  'Houston Dynamo',
#  'Kansas City Wizards',
#  'Vastra Frolunda',
#  'Montpellier',
#  'RC Kouba',
#  'Helsingborgs IF',
#  'Fagiano',
#  'Tambov',
#  'COD Meknes',
#  'Otago United',
#  'Sichuan Guancheng',
#  'Wydad de Fes',
#  'FSV Frankfurt',
#  'FC Salyut Belgorod',
#  'Telford United',
#  'Ethnikos Asteras',
#  'Angostura',
#  'Anzhi Makhachkala',
#  'Chacarita Juniors',
#  'Motherwell',
#  'Shaanxi Lijun Guoli',
#  'Pontevedra',
#  'Tasman United',
#  'Sabadell',
#  'Universidad Central FC',
#  'Gran Valencia Maracay',
#  'Tromso IL',
#  'Murcia',
#  'Deportivo Anzoategui',
#  'Hawkes Bay United FC',
#  'Malaga',
#  'Queen of the South',
#  'Welling United',
#  'Reggiana',
#  'JS El Massira',
#  'Treviso',
#  'Rostselmash Rostov',
#  'Atletico San Luis',
#  'JEF United',
#  'Alessandria',
#  'Melipilla',
#  'Boston',
#  'New Mexico United',
#  'Racing de Casablanca',
#  'Empoli',
#  'Ittihad Tanger',
#  'Kongsvinger IL',
#  'SV Grodig',
#  'Sydney Olympic',
#  'Seattle Sounders',
#  'Xerez',
#  'FC Martigues',
#  'Liaoning',
#  'Zwolle',
#  'TSV Hartberg',
#  'Dunfermline Athletic',
#  'Heidenheim',
#  'Wolfsberger AC',
#  'Red Star',
#  'Deportivo Toluca',
#  'Maccabi Petach-Tikva',
#  'Aalen',
#  'FK Tyumen',
#  'Olympiakos Volou',
#  'Grimsby',
#  'Changsha Ginde',
#  'Ternana',
#  'Nosta Novotroitsk',
#  'Kickers Offenbach',
#  'TPS Turku',
#  'Clydebank',
#  'CA Batna',
#  'Louisville City FC',
#  'GyE Jujuy',
#  'Santos Laguna',
#  'US Concarneau',
#  'FAR de Rabat',
#  'IK Start',
#  'Hassania US Agadir',
#  'Ittihad Khemisset',
#  'Mazatlan',
#  'Philadelphia Union',
#  'Roosendaal',
#  'Fortaleza',
#  'Ehime FC',
#  'Huddersfield Town',
#  'FC Sakhalin',
#  'Celtic Glasgow',
#  'Ottawa Fury',
#  'Eintracht Trier',
#  'Rejiche',
#  'Auxerre',
#  'Vannes OC',
#  'Mordovia Saransk',
#  'AFC Eskilstuna',
#  'ES Beni-Khalled',
#  'CF Pachuca',
#  'Gallipoli',
#  'Atletico El Vigia',
#  'Silver Stars',
#  'Ponferradina',
#  'Poli Ejido',
#  'St Etienne',
#  'Louhans-Cuiseaux',
#  'Wrexham',
#  'Trapani',
#  'Maccabi Tel Aviv',
#  'Kuban Krasnodar',
#  'Richmond Kickers',
#  'Alcorcon',
#  'Llaneros de Guanare',
#  'Hoffenheim',
#  'AZ Alkmaar',
#  'Curico Unido',
#  'Sokol Saratov',
#  'Oud-Heverlee Leuven',
#  'Varzim',
#  'Oued Zem',
#  'Werder Bremen II',
#  'Guaros de Lara',
#  'Chelsea',
#  'Monarcas Morelia',
#  'Sydney United Pumas',
#  'CS Hammam-Lif',
#  'Chunnam Dragons',
#  'Panserraikos',
#  'Talleres Cordoba',
#  'Viikingit',
#  'Hapoel Ramat Gan',
#  'Hyde United',
#  'Atletico Socopo',
#  'Hellas Verona',
#  'FC Vaduz',
#  'Cesena',
#  'Beijing Sanyaun',
#  'San Antonio Scorpions',
#  'Sportfreunde Lotte',
#  'Dinamo St Petersburg',
#  'Brisbane Roar',
#  'America de Quito',
#  'Elgin City',
#  'Darlington',
#  'Deportivo Azogues',
#  'Newcastle United',
#  'Sao Caetano',
#  'Northwich',
#  'Logrones',
#  'Nimes',
#  'Rochdale',
#  'Frosinone',
#  'Vendee Lucon',
#  'Barracas Central',
#  'Changchun Yatai',
#  'Stade de Reims',
#  'Deportivo Quevedo',
#  'Schweinfurt',
#  'Cuernavaca',
#  'Lausanne Sport',
#  'Panthrakikos',
#  'Dalkurd',
#  'Bastia-Borgo',
#  'Hapoel Ashkelon',
#  'CSKA Moscow',
#  'Machida Zelvia',
#  'Tottenham Hotspur',
#  'Salgueiros',
#  'Rodina Moskva',
#  'Hercules',
#  'Esbjerg fB',
#  'Solihull',
#  'Orange County SC',
#  'Nocerina 1910',
#  'Real Sociedad',
#  'Club Tijuana',
#  'Wanderers SC',
#  'Novara',
#  'Deportes Copiapo',
#  'Burgos',
#  'Grays',
#  'Helisngor',
#  'Koblenz',
#  'Morecambe',
#  'Paris FC',
#  'SV Ried',
#  'Panionios',
#  'CD Veracruz',
#  'Union La Calera',
#  'Neuchatel Xamax',
#  'Manta FC',
#  'Shanghai East Asia',
#  'Newcastle United Jets',
#  'FK Zhemchuzhina',
#  'Bromley',
#  'CA Banfield',
#  'Portuguesa FC',
#  'Villarreal',
#  'Aberdeen',
#  'Austin FC',
#  'Maccabi Haifa',
#  'Deportivo Petare',
#  'Aalst',
#  'Brusque - SC',
#  'Marseille Consolat',
#  'Dijon',
#  'Los Andes',
#  'SV Mattersburg',
#  'CD Huachipato',
#  'EGS Gafsa',
#  'Daejeon Citizen',
#  'FC Volgar Astrakhan',
#  'Ravenna',
#  'Hapoel Raanana',
#  'Chaves',
#  'Avai FC',
#  'Burton',
#  'SCR Altach',
#  'Go Ahead Eagles',
#  'Jubilo Iwata',
#  'Metropolitanos FC',
#  'Tuks FC',
#  'Barnsley',
#  'Birmingham City',
#  'Instituto de Córdoba',
#  'FC Edmonton',
#  'Chicago Fire',
#  'Kagoshima',
#  'VfB Oldenburg',
#  'Wehen Wiesbaden',
#  'Tondela',
#  'Pacy Vallee',
#  'Internazionale Milano',
#  'Yaracuyanos FC',
#  'Charleston Battery',
#  'Genk',
#  'Harelbeke',
#  'Gubbio',
#  'Stade Plabennec',
#  'Charlton Athletic',
#  'Accrington',
#  'Clube de Regatas Brasil',
#  'Hartlepool',
#  'Lokeren',
#  'Assyriska',
#  'Consadole Sapporo',
#  'Sporting Kansas City',
#  'Highlands Park',
#  'Colchester',
#  'Henan Jianye',
#  'Hannover 96',
#  'Ionikos',
#  'New England Revolution',
#  'FC Chambly',
#  'GyE La Plata',
#  'EO Sidi Bouzid',
#  'Deportivo Italia',
#  'Leicester City',
#  'Northampton Town',
#  'UA Maracaibo',
#  'Hapoel Beer Sheva',
#  'San Diego Loyal',
#  'Ipswich Town',
#  'Hertha Berlin',
#  'Kyoto Sanga',
#  'Pisa',
#  'Khemis Zemamra',
#  'Chayka Peschanokopskoye',
#  'Duque de Caxias',
#  'SpVgg Bayreuth',
#  'FC Tambov',
#  'Djurgardens',
#  'Sandefjord Fotball',
#  'Union de Santa Fe',
#  'Irtysh Omsk',
#  'Sedan',
#  'Santos FC',
#  'Raja Beni Mellal',
#  'FC St Gallen',
#  'Lorca',
#  'Le Poire-sur-Vie',
#  'Operario Ferroviario ',
#  'Shrewsbury Town',
#  'MO Bejaia',
#  'Chateauroux',
#  'Sandnes Ulf',
#  'Sanfrecce',
#  'Monagas',
#  'Canterbury United',
#  'St Raphael FC',
#  'Uniao Madeira',
#  'Las Vegas Lights FC',
#  'Cagliari',
#  'Atvidabergs',
#  'Santander',
#  'Sampdoria',
#  'MVD Rossii',
#  'US Colomiers',
#  'Havant and Waterlooville',
#  'Newport County',
#  'Biskra',
#  'Waldhof Mannheim',
#  'Hangzhou Greentown',
#  'New York Red Bulls II',
#  'Deportivo Cuenca',
#  'Chernomorets Novorossisk',
#  'Carolina RailHawks',
#  'Ajax Cape Town',
#  'Zwickau',
#  'Sochi',
#  'CA Bizertin',
#  'Veria',
#  'Wuhan Optics Valley',
#  'CD Godoy Cruz',
#  'Boreham Wood',
#  'Swansea City',
#  'FK Tosno',
#  'Iraklis',
#  'JS Kasba Tadla',
#  'Grasshoppers Zurich',
#  'Uerdingen',
#  'Stabia',
#  'Falkenbergs',
#  'Olympic Sharks',
#  'GIF Sundsvall',
#  'Gillingham',
#  'Hyeres FC',
#  'Kings Lynn',
#  'FK Amkar Perm',
#  'AC Milan',
#  'JS Kabylie',
#  'Pittsburgh Riverhounds',
#  'Eastleigh',
#  'NA Hussein Dey',
#  'Miami FC',
#  'Wuppertaler SV',
#  'Foggia',
#  'Spezia',
#  'Richards Bay FC',
#  'Celta de Vigo',
#  'Agremiacao Sportiva Arapiraquense',
#  'Randers FC',
#  'Paniliakos',
#  'San Martin de San Juan',
#  'Bury',
#  'Esperance Zarzis',
#  'Los Angeles Galaxy',
#  'Adelaide United',
#  'Vallecano',
#  'Kalmar FF',
#  'Kaizer Chiefs',
#  'Stranraer',
#  'Harrogate Town',
#  'Waitakere United',
#  'Lens',
#  'Rennes',
#  'Santa Clara',
#  'Gamba Osaka',
#  'FK Kamaz',
#  'Birmingham Legion',
#  'AFC Wimbledon',
#  'Rochester Rhinos',
#  'Tochigi SC',
#  'Queens Park Rangers',
#  'Altrincham',
#  'Giravanz',
#  'El Bayadh',
#  'Standard',
#  'FK Nizhniy Novgorod',
#  'Gravesend',
#  'PS Kemi',
#  'Kaiserslautern',
#  'St Pauli',
#  'Cartagena',
#  'Nottingham Forest',
#  'Guaratingueta',
#  'ESTAC Troyes',
#  'Cordoba',
#  'Landskrona BoIS',
#  'Torpedo Vladimir',
#  'Club Necaxa',
#  'Blackburn Rovers',
#  'Sevilla Atletico',
#  'Torquay',
#  'Los Angeles Galaxy II',
#  'Hearts',
#  'Fortuna Dusseldorf',
#  'Cassis-Carnoux',
#  'Cove Rangers',
#  'Palermo',
#  'Odense',
#  'Kristiansund BK',
#  'Oviedo',
#  'Hapoel Kfar Saba',
#  'Real Madrid B',
#  'Maccabi Ahi Nazareth',
#  'Brentford',
#  'AEK',
#  'Parana Clube',
#  'Preussen Munster',
#  'Werder Bremen',
#  'Kashiwa Reysol',
#  'Angers SCO',
#  'Jacksonville Armada',
#  'AIK Solna',
#  'Shonan Bellmare',
#  'August First Football Team',
#  'Watford',
#  'Istres',
#  'Osnabruck',
#  'Olympique Beja',
#  'Hakoah Ramat Gan',
#  'Enkopings',
#  'Groningen',
#  'Ljungskile SK',
#  'Gent',
#  'Extremadura',
#  'Los Angeles FC',
#  'BidVest Wits',
#  'Amorebieta',
#  'Xiamen Xiaxin',
#  'D.C. United',
#  'Schalke 04',
#  'Zenit St Petersburg',
#  'Bnei Sachnin FC',
#  'Rodez AF',
#  'PAOK',
#  'Atletico Clube Goianiense',
#  'Luch-Energia',
#  'FC Dundee',
#  'Verl',
#  'Veracruz Sporting Club',
#  'Uralan Elista',
#  'Hobro',
#  'SK Austria Klagenfurt',
#  'AS Beziers',
#  'Macara',
#  'Magdeburg',
#  'Deportes Melipilla',
#  'Andorra',
#  'Sheffield Wednesday',
#  'Renofa Yamaguchi',
#  'Shimizu Pulse',
#  'Chiapas FC',
#  'Atlanta United FC II',
#  'Lorient',
#  'Ayr United',
#  'Compostela',
#  'Shinnik Yaroslavl',
#  'Silkeborg',
#  'Puerto Rico FC',
#  'Macarthur FC',
#  'Lille',
#  'Thanda Royal Zulu',
#  'Utrecht',
#  'Cannes',
#  'Chapecoense',
#  'Deportivo Nublense',
#  'OMR El Annasser',
#  'Twente Enschede',
#  'Maidenhead United',
#  'US Avranches',
#  'Hapoel Tel Aviv',
#  'Academica',
#  'Troyes',
#  'Dalian Haichang',
#  'Deportivo Lara',
#  'Siegen',
#  'SD Aucas',
#  'FC Orenburg',
#  'ADO Den Haag',
#  'Gateshead',
#  'FC Sion',
#  'Vissel Kobe',
#  'Sogndal IL',
#  'Blaublitz',
#  'Jeju United',
#  'St Polten',
#  'Argentinos Juniors',
#  'Bellinzona',
#  'Sonnenhof Grossaspach',
#  'Everton',
#  'SC Bastia',
#  'Skikda',
#  'Khenchela',
#  'Bayern Munich II',
#  'Entente SSG',
#  'Port Vale',
#  'Gremio Novorizontino',
#  'Sporting Kansas City 2',
#  'Molenbeek',
#  'Engen Santos FC',
#  'Hapoel Rishon',
#  'Sao Paulo FC',
#  'Harrisburg City Islanders',
#  'Belenenses',
#  'Fulham',
#  'Deportivo Zulia',
#  'Catanzaro',
#  'Leonesa',
#  'Estudiantes de Caracas',
#  'Wimbledon',
#  'Burnley',
#  'Farense',
#  'Milton Keynes Dons',
#  'Tours',
#  'Club Irapuato',
#  'Rotor Volgograd',
#  'Stoke City',
#  'FK Tom Tomsk',
#  'Santiago Morning',
#  'Ituano - SP',
#  'New York City FC',
#  'NEC Nijmegen',
#  'Padova',
#  'FK Moscow',
#  'Arbroath',
#  'Jendouba Sport',
#  'Gold Coast United',
#  'CF Montreal',
#  'Reggina',
#  'Westerlo',
#  'Peterborough United',
#  'Dorking Wanderers',
#  'SO Cholet',
#  'Trelleborgs FF',
#  'Vila Nova FC GO',
#  'Oulu',
#  'Volendam',
#  'Brondby',
#  'Le Puy',
#  'Venezia',
#  'Paderborn',
#  'Histon',
#  'Incheon United',
#  'Valence',
#  'Oldham Athletic',
#  'Montreal Impact',
#  'Hartford Athletic',
#  'Atalanta',
#  'Tulsa Roughnecks',
#  'Ebbsfleet',
#  'Antwerp',
#  'Rovaniemi PS',
#  'Feyenoord Rotterdam',
#  'Athletic Bilbao',
#  'FC Gueugnon',
#  'Beira Mar',
#  'Gap FC',
#  'AC Barnechea',
#  'Lillestrom SK',
#  'RB Leipzig',
#  'Sandhausen',
#  'Yokohama Marinos',
#  'Sagamihara',
#  'San Lorenzo',
#  'Cercle Brugge',
#  'SPAL Ferrara',
#  'Start Kristiansand',
#  'FC Thun',
#  'Free State Stars',
#  'North Carolina FC',
#  'Antofagasta',
#  'AS Lyon-Duchere',
#  'Southampton',
#  'North Ferriby',
#  'Sekhukhune United',
#  'Tranmere',
#  'Preston North End',
#  'Proodeftiki',
#  'Mirandes',
#  'Erzgebirge Aue',
#  'Racing Club',
#  'Cittadella',
#  'Youssoufia Berrechid',
#  'Olhanense',
#  'VfB Stuttgart II',
#  'AS Cherbourg',
#  'Valenciennes',
#  'Nordsjalland',
#  'Molde FK',
#  'Cadiz',
#  'Esporte Clube Juventude',
#  'PSV Eindhoven',
#  'Chertanovo',
#  'Estudiantes de Merida',
#  'Viktoria Koln',
#  'Aston Villa',
#  'ES Uzes Pont du Gard',
#  'Oeste FC',
#  'Egaleo',
#  'Orlando City B',
#  'Viborg',
#  'Reutlingen',
#  'Bonnyrigg Rose',
#  'Thrasyvoulos',
#  'Santa Cruz FC',
#  'Khimik Dzerzhinsk',
#  'Guadalajara',
#  'Stellenbosch',
#  'Yokohama FC',
#  'IFK Mariehamn',
#  'Ostersunds FK',
#  'AC Ajaccio',
#  'Juventus',
#  'FC Tokyo',
#  'Aldosivi',
#  'Cape Town City FC',
#  'Panathinaikos',
#  'Hibernian',
#  'Eastern Suburbs',
#  'Ancona 1905',
#  'CR Belouizdad',
#  'Dinamo Moscow',
#  'Rushden and Diamonds',
#  'Central Coast Mariners',
#  'Arminia Bielefeld',
#  'Spartak Moscow',
#  'FC Zurich',
#  'Viking Stavanger',
#  'Wycombe Wanderers',
#  'Clermont',
#  'Dartford',
#  'Deportes Temuco',
#  'Paradou AC',
#  'For Sittard',
#  'CSD Rangers',
#  'Olympique de Safi',
#  'Mamelodi Sundowns',
#  'Sacramento Republic',
#  'FC Rouen',
#  'Raja Casablanca',
#  'Gretna',
#  'Braunschweig',
#  'FC Ufa',
#  'Columbus Crew',
#  'FC Neftekhimik',
#  'EA Guingamp',
#  'Guimaraes',
#  'FC Honka',
#  'Kapfenberger SV',
#  'Ponte Preta',
#  'Leiria',
#  'Orlando City',
#  'Doncaster Rovers',
#  'Club Brugge',
#  'FK Krasnodar',
#  'Den Bosch',
#  'Olympique Lyonnais',
#  'Athletic Bilbao B',
#  'Notts County',
#  'Heracles',
#  'SC Imbabura',
#  'LB Chateauroux',
#  'West Ham United',
#  'Carl Zeiss Jena',
#  'Gimcheon Sangmu',
#  'Dynamo Dresden',
#  'Freiburg II',
#  'Partick Thistle',
#  'Waalwijk',
#  'Babelsberg',
#  'FC Luzern',
#  'Mechelen',
#  'Queensland Roar',
#  'Atletico Mineiro',
#  'Deportivo Guadalajara',
#  'Porto',
#  'Red Diamonds',
#  'Middlesbrough',
#  'Crystal Palace',
#  'Crotone',
#  'Everton CD',
#  'FK Radian-Baikal Irkutsk',
#  'Pumas de la UNAM',
#  'Sheffield United',
#  'AS Moulins',
#  'FK Haugesund',
#  'Hamilton Wanderers',
#  'Aalborg',
#  'Sporting Gijon',
#  'Grenoble',
#  'Varbergs BoIS',
#  'Bordeaux',
#  'Tigres de la Universidad Autonoma',
#  'RW Erfurt',
#  'RC Relizane',
#  'Dender',
#  'Atletico Celaya',
#  'Golden Arrows',
#  'Le Mans',
#  'Gremio Prudente',
#  'K Beerschot VA',
#  'Darmstadt 98',
#  'Midtjylland',
#  'Hamburger SV',
#  'Gwangju FC',
#  'Pescara',
#  'Parramatta Power',
#  'Villefranche Beaujolais',
#  'Inter Turku',
#  'Rapid Wien',
#  'USM Bel Abbes',
#  'AS Marsa',
#  'Lamia FC',
#  'Kamatamare',
#  'Ilves Tampere',
#  'Estrella Roja',
#  'Vasco da Gama',
#  'Olympiakos Piraeus',
#  'Castellon',
#  'SR Colmar',
#  'Aves',
#  'Apollon',
#  'IFK Norrkoping',
#  'Difaa Jadida',
#  'Gallos Blancos Queretaro FC',
#  'Estoril',
#  'FK Torpedo Armavir',
#  'Roda',
#  'Gimnastic Tarragona',
#  'Kemi Kings',
#  'CR Vasco da Gama',
#  'OKC Energy FC',
#  'Mushuc Runa',
#  'Bergen',
#  'Lota Schwager',
#  'Cheltenham',
#  'Wigan Athletic',
#  'Wellington Phoenix',
#  'Avellino',
#  'Stirling Albion',
#  'Kerkyra',
#  'Ipatinga FC',
#  'Union Berlin',
#  'JS Kairouan',
#  'Feirense',
#  'Wacker Burghausen',
#  'Chorley FC',
#  'Wuhan Zall FC',
#  'Union de Touarga',
#  'Osters IF',
#  'Estudiantes Tecos',
#  'Reno 1868 FC',
#  'Nuneaton Town',
#  'HJK Helsinki',
#  'Jonkopings Sodra',
#  'Sassuolo',
#  'Hebei China Fortune FC',
#  'Brommapojkarna',
#  'Ranheim IL',
#  'Chippa United',
#  'Ross County',
#  'Auckland Football Kingz',
#  'St Johnstone',
#  'Nimes Olympique',
#  'Bradford',
#  'Delemont',
#  'Union Saint-Gilloise',
#  'Velez Sarsfield',
#  'Crawley Town',
#  'Famalicao',
#  'Rio Grande Valley FC',
#  'Doxa Dramas',
#  'Monterey Bay FC',
#  'FC Basel',
#  'Aragua FC',
#  'Chongqing Lifan',
#  'Barrow',
#  'Ferrol',
#  'Drancy',
#  'Arsenal Tula',
#  'Stafford Rangers',
#  'Lyn Oslo',
#  'Leyton Orient',
#  'Beitar Jerusalem',
#  'Lazio',
#  'River Plate',
#  'Nantes',
#  'Kawkab AC Marrakech',
#  'Memphis 901',
#  'Juve Stabia',
#  'Sevilla FC',
#  'Renaissance de Berkane',
#  'CA Bordj Bou Arreridj',
#  'Chebba',
#  'Jyvaskyla',
#  'US Luzenac',
#  'Caen',
#  'Hereford',
#  'Alverca',
#  'Mjallby AIF',
#  'Ceara SC',
#  'Paris Saint-Germain',
#  'Martigues',
#  'Bayern Munich',
#  'Yanbian FC',
#  'Volga Nizhniy Novgorod',
#  'Braintree Town',
#  'Karlsruher SC',
#  'Swindon Town',
#  'San Marcos de Arica',
#  'Hapoel Nazareth',
#  'MC El Eulma',
#  'Ulsan Hyundai',
#  'West Bromwich Albion',
#  'Bnei Yehuda Tel Aviv',
#  'Eintracht Frankfurt',
#  'Schwarz Weiss Bregenz',
#  'FC Schaffhausen',
#  'Lleida',
#  'Newells Old Boys',
#  'Shandong Luneng',
#  'Louvieroise',
#  'Cerezo Osaka',
#  'La Palme Tozeur',
#  'Melbourne Victory',
#  'York City',
#  'Beveren',
#  'Austria Lustenau',
#  'Guangzhou Evergrande',
#  'Algeciras',
#  'Recreativo',
#  'Alcoyano',
#  'Kidderminster',
#  'Huracan',
#  'Niki Volou FC',
#  'Stade Tunisien',
#  'Monza',
#  'Jaen',
#  'AS Sale',
#  'Independiente del Valle',
#  'St Mirren',
#  'Pro Vercelli',
#  'Vestsjalland',
#  'Colorado Rapids',
#  'Leixoes',
#  'Stabaek IF',
#  'Hapoel Haifa',
#  'Pohang Steelers',
#  'Fredrikstad FK',
#  'FC Koln',
#  'AS Kasserine',
#  'Internacional',
#  'HB Koge',
#  'Deportivo Rayo Zuliano',
#  'Atlanta United FC',
#  'Energie Cottbus',
#  'GE Brasil Pelotas',
#  'Maritzburg Classic',
#  'Ajaccio GFCO',
#  'Brest',
#  'Latina',
#  'Bragantino',
#  'Deportivo La Guaira',
#  'Inter Miami',
#  'Peterhead',
#  'Deportivo Quito',
#  'AFC Fylde',
#  'Kalamaria',
#  'Charlotte Independence',
#  'Polokwane City',
#  ...]

# %% [markdown]
# ### Functions to gather each team statistics

# %%
def extract_team_df(team_name):
    ''' Extracts games of a specific team from whole training set.
    '''
    
    home_team_df = training_set[training_set["HT"] == team_name]
    away_team_df = training_set[training_set["AT"] == team_name]
        
    team_df = pd.concat([home_team_df, away_team_df]).sort_values(by="Date")
    
    return team_df, home_team_df, away_team_df

# %%
def get_stats(df, local=True):
    '''Fills in team statistics dictionary.
    '''
    team_stats = dict()
    if local is True:
        prefix = "home"
        goals_scored_col = "HS"
        goals_against_col = "AS"
        win, loss = "W", "L"
        goals_difference = df["GD"].sum()
        try:
            avg_goals_difference = round(df["GD"].sum() / df.shape[0], 3)
        except ZeroDivisionError:
            avg_goals_difference = np.nan
    else:
        prefix = "away"
        goals_scored_col = "AS"
        goals_against_col = "HS"
        win, loss = "L", "W"
        goals_difference = - df["GD"].sum()
        try:
            avg_goals_difference = - round(df["GD"].sum() / df.shape[0], 3)
        except ZeroDivisionError:
            avg_goals_difference = np.nan

    team_stats[f"{prefix}_games"] = df.shape[0]
    
    team_stats[f"{prefix}_wins"] = df["WDL"].value_counts().get(win, 0)
    team_stats[f"{prefix}_draws"] = df["WDL"].value_counts().get("D", 0)
    team_stats[f"{prefix}_losses"] = df["WDL"].value_counts().get(loss, 0)
    
    try:
        team_stats[f"{prefix}_win_percentage"] = round(df["WDL"].value_counts().get(win, 0) / df.shape[0], 3)
    except ZeroDivisionError:
        team_stats[f"{prefix}_win_percentage"] = np.nan
    try:
        team_stats[f"{prefix}_draw_percentage"] = round(df["WDL"].value_counts().get("D", 0) / df.shape[0], 3)
    except ZeroDivisionError:
        team_stats[f"{prefix}_draw_percentage"] = np.nan
    try:
        team_stats[f"{prefix}_loss_percentage"] = round(df["WDL"].value_counts().get(loss, 0) / df.shape[0], 3)
    except ZeroDivisionError:
        team_stats[f"{prefix}_loss_percentage"] = np.nan
    team_stats[f"{prefix}_goals_scored"] = df[goals_scored_col].sum()
    team_stats[f"{prefix}_goals_against"] = df[goals_against_col].sum()
    team_stats[f"{prefix}_goals_difference"] = goals_difference
    try:
        team_stats[f"{prefix}_avg_goals_scored"] = round(df[goals_scored_col].sum() / df.shape[0], 3)
    except ZeroDivisionError:
        team_stats[f"{prefix}_avg_goals_scored"] = np.nan
    try:
        team_stats[f"{prefix}_avg_goals_against"] = round(df[goals_against_col].sum() / df.shape[0], 3)
    except ZeroDivisionError:
        team_stats[f"{prefix}_avg_goals_against"] = np.nan
    team_stats[f"{prefix}_avg_goals_difference"] = avg_goals_difference

    return team_stats

# %% [markdown]
# ### Basic function to fill in each team dict with specific data

# %%
def complete_team_info(team_name):

    # Filter games only of specified team
    team_df, home_team_df, away_team_df = extract_team_df(team_name)
        
    # Create team dict
    team_stats = dict()

    # Recover home and away teams separately
    home_stats = get_stats(home_team_df, local=True)
    away_stats = get_stats(away_team_df, local=False)

    # Add home and away stats
    team_stats_temp = home_stats | away_stats

    # Add general stats
    team_stats["name"] = team_name
    team_stats["total_games"] = team_df.shape[0]
    team_stats["wins"] = team_stats_temp["home_wins"] + team_stats_temp["away_wins"]
    team_stats["draws"] = team_stats_temp["home_draws"] + team_stats_temp["away_draws"]
    team_stats["losses"] = team_stats_temp["home_losses"] + team_stats_temp["away_losses"]
    team_stats["win_percentage"] = round(team_stats["wins"] / team_df.shape[0], 3)
    team_stats["draw_percentage"] = round(team_stats["draws"] / team_df.shape[0], 3)
    team_stats["loss_percentage"] = round(team_stats["losses"] / team_df.shape[0], 3)
    team_stats["goals_scored"] = team_stats_temp["home_goals_scored"] + team_stats_temp["away_goals_scored"]
    team_stats["goals_against"] = team_stats_temp["home_goals_against"] + team_stats_temp["away_goals_against"]
    team_stats["goals_difference"] = team_stats["goals_scored"] - team_stats["goals_against"]
    team_stats["avg_goals_scored"] = round(team_stats["goals_scored"] / team_df.shape[0], 3)
    team_stats["avg_goals_against"] = round(team_stats["goals_against"] / team_df.shape[0], 3)
    team_stats["avg_goals_difference"] = round(team_stats["goals_difference"] / team_df.shape[0], 3)
    
    team_stats = team_stats | home_stats | away_stats
       
    return team_stats

# %% [markdown]
# ### Complete each team info

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
teams = list()

# For each team, complete its info...
for team in teams_list:
    team_stats = complete_team_info(team_name=team)
    teams.append(team_stats)

# %% [markdown]
# ### Check list with all teams dicts info isolated

# %%
teams

# with open("teams.pickle") as teams_file:
#    pickle.dump(teams, teams_file)
# Out:
# [{'name': 'Barcelona SC',
#   'total_games': 410,
#   'wins': 191,
#   'draws': 106,
#   'losses': 113,
#   'win_percentage': 0.466,
#   'draw_percentage': 0.259,
#   'loss_percentage': 0.276,
#   'goals_scored': 557,
#   'goals_against': 392,
#   'goals_difference': 165,
#   'avg_goals_scored': 1.359,
#   'avg_goals_against': 0.956,
#   'avg_goals_difference': 0.402,
#   'home_games': 205,
#   'home_wins': 124,
#   'home_draws': 47,
#   'home_losses': 34,
#   'home_win_percentage': 0.605,
#   'home_draw_percentage': 0.229,
#   'home_loss_percentage': 0.166,
#   'home_goals_scored': 346,
#   'home_goals_against': 145,
#   'home_goals_difference': 201,
#   'home_avg_goals_scored': 1.688,
#   'home_avg_goals_against': 0.707,
#   'home_avg_goals_difference': 0.98,
#   'away_games': 205,
#   'away_wins': 67,
#   'away_draws': 59,
#   'away_losses': 79,
#   'away_win_percentage': 0.327,
#   'away_draw_percentage': 0.288,
#   'away_loss_percentage': 0.385,
#   'away_goals_scored': 211,
#   'away_goals_against': 247,
#   'away_goals_difference': -36,
#   'away_avg_goals_scored': 1.029,
#   'away_avg_goals_against': 1.205,
#   'away_avg_goals_difference': -0.176},
#  {'name': 'YoungHeart Manawatu',
#   'total_games': 112,
#   'wins': 33,
#   'draws': 15,
#   'losses': 64,
#   'win_percentage': 0.295,
#   'draw_percentage': 0.134,
#   'loss_percentage': 0.571,
#   'goals_scored': 177,
#   'goals_against': 279,
#   'goals_difference': -102,
#   'avg_goals_scored': 1.58,
#   'avg_goals_against': 2.491,
#   'avg_goals_difference': -0.911,
#   'home_games': 56,
#   'home_wins': 17,
#   'home_draws': 5,
#   'home_losses': 34,
#   'home_win_percentage': 0.304,
#   'home_draw_percentage': 0.089,
#   'home_loss_percentage': 0.607,
#   'home_goals_scored': 87,
#   'home_goals_against': 139,
#   'home_goals_difference': -52,
#   'home_avg_goals_scored': 1.554,
#   'home_avg_goals_against': 2.482,
#   'home_avg_goals_difference': -0.929,
#   'away_games': 56,
#   'away_wins': 16,
#   'away_draws': 10,
#   'away_losses': 30,
#   'away_win_percentage': 0.286,
#   'away_draw_percentage': 0.179,
#   'away_loss_percentage': 0.536,
#   'away_goals_scored': 90,
#   'away_goals_against': 140,
#   'away_goals_difference': -50,
#   'away_avg_goals_scored': 1.607,
#   'away_avg_goals_against': 2.5,
#   'away_avg_goals_difference': -0.893},
#  {'name': 'Ironi Ramat HaSharon',
#   'total_games': 82,
#   'wins': 25,
#   'draws': 19,
#   'losses': 38,
#   'win_percentage': 0.305,
#   'draw_percentage': 0.232,
#   'loss_percentage': 0.463,
#   'goals_scored': 78,
#   'goals_against': 120,
#   'goals_difference': -42,
#   'avg_goals_scored': 0.951,
#   'avg_goals_against': 1.463,
#   'avg_goals_difference': -0.512,
#   'home_games': 41,
#   'home_wins': 13,
#   'home_draws': 9,
#   'home_losses': 19,
#   'home_win_percentage': 0.317,
#   'home_draw_percentage': 0.22,
#   'home_loss_percentage': 0.463,
#   'home_goals_scored': 40,
#   'home_goals_against': 54,
#   'home_goals_difference': -14,
#   'home_avg_goals_scored': 0.976,
#   'home_avg_goals_against': 1.317,
#   'home_avg_goals_difference': -0.341,
#   'away_games': 41,
#   'away_wins': 12,
#   'away_draws': 10,
#   'away_losses': 19,
#   'away_win_percentage': 0.293,
#   'away_draw_percentage': 0.244,
#   'away_loss_percentage': 0.463,
#   'away_goals_scored': 38,
#   'away_goals_against': 66,
#   'away_goals_difference': -28,
#   'away_avg_goals_scored': 0.927,
#   'away_avg_goals_against': 1.61,
#   'away_avg_goals_difference': -0.683},
#  {'name': 'Icasa',
#   'total_games': 114,
#   'wins': 40,
#   'draws': 29,
#   'losses': 45,
#   'win_percentage': 0.351,
#   'draw_percentage': 0.254,
#   'loss_percentage': 0.395,
#   'goals_scored': 136,
#   'goals_against': 152,
#   'goals_difference': -16,
#   'avg_goals_scored': 1.193,
#   'avg_goals_against': 1.333,
#   'avg_goals_difference': -0.14,
#   'home_games': 57,
#   'home_wins': 28,
#   'home_draws': 12,
#   'home_losses': 17,
#   'home_win_percentage': 0.491,
#   'home_draw_percentage': 0.211,
#   'home_loss_percentage': 0.298,
#   'home_goals_scored': 82,
#   'home_goals_against': 67,
#   'home_goals_difference': 15,
#   'home_avg_goals_scored': 1.439,
#   'home_avg_goals_against': 1.175,
#   'home_avg_goals_difference': 0.263,
#   'away_games': 57,
#   'away_wins': 12,
#   'away_draws': 17,
#   'away_losses': 28,
#   'away_win_percentage': 0.211,
#   'away_draw_percentage': 0.298,
#   'away_loss_percentage': 0.491,
#   'away_goals_scored': 54,
#   'away_goals_against': 85,
#   'away_goals_difference': -31,
#   'away_avg_goals_scored': 0.947,
#   'away_avg_goals_against': 1.491,
#   'away_avg_goals_difference': -0.544},
#  {'name': 'Albacete',
#   'total_games': 731,
#   'wins': 230,
#   'draws': 218,
#   'losses': 283,
#   'win_percentage': 0.315,
#   'draw_percentage': 0.298,
#   'loss_percentage': 0.387,
#   'goals_scored': 759,
#   'goals_against': 877,
#   'goals_difference': -118,
#   'avg_goals_scored': 1.038,
#   'avg_goals_against': 1.2,
#   'avg_goals_difference': -0.161,
#   'home_games': 365,
#   'home_wins': 143,
#   'home_draws': 115,
#   'home_losses': 107,
#   'home_win_percentage': 0.392,
#   'home_draw_percentage': 0.315,
#   'home_loss_percentage': 0.293,
#   'home_goals_scored': 422,
#   'home_goals_against': 362,
#   'home_goals_difference': 60,
#   'home_avg_goals_scored': 1.156,
#   'home_avg_goals_against': 0.992,
#   'home_avg_goals_difference': 0.164,
#   'away_games': 366,
#   'away_wins': 87,
#   'away_draws': 103,
#   'away_losses': 176,
#   'away_win_percentage': 0.238,
#   'away_draw_percentage': 0.281,
#   'away_loss_percentage': 0.481,
#   'away_goals_scored': 337,
#   'away_goals_against': 515,
#   'away_goals_difference': -178,
#   'away_avg_goals_scored': 0.921,
#   'away_avg_goals_against': 1.407,
#   'away_avg_goals_difference': -0.486},
#  {'name': 'Virtus Lanciano',
#   'total_games': 168,
#   'wins': 46,
#   'draws': 68,
#   'losses': 54,
#   'win_percentage': 0.274,
#   'draw_percentage': 0.405,
#   'loss_percentage': 0.321,
#   'goals_scored': 186,
#   'goals_against': 209,
#   'goals_difference': -23,
#   'avg_goals_scored': 1.107,
#   'avg_goals_against': 1.244,
#   'avg_goals_difference': -0.137,
#   'home_games': 84,
#   'home_wins': 31,
#   'home_draws': 33,
#   'home_losses': 20,
#   'home_win_percentage': 0.369,
#   'home_draw_percentage': 0.393,
#   'home_loss_percentage': 0.238,
#   'home_goals_scored': 102,
#   'home_goals_against': 92,
#   'home_goals_difference': 10,
#   'home_avg_goals_scored': 1.214,
#   'home_avg_goals_against': 1.095,
#   'home_avg_goals_difference': 0.119,
#   'away_games': 84,
#   'away_wins': 15,
#   'away_draws': 35,
#   'away_losses': 34,
#   'away_win_percentage': 0.179,
#   'away_draw_percentage': 0.417,
#   'away_loss_percentage': 0.405,
#   'away_goals_scored': 84,
#   'away_goals_against': 117,
#   'away_goals_difference': -33,
#   'away_avg_goals_scored': 1.0,
#   'away_avg_goals_against': 1.393,
#   'away_avg_goals_difference': -0.393},
#  {'name': 'FK Rostov',
#   'total_games': 556,
#   'wins': 179,
#   'draws': 153,
#   'losses': 224,
#   'win_percentage': 0.322,
#   'draw_percentage': 0.275,
#   'loss_percentage': 0.403,
#   'goals_scored': 614,
#   'goals_against': 725,
#   'goals_difference': -111,
#   'avg_goals_scored': 1.104,
#   'avg_goals_against': 1.304,
#   'avg_goals_difference': -0.2,
#   'home_games': 278,
#   'home_wins': 113,
#   'home_draws': 79,
#   'home_losses': 86,
#   'home_win_percentage': 0.406,
#   'home_draw_percentage': 0.284,
#   'home_loss_percentage': 0.309,
#   'home_goals_scored': 346,
#   'home_goals_against': 300,
#   'home_goals_difference': 46,
#   'home_avg_goals_scored': 1.245,
#   'home_avg_goals_against': 1.079,
#   'home_avg_goals_difference': 0.165,
#   'away_games': 278,
#   'away_wins': 66,
#   'away_draws': 74,
#   'away_losses': 138,
#   'away_win_percentage': 0.237,
#   'away_draw_percentage': 0.266,
#   'away_loss_percentage': 0.496,
#   'away_goals_scored': 268,
#   'away_goals_against': 425,
#   'away_goals_difference': -157,
#   'away_avg_goals_scored': 0.964,
#   'away_avg_goals_against': 1.529,
#   'away_avg_goals_difference': -0.565},
#  {'name': 'Napoli',
#   'total_games': 789,
#   'wins': 394,
#   'draws': 212,
#   'losses': 183,
#   'win_percentage': 0.499,
#   'draw_percentage': 0.269,
#   'loss_percentage': 0.232,
#   'goals_scored': 1297,
#   'goals_against': 839,
#   'goals_difference': 458,
#   'avg_goals_scored': 1.644,
#   'avg_goals_against': 1.063,
#   'avg_goals_difference': 0.58,
#   'home_games': 394,
#   'home_wins': 227,
#   'home_draws': 113,
#   'home_losses': 54,
#   'home_win_percentage': 0.576,
#   'home_draw_percentage': 0.287,
#   'home_loss_percentage': 0.137,
#   'home_goals_scored': 724,
#   'home_goals_against': 359,
#   'home_goals_difference': 365,
#   'home_avg_goals_scored': 1.838,
#   'home_avg_goals_against': 0.911,
#   'home_avg_goals_difference': 0.926,
#   'away_games': 395,
#   'away_wins': 167,
#   'away_draws': 99,
#   'away_losses': 129,
#   'away_win_percentage': 0.423,
#   'away_draw_percentage': 0.251,
#   'away_loss_percentage': 0.327,
#   'away_goals_scored': 573,
#   'away_goals_against': 480,
#   'away_goals_difference': 93,
#   'away_avg_goals_scored': 1.451,
#   'away_avg_goals_against': 1.215,
#   'away_avg_goals_difference': 0.235},
#  {'name': 'ES Metlaoui',
#   'total_games': 235,
#   'wins': 74,
#   'draws': 70,
#   'losses': 91,
#   'win_percentage': 0.315,
#   'draw_percentage': 0.298,
#   'loss_percentage': 0.387,
#   'goals_scored': 211,
#   'goals_against': 256,
#   'goals_difference': -45,
#   'avg_goals_scored': 0.898,
#   'avg_goals_against': 1.089,
#   'avg_goals_difference': -0.191,
#   'home_games': 118,
#   'home_wins': 58,
#   'home_draws': 29,
#   'home_losses': 31,
#   'home_win_percentage': 0.492,
#   'home_draw_percentage': 0.246,
#   'home_loss_percentage': 0.263,
#   'home_goals_scored': 127,
#   'home_goals_against': 94,
#   'home_goals_difference': 33,
#   'home_avg_goals_scored': 1.076,
#   'home_avg_goals_against': 0.797,
#   'home_avg_goals_difference': 0.28,
#   'away_games': 117,
#   'away_wins': 16,
#   'away_draws': 41,
#   'away_losses': 60,
#   'away_win_percentage': 0.137,
#   'away_draw_percentage': 0.35,
#   'away_loss_percentage': 0.513,
#   'away_goals_scored': 84,
#   'away_goals_against': 162,
#   'away_goals_difference': -78,
#   'away_avg_goals_scored': 0.718,
#   'away_avg_goals_against': 1.385,
#   'away_avg_goals_difference': -0.667},
#  {'name': 'Perugia',
#   'total_games': 484,
#   'wins': 168,
#   'draws': 157,
#   'losses': 159,
#   'win_percentage': 0.347,
#   'draw_percentage': 0.324,
#   'loss_percentage': 0.329,
#   'goals_scored': 594,
#   'goals_against': 583,
#   'goals_difference': 11,
#   'avg_goals_scored': 1.227,
#   'avg_goals_against': 1.205,
#   'avg_goals_difference': 0.023,
#   'home_games': 241,
#   'home_wins': 102,
#   'home_draws': 80,
#   'home_losses': 59,
#   'home_win_percentage': 0.423,
#   'home_draw_percentage': 0.332,
#   'home_loss_percentage': 0.245,
#   'home_goals_scored': 320,
#   'home_goals_against': 243,
#   'home_goals_difference': 77,
#   'home_avg_goals_scored': 1.328,
#   'home_avg_goals_against': 1.008,
#   'home_avg_goals_difference': 0.32,
#   'away_games': 243,
#   'away_wins': 66,
#   'away_draws': 77,
#   'away_losses': 100,
#   'away_win_percentage': 0.272,
#   'away_draw_percentage': 0.317,
#   'away_loss_percentage': 0.412,
#   'away_goals_scored': 274,
#   'away_goals_against': 340,
#   'away_goals_difference': -66,
#   'away_avg_goals_scored': 1.128,
#   'away_avg_goals_against': 1.399,
#   'away_avg_goals_difference': -0.272},
#  {'name': 'Kataller Toyama',
#   'total_games': 164,
#   'wins': 36,
#   'draws': 40,
#   'losses': 88,
#   'win_percentage': 0.22,
#   'draw_percentage': 0.244,
#   'loss_percentage': 0.537,
#   'goals_scored': 147,
#   'goals_against': 245,
#   'goals_difference': -98,
#   'avg_goals_scored': 0.896,
#   'avg_goals_against': 1.494,
#   'avg_goals_difference': -0.598,
#   'home_games': 82,
#   'home_wins': 19,
#   'home_draws': 20,
#   'home_losses': 43,
#   'home_win_percentage': 0.232,
#   'home_draw_percentage': 0.244,
#   'home_loss_percentage': 0.524,
#   'home_goals_scored': 75,
#   'home_goals_against': 121,
#   'home_goals_difference': -46,
#   'home_avg_goals_scored': 0.915,
#   'home_avg_goals_against': 1.476,
#   'home_avg_goals_difference': -0.561,
#   'away_games': 82,
#   'away_wins': 17,
#   'away_draws': 20,
#   'away_losses': 45,
#   'away_win_percentage': 0.207,
#   'away_draw_percentage': 0.244,
#   'away_loss_percentage': 0.549,
#   'away_goals_scored': 72,
#   'away_goals_against': 124,
#   'away_goals_difference': -52,
#   'away_avg_goals_scored': 0.878,
#   'away_avg_goals_against': 1.512,
#   'away_avg_goals_difference': -0.634},
#  {'name': 'Valladolid',
#   'total_games': 896,
#   'wins': 317,
#   'draws': 254,
#   'losses': 325,
#   'win_percentage': 0.354,
#   'draw_percentage': 0.283,
#   'loss_percentage': 0.363,
#   'goals_scored': 1113,
#   'goals_against': 1148,
#   'goals_difference': -35,
#   'avg_goals_scored': 1.242,
#   'avg_goals_against': 1.281,
#   'avg_goals_difference': -0.039,
#   'home_games': 448,
#   'home_wins': 200,
#   'home_draws': 132,
#   'home_losses': 116,
#   'home_win_percentage': 0.446,
#   'home_draw_percentage': 0.295,
#   'home_loss_percentage': 0.259,
#   'home_goals_scored': 607,
#   'home_goals_against': 456,
#   'home_goals_difference': 151,
#   'home_avg_goals_scored': 1.355,
#   'home_avg_goals_against': 1.018,
#   'home_avg_goals_difference': 0.337,
#   'away_games': 448,
#   'away_wins': 117,
#   'away_draws': 122,
#   'away_losses': 209,
#   'away_win_percentage': 0.261,
#   'away_draw_percentage': 0.272,
#   'away_loss_percentage': 0.467,
#   'away_goals_scored': 506,
#   'away_goals_against': 692,
#   'away_goals_difference': -186,
#   'away_avg_goals_scored': 1.129,
#   'away_avg_goals_against': 1.545,
#   'away_avg_goals_difference': -0.415},
#  {'name': 'Tianjin Teda',
#   'total_games': 482,
#   'wins': 172,
#   'draws': 156,
#   'losses': 154,
#   'win_percentage': 0.357,
#   'draw_percentage': 0.324,
#   'loss_percentage': 0.32,
#   'goals_scored': 626,
#   'goals_against': 589,
#   'goals_difference': 37,
#   'avg_goals_scored': 1.299,
#   'avg_goals_against': 1.222,
#   'avg_goals_difference': 0.077,
#   'home_games': 241,
#   'home_wins': 107,
#   'home_draws': 74,
#   'home_losses': 60,
#   'home_win_percentage': 0.444,
#   'home_draw_percentage': 0.307,
#   'home_loss_percentage': 0.249,
#   'home_goals_scored': 338,
#   'home_goals_against': 241,
#   'home_goals_difference': 97,
#   'home_avg_goals_scored': 1.402,
#   'home_avg_goals_against': 1.0,
#   'home_avg_goals_difference': 0.402,
#   'away_games': 241,
#   'away_wins': 65,
#   'away_draws': 82,
#   'away_losses': 94,
#   'away_win_percentage': 0.27,
#   'away_draw_percentage': 0.34,
#   'away_loss_percentage': 0.39,
#   'away_goals_scored': 288,
#   'away_goals_against': 348,
#   'away_goals_difference': -60,
#   'away_avg_goals_scored': 1.195,
#   'away_avg_goals_against': 1.444,
#   'away_avg_goals_difference': -0.249},
#  {'name': 'Droylsden',
#   'total_games': 46,
#   'wins': 5,
#   'draws': 9,
#   'losses': 32,
#   'win_percentage': 0.109,
#   'draw_percentage': 0.196,
#   'loss_percentage': 0.696,
#   'goals_scored': 46,
#   'goals_against': 103,
#   'goals_difference': -57,
#   'avg_goals_scored': 1.0,
#   'avg_goals_against': 2.239,
#   'avg_goals_difference': -1.239,
#   'home_games': 23,
#   'home_wins': 4,
#   'home_draws': 5,
#   'home_losses': 14,
#   'home_win_percentage': 0.174,
#   'home_draw_percentage': 0.217,
#   'home_loss_percentage': 0.609,
#   'home_goals_scored': 27,
#   'home_goals_against': 45,
#   'home_goals_difference': -18,
#   'home_avg_goals_scored': 1.174,
#   'home_avg_goals_against': 1.957,
#   'home_avg_goals_difference': -0.783,
#   'away_games': 23,
#   'away_wins': 1,
#   'away_draws': 4,
#   'away_losses': 18,
#   'away_win_percentage': 0.043,
#   'away_draw_percentage': 0.174,
#   'away_loss_percentage': 0.783,
#   'away_goals_scored': 19,
#   'away_goals_against': 58,
#   'away_goals_difference': -39,
#   'away_avg_goals_scored': 0.826,
#   'away_avg_goals_against': 2.522,
#   'away_avg_goals_difference': -1.696},
#  {'name': 'Sevilla FC B',
#   'total_games': 84,
#   'wins': 16,
#   'draws': 27,
#   'losses': 41,
#   'win_percentage': 0.19,
#   'draw_percentage': 0.321,
#   'loss_percentage': 0.488,
#   'goals_scored': 72,
#   'goals_against': 137,
#   'goals_difference': -65,
#   'avg_goals_scored': 0.857,
#   'avg_goals_against': 1.631,
#   'avg_goals_difference': -0.774,
#   'home_games': 42,
#   'home_wins': 11,
#   'home_draws': 17,
#   'home_losses': 14,
#   'home_win_percentage': 0.262,
#   'home_draw_percentage': 0.405,
#   'home_loss_percentage': 0.333,
#   'home_goals_scored': 49,
#   'home_goals_against': 60,
#   'home_goals_difference': -11,
#   'home_avg_goals_scored': 1.167,
#   'home_avg_goals_against': 1.429,
#   'home_avg_goals_difference': -0.262,
#   'away_games': 42,
#   'away_wins': 5,
#   'away_draws': 10,
#   'away_losses': 27,
#   'away_win_percentage': 0.119,
#   'away_draw_percentage': 0.238,
#   'away_loss_percentage': 0.643,
#   'away_goals_scored': 23,
#   'away_goals_against': 77,
#   'away_goals_difference': -54,
#   'away_avg_goals_scored': 0.548,
#   'away_avg_goals_against': 1.833,
#   'away_avg_goals_difference': -1.286},
#  {'name': 'Confianca',
#   'total_games': 76,
#   'wins': 21,
#   'draws': 20,
#   'losses': 35,
#   'win_percentage': 0.276,
#   'draw_percentage': 0.263,
#   'loss_percentage': 0.461,
#   'goals_scored': 73,
#   'goals_against': 94,
#   'goals_difference': -21,
#   'avg_goals_scored': 0.961,
#   'avg_goals_against': 1.237,
#   'avg_goals_difference': -0.276,
#   'home_games': 38,
#   'home_wins': 13,
#   'home_draws': 9,
#   'home_losses': 16,
#   'home_win_percentage': 0.342,
#   'home_draw_percentage': 0.237,
#   'home_loss_percentage': 0.421,
#   'home_goals_scored': 41,
#   'home_goals_against': 46,
#   'home_goals_difference': -5,
#   'home_avg_goals_scored': 1.079,
#   'home_avg_goals_against': 1.211,
#   'home_avg_goals_difference': -0.132,
#   'away_games': 38,
#   'away_wins': 8,
#   'away_draws': 11,
#   'away_losses': 19,
#   'away_win_percentage': 0.211,
#   'away_draw_percentage': 0.289,
#   'away_loss_percentage': 0.5,
#   'away_goals_scored': 32,
#   'away_goals_against': 48,
#   'away_goals_difference': -16,
#   'away_avg_goals_scored': 0.842,
#   'away_avg_goals_against': 1.263,
#   'away_avg_goals_difference': -0.421},
#  {'name': 'DRB Tadjenanet',
#   'total_games': 120,
#   'wins': 38,
#   'draws': 36,
#   'losses': 46,
#   'win_percentage': 0.317,
#   'draw_percentage': 0.3,
#   'loss_percentage': 0.383,
#   'goals_scored': 124,
#   'goals_against': 141,
#   'goals_difference': -17,
#   'avg_goals_scored': 1.033,
#   'avg_goals_against': 1.175,
#   'avg_goals_difference': -0.142,
#   'home_games': 60,
#   'home_wins': 32,
#   'home_draws': 18,
#   'home_losses': 10,
#   'home_win_percentage': 0.533,
#   'home_draw_percentage': 0.3,
#   'home_loss_percentage': 0.167,
#   'home_goals_scored': 67,
#   'home_goals_against': 36,
#   'home_goals_difference': 31,
#   'home_avg_goals_scored': 1.117,
#   'home_avg_goals_against': 0.6,
#   'home_avg_goals_difference': 0.517,
#   'away_games': 60,
#   'away_wins': 6,
#   'away_draws': 18,
#   'away_losses': 36,
#   'away_win_percentage': 0.1,
#   'away_draw_percentage': 0.3,
#   'away_loss_percentage': 0.6,
#   'away_goals_scored': 57,
#   'away_goals_against': 105,
#   'away_goals_difference': -48,
#   'away_avg_goals_scored': 0.95,
#   'away_avg_goals_against': 1.75,
#   'away_avg_goals_difference': -0.8},
#  {'name': 'Degerfors',
#   'total_games': 30,
#   'wins': 10,
#   'draws': 4,
#   'losses': 16,
#   'win_percentage': 0.333,
#   'draw_percentage': 0.133,
#   'loss_percentage': 0.533,
#   'goals_scored': 34,
#   'goals_against': 51,
#   'goals_difference': -17,
#   'avg_goals_scored': 1.133,
#   'avg_goals_against': 1.7,
#   'avg_goals_difference': -0.567,
#   'home_games': 15,
#   'home_wins': 7,
#   'home_draws': 1,
#   'home_losses': 7,
#   'home_win_percentage': 0.467,
#   'home_draw_percentage': 0.067,
#   'home_loss_percentage': 0.467,
#   'home_goals_scored': 23,
#   'home_goals_against': 22,
#   'home_goals_difference': 1,
#   'home_avg_goals_scored': 1.533,
#   'home_avg_goals_against': 1.467,
#   'home_avg_goals_difference': 0.067,
#   'away_games': 15,
#   'away_wins': 3,
#   'away_draws': 3,
#   'away_losses': 9,
#   'away_win_percentage': 0.2,
#   'away_draw_percentage': 0.2,
#   'away_loss_percentage': 0.6,
#   'away_goals_scored': 11,
#   'away_goals_against': 29,
#   'away_goals_difference': -18,
#   'away_avg_goals_scored': 0.733,
#   'away_avg_goals_against': 1.933,
#   'away_avg_goals_difference': -1.2},
#  {'name': 'FK Ural',
#   'total_games': 432,
#   'wins': 146,
#   'draws': 136,
#   'losses': 150,
#   'win_percentage': 0.338,
#   'draw_percentage': 0.315,
#   'loss_percentage': 0.347,
#   'goals_scored': 483,
#   'goals_against': 522,
#   'goals_difference': -39,
#   'avg_goals_scored': 1.118,
#   'avg_goals_against': 1.208,
#   'avg_goals_difference': -0.09,
#   'home_games': 217,
#   'home_wins': 86,
#   'home_draws': 63,
#   'home_losses': 68,
#   'home_win_percentage': 0.396,
#   'home_draw_percentage': 0.29,
#   'home_loss_percentage': 0.313,
#   'home_goals_scored': 270,
#   'home_goals_against': 240,
#   'home_goals_difference': 30,
#   'home_avg_goals_scored': 1.244,
#   'home_avg_goals_against': 1.106,
#   'home_avg_goals_difference': 0.138,
#   'away_games': 215,
#   'away_wins': 60,
#   'away_draws': 73,
#   'away_losses': 82,
#   'away_win_percentage': 0.279,
#   'away_draw_percentage': 0.34,
#   'away_loss_percentage': 0.381,
#   'away_goals_scored': 213,
#   'away_goals_against': 282,
#   'away_goals_difference': -69,
#   'away_avg_goals_scored': 0.991,
#   'away_avg_goals_against': 1.312,
#   'away_avg_goals_difference': -0.321},
#  {'name': 'Villarreal B',
#   'total_games': 152,
#   'wins': 54,
#   'draws': 36,
#   'losses': 62,
#   'win_percentage': 0.355,
#   'draw_percentage': 0.237,
#   'loss_percentage': 0.408,
#   'goals_scored': 186,
#   'goals_against': 216,
#   'goals_difference': -30,
#   'avg_goals_scored': 1.224,
#   'avg_goals_against': 1.421,
#   'avg_goals_difference': -0.197,
#   'home_games': 76,
#   'home_wins': 31,
#   'home_draws': 22,
#   'home_losses': 23,
#   'home_win_percentage': 0.408,
#   'home_draw_percentage': 0.289,
#   'home_loss_percentage': 0.303,
#   'home_goals_scored': 107,
#   'home_goals_against': 97,
#   'home_goals_difference': 10,
#   'home_avg_goals_scored': 1.408,
#   'home_avg_goals_against': 1.276,
#   'home_avg_goals_difference': 0.132,
#   'away_games': 76,
#   'away_wins': 23,
#   'away_draws': 14,
#   'away_losses': 39,
#   'away_win_percentage': 0.303,
#   'away_draw_percentage': 0.184,
#   'away_loss_percentage': 0.513,
#   'away_goals_scored': 79,
#   'away_goals_against': 119,
#   'away_goals_difference': -40,
#   'away_avg_goals_scored': 1.039,
#   'away_avg_goals_against': 1.566,
#   'away_avg_goals_difference': -0.526},
#  {'name': 'Tokushima Vortis',
#   'total_games': 488,
#   'wins': 187,
#   'draws': 124,
#   'losses': 177,
#   'win_percentage': 0.383,
#   'draw_percentage': 0.254,
#   'loss_percentage': 0.363,
#   'goals_scored': 584,
#   'goals_against': 553,
#   'goals_difference': 31,
#   'avg_goals_scored': 1.197,
#   'avg_goals_against': 1.133,
#   'avg_goals_difference': 0.064,
#   'home_games': 244,
#   'home_wins': 95,
#   'home_draws': 70,
#   'home_losses': 79,
#   'home_win_percentage': 0.389,
#   'home_draw_percentage': 0.287,
#   'home_loss_percentage': 0.324,
#   'home_goals_scored': 319,
#   'home_goals_against': 276,
#   'home_goals_difference': 43,
#   'home_avg_goals_scored': 1.307,
#   'home_avg_goals_against': 1.131,
#   'home_avg_goals_difference': 0.176,
#   'away_games': 244,
#   'away_wins': 92,
#   'away_draws': 54,
#   'away_losses': 98,
#   'away_win_percentage': 0.377,
#   'away_draw_percentage': 0.221,
#   'away_loss_percentage': 0.402,
#   'away_goals_scored': 265,
#   'away_goals_against': 277,
#   'away_goals_difference': -12,
#   'away_avg_goals_scored': 1.086,
#   'away_avg_goals_against': 1.135,
#   'away_avg_goals_difference': -0.049},
#  {'name': 'Mouloudia Oujda',
#   'total_games': 256,
#   'wins': 72,
#   'draws': 79,
#   'losses': 105,
#   'win_percentage': 0.281,
#   'draw_percentage': 0.309,
#   'loss_percentage': 0.41,
#   'goals_scored': 257,
#   'goals_against': 323,
#   'goals_difference': -66,
#   'avg_goals_scored': 1.004,
#   'avg_goals_against': 1.262,
#   'avg_goals_difference': -0.258,
#   'home_games': 126,
#   'home_wins': 47,
#   'home_draws': 45,
#   'home_losses': 34,
#   'home_win_percentage': 0.373,
#   'home_draw_percentage': 0.357,
#   'home_loss_percentage': 0.27,
#   'home_goals_scored': 149,
#   'home_goals_against': 133,
#   'home_goals_difference': 16,
#   'home_avg_goals_scored': 1.183,
#   'home_avg_goals_against': 1.056,
#   'home_avg_goals_difference': 0.127,
#   'away_games': 130,
#   'away_wins': 25,
#   'away_draws': 34,
#   'away_losses': 71,
#   'away_win_percentage': 0.192,
#   'away_draw_percentage': 0.262,
#   'away_loss_percentage': 0.546,
#   'away_goals_scored': 108,
#   'away_goals_against': 190,
#   'away_goals_difference': -82,
#   'away_avg_goals_scored': 0.831,
#   'away_avg_goals_against': 1.462,
#   'away_avg_goals_difference': -0.631},
#  {'name': 'Wolfsburg',
#   'total_games': 767,
#   'wins': 295,
#   'draws': 193,
#   'losses': 279,
#   'win_percentage': 0.385,
#   'draw_percentage': 0.252,
#   'loss_percentage': 0.364,
#   'goals_scored': 1174,
#   'goals_against': 1103,
#   'goals_difference': 71,
#   'avg_goals_scored': 1.531,
#   'avg_goals_against': 1.438,
#   'avg_goals_difference': 0.093,
#   'home_games': 383,
#   'home_wins': 181,
#   'home_draws': 99,
#   'home_losses': 103,
#   'home_win_percentage': 0.473,
#   'home_draw_percentage': 0.258,
#   'home_loss_percentage': 0.269,
#   'home_goals_scored': 684,
#   'home_goals_against': 480,
#   'home_goals_difference': 204,
#   'home_avg_goals_scored': 1.786,
#   'home_avg_goals_against': 1.253,
#   'home_avg_goals_difference': 0.533,
#   'away_games': 384,
#   'away_wins': 114,
#   'away_draws': 94,
#   'away_losses': 176,
#   'away_win_percentage': 0.297,
#   'away_draw_percentage': 0.245,
#   'away_loss_percentage': 0.458,
#   'away_goals_scored': 490,
#   'away_goals_against': 623,
#   'away_goals_difference': -133,
#   'away_avg_goals_scored': 1.276,
#   'away_avg_goals_against': 1.622,
#   'away_avg_goals_difference': -0.346},
#  {'name': 'Roasso Kumamoto',
#   'total_games': 374,
#   'wins': 112,
#   'draws': 104,
#   'losses': 158,
#   'win_percentage': 0.299,
#   'draw_percentage': 0.278,
#   'loss_percentage': 0.422,
#   'goals_scored': 382,
#   'goals_against': 499,
#   'goals_difference': -117,
#   'avg_goals_scored': 1.021,
#   'avg_goals_against': 1.334,
#   'avg_goals_difference': -0.313,
#   'home_games': 187,
#   'home_wins': 59,
#   'home_draws': 48,
#   'home_losses': 80,
#   'home_win_percentage': 0.316,
#   'home_draw_percentage': 0.257,
#   'home_loss_percentage': 0.428,
#   'home_goals_scored': 201,
#   'home_goals_against': 240,
#   'home_goals_difference': -39,
#   'home_avg_goals_scored': 1.075,
#   'home_avg_goals_against': 1.283,
#   'home_avg_goals_difference': -0.209,
#   'away_games': 187,
#   'away_wins': 53,
#   'away_draws': 56,
#   'away_losses': 78,
#   'away_win_percentage': 0.283,
#   'away_draw_percentage': 0.299,
#   'away_loss_percentage': 0.417,
#   'away_goals_scored': 181,
#   'away_goals_against': 259,
#   'away_goals_difference': -78,
#   'away_avg_goals_scored': 0.968,
#   'away_avg_goals_against': 1.385,
#   'away_avg_goals_difference': -0.417},
#  {'name': 'Nublense',
#   'total_games': 64,
#   'wins': 27,
#   'draws': 21,
#   'losses': 16,
#   'win_percentage': 0.422,
#   'draw_percentage': 0.328,
#   'loss_percentage': 0.25,
#   'goals_scored': 99,
#   'goals_against': 71,
#   'goals_difference': 28,
#   'avg_goals_scored': 1.547,
#   'avg_goals_against': 1.109,
#   'avg_goals_difference': 0.438,
#   'home_games': 32,
#   'home_wins': 17,
#   'home_draws': 9,
#   'home_losses': 6,
#   'home_win_percentage': 0.531,
#   'home_draw_percentage': 0.281,
#   'home_loss_percentage': 0.188,
#   'home_goals_scored': 60,
#   'home_goals_against': 32,
#   'home_goals_difference': 28,
#   'home_avg_goals_scored': 1.875,
#   'home_avg_goals_against': 1.0,
#   'home_avg_goals_difference': 0.875,
#   'away_games': 32,
#   'away_wins': 10,
#   'away_draws': 12,
#   'away_losses': 10,
#   'away_win_percentage': 0.312,
#   'away_draw_percentage': 0.375,
#   'away_loss_percentage': 0.312,
#   'away_goals_scored': 39,
#   'away_goals_against': 39,
#   'away_goals_difference': 0,
#   'away_avg_goals_scored': 1.219,
#   'away_avg_goals_against': 1.219,
#   'away_avg_goals_difference': -0.0},
#  {'name': 'Gainare Tottori',
#   'total_games': 122,
#   'wins': 24,
#   'draws': 28,
#   'losses': 70,
#   'win_percentage': 0.197,
#   'draw_percentage': 0.23,
#   'loss_percentage': 0.574,
#   'goals_scored': 107,
#   'goals_against': 212,
#   'goals_difference': -105,
#   'avg_goals_scored': 0.877,
#   'avg_goals_against': 1.738,
#   'avg_goals_difference': -0.861,
#   'home_games': 61,
#   'home_wins': 14,
#   'home_draws': 16,
#   'home_losses': 31,
#   'home_win_percentage': 0.23,
#   'home_draw_percentage': 0.262,
#   'home_loss_percentage': 0.508,
#   'home_goals_scored': 56,
#   'home_goals_against': 103,
#   'home_goals_difference': -47,
#   'home_avg_goals_scored': 0.918,
#   'home_avg_goals_against': 1.689,
#   'home_avg_goals_difference': -0.77,
#   'away_games': 61,
#   'away_wins': 10,
#   'away_draws': 12,
#   'away_losses': 39,
#   'away_win_percentage': 0.164,
#   'away_draw_percentage': 0.197,
#   'away_loss_percentage': 0.639,
#   'away_goals_scored': 51,
#   'away_goals_against': 109,
#   'away_goals_difference': -58,
#   'away_avg_goals_scored': 0.836,
#   'away_avg_goals_against': 1.787,
#   'away_avg_goals_difference': -0.951},
#  {'name': 'Chemnitzer FC',
#   'total_games': 304,
#   'wins': 107,
#   'draws': 79,
#   'losses': 118,
#   'win_percentage': 0.352,
#   'draw_percentage': 0.26,
#   'loss_percentage': 0.388,
#   'goals_scored': 398,
#   'goals_against': 403,
#   'goals_difference': -5,
#   'avg_goals_scored': 1.309,
#   'avg_goals_against': 1.326,
#   'avg_goals_difference': -0.016,
#   'home_games': 152,
#   'home_wins': 73,
#   'home_draws': 38,
#   'home_losses': 41,
#   'home_win_percentage': 0.48,
#   'home_draw_percentage': 0.25,
#   'home_loss_percentage': 0.27,
#   'home_goals_scored': 222,
#   'home_goals_against': 161,
#   'home_goals_difference': 61,
#   'home_avg_goals_scored': 1.461,
#   'home_avg_goals_against': 1.059,
#   'home_avg_goals_difference': 0.401,
#   'away_games': 152,
#   'away_wins': 34,
#   'away_draws': 41,
#   'away_losses': 77,
#   'away_win_percentage': 0.224,
#   'away_draw_percentage': 0.27,
#   'away_loss_percentage': 0.507,
#   'away_goals_scored': 176,
#   'away_goals_against': 242,
#   'away_goals_difference': -66,
#   'away_avg_goals_scored': 1.158,
#   'away_avg_goals_against': 1.592,
#   'away_avg_goals_difference': -0.434},
#  {'name': 'IF Elfsborg',
#   'total_games': 628,
#   'wins': 275,
#   'draws': 173,
#   'losses': 180,
#   'win_percentage': 0.438,
#   'draw_percentage': 0.275,
#   'loss_percentage': 0.287,
#   'goals_scored': 947,
#   'goals_against': 793,
#   'goals_difference': 154,
#   'avg_goals_scored': 1.508,
#   'avg_goals_against': 1.263,
#   'avg_goals_difference': 0.245,
#   'home_games': 314,
#   'home_wins': 173,
#   'home_draws': 84,
#   'home_losses': 57,
#   'home_win_percentage': 0.551,
#   'home_draw_percentage': 0.268,
#   'home_loss_percentage': 0.182,
#   'home_goals_scored': 546,
#   'home_goals_against': 299,
#   'home_goals_difference': 247,
#   'home_avg_goals_scored': 1.739,
#   'home_avg_goals_against': 0.952,
#   'home_avg_goals_difference': 0.787,
#   'away_games': 314,
#   'away_wins': 102,
#   'away_draws': 89,
#   'away_losses': 123,
#   'away_win_percentage': 0.325,
#   'away_draw_percentage': 0.283,
#   'away_loss_percentage': 0.392,
#   'away_goals_scored': 401,
#   'away_goals_against': 494,
#   'away_goals_difference': -93,
#   'away_avg_goals_scored': 1.277,
#   'away_avg_goals_against': 1.573,
#   'away_avg_goals_difference': -0.296},
#  {'name': 'Jahn Regensburg',
#   'total_games': 523,
#   'wins': 163,
#   'draws': 153,
#   'losses': 207,
#   'win_percentage': 0.312,
#   'draw_percentage': 0.293,
#   'loss_percentage': 0.396,
#   'goals_scored': 666,
#   'goals_against': 762,
#   'goals_difference': -96,
#   'avg_goals_scored': 1.273,
#   'avg_goals_against': 1.457,
#   'avg_goals_difference': -0.184,
#   'home_games': 262,
#   'home_wins': 99,
#   'home_draws': 77,
#   'home_losses': 86,
#   'home_win_percentage': 0.378,
#   'home_draw_percentage': 0.294,
#   'home_loss_percentage': 0.328,
#   'home_goals_scored': 350,
#   'home_goals_against': 340,
#   'home_goals_difference': 10,
#   'home_avg_goals_scored': 1.336,
#   'home_avg_goals_against': 1.298,
#   'home_avg_goals_difference': 0.038,
#   'away_games': 261,
#   'away_wins': 64,
#   'away_draws': 76,
#   'away_losses': 121,
#   'away_win_percentage': 0.245,
#   'away_draw_percentage': 0.291,
#   'away_loss_percentage': 0.464,
#   'away_goals_scored': 316,
#   'away_goals_against': 422,
#   'away_goals_difference': -106,
#   'away_avg_goals_scored': 1.211,
#   'away_avg_goals_against': 1.617,
#   'away_avg_goals_difference': -0.406},
#  {'name': 'Toulouse',
#   'total_games': 806,
#   'wins': 269,
#   'draws': 232,
#   'losses': 305,
#   'win_percentage': 0.334,
#   'draw_percentage': 0.288,
#   'loss_percentage': 0.378,
#   'goals_scored': 927,
#   'goals_against': 968,
#   'goals_difference': -41,
#   'avg_goals_scored': 1.15,
#   'avg_goals_against': 1.201,
#   'avg_goals_difference': -0.051,
#   'home_games': 402,
#   'home_wins': 173,
#   'home_draws': 122,
#   'home_losses': 107,
#   'home_win_percentage': 0.43,
#   'home_draw_percentage': 0.303,
#   'home_loss_percentage': 0.266,
#   'home_goals_scored': 541,
#   'home_goals_against': 400,
#   'home_goals_difference': 141,
#   'home_avg_goals_scored': 1.346,
#   'home_avg_goals_against': 0.995,
#   'home_avg_goals_difference': 0.351,
#   'away_games': 404,
#   'away_wins': 96,
#   'away_draws': 110,
#   'away_losses': 198,
#   'away_win_percentage': 0.238,
#   'away_draw_percentage': 0.272,
#   'away_loss_percentage': 0.49,
#   'away_goals_scored': 386,
#   'away_goals_against': 568,
#   'away_goals_difference': -182,
#   'away_avg_goals_scored': 0.955,
#   'away_avg_goals_against': 1.406,
#   'away_avg_goals_difference': -0.45},
#  {'name': 'Dundee United',
#   'total_games': 844,
#   'wins': 292,
#   'draws': 231,
#   'losses': 321,
#   'win_percentage': 0.346,
#   'draw_percentage': 0.274,
#   'loss_percentage': 0.38,
#   'goals_scored': 1069,
#   'goals_against': 1199,
#   'goals_difference': -130,
#   'avg_goals_scored': 1.267,
#   'avg_goals_against': 1.421,
#   'avg_goals_difference': -0.154,
#   'home_games': 422,
#   'home_wins': 172,
#   'home_draws': 115,
#   'home_losses': 135,
#   'home_win_percentage': 0.408,
#   'home_draw_percentage': 0.273,
#   'home_loss_percentage': 0.32,
#   'home_goals_scored': 586,
#   'home_goals_against': 542,
#   'home_goals_difference': 44,
#   'home_avg_goals_scored': 1.389,
#   'home_avg_goals_against': 1.284,
#   'home_avg_goals_difference': 0.104,
#   'away_games': 422,
#   'away_wins': 120,
#   'away_draws': 116,
#   'away_losses': 186,
#   'away_win_percentage': 0.284,
#   'away_draw_percentage': 0.275,
#   'away_loss_percentage': 0.441,
#   'away_goals_scored': 483,
#   'away_goals_against': 657,
#   'away_goals_difference': -174,
#   'away_avg_goals_scored': 1.145,
#   'away_avg_goals_against': 1.557,
#   'away_avg_goals_difference': -0.412},
#  {'name': 'Portland Timbers',
#   'total_games': 407,
#   'wins': 160,
#   'draws': 110,
#   'losses': 137,
#   'win_percentage': 0.393,
#   'draw_percentage': 0.27,
#   'loss_percentage': 0.337,
#   'goals_scored': 620,
#   'goals_against': 588,
#   'goals_difference': 32,
#   'avg_goals_scored': 1.523,
#   'avg_goals_against': 1.445,
#   'avg_goals_difference': 0.079,
#   'home_games': 205,
#   'home_wins': 109,
#   'home_draws': 54,
#   'home_losses': 42,
#   'home_win_percentage': 0.532,
#   'home_draw_percentage': 0.263,
#   'home_loss_percentage': 0.205,
#   'home_goals_scored': 371,
#   'home_goals_against': 241,
#   'home_goals_difference': 130,
#   'home_avg_goals_scored': 1.81,
#   'home_avg_goals_against': 1.176,
#   'home_avg_goals_difference': 0.634,
#   'away_games': 202,
#   'away_wins': 51,
#   'away_draws': 56,
#   'away_losses': 95,
#   'away_win_percentage': 0.252,
#   'away_draw_percentage': 0.277,
#   'away_loss_percentage': 0.47,
#   'away_goals_scored': 249,
#   'away_goals_against': 347,
#   'away_goals_difference': -98,
#   'away_avg_goals_scored': 1.233,
#   'away_avg_goals_against': 1.718,
#   'away_avg_goals_difference': -0.485},
#  {'name': 'Vejle',
#   'total_games': 189,
#   'wins': 36,
#   'draws': 57,
#   'losses': 96,
#   'win_percentage': 0.19,
#   'draw_percentage': 0.302,
#   'loss_percentage': 0.508,
#   'goals_scored': 198,
#   'goals_against': 347,
#   'goals_difference': -149,
#   'avg_goals_scored': 1.048,
#   'avg_goals_against': 1.836,
#   'avg_goals_difference': -0.788,
#   'home_games': 93,
#   'home_wins': 25,
#   'home_draws': 33,
#   'home_losses': 35,
#   'home_win_percentage': 0.269,
#   'home_draw_percentage': 0.355,
#   'home_loss_percentage': 0.376,
#   'home_goals_scored': 122,
#   'home_goals_against': 156,
#   'home_goals_difference': -34,
#   'home_avg_goals_scored': 1.312,
#   'home_avg_goals_against': 1.677,
#   'home_avg_goals_difference': -0.366,
#   'away_games': 96,
#   'away_wins': 11,
#   'away_draws': 24,
#   'away_losses': 61,
#   'away_win_percentage': 0.115,
#   'away_draw_percentage': 0.25,
#   'away_loss_percentage': 0.635,
#   'away_goals_scored': 76,
#   'away_goals_against': 191,
#   'away_goals_difference': -115,
#   'away_avg_goals_scored': 0.792,
#   'away_avg_goals_against': 1.99,
#   'away_avg_goals_difference': -1.198},
#  {'name': 'Macclesfield',
#   'total_games': 911,
#   'wins': 299,
#   'draws': 251,
#   'losses': 361,
#   'win_percentage': 0.328,
#   'draw_percentage': 0.276,
#   'loss_percentage': 0.396,
#   'goals_scored': 1075,
#   'goals_against': 1230,
#   'goals_difference': -155,
#   'avg_goals_scored': 1.18,
#   'avg_goals_against': 1.35,
#   'avg_goals_difference': -0.17,
#   'home_games': 455,
#   'home_wins': 174,
#   'home_draws': 137,
#   'home_losses': 144,
#   'home_win_percentage': 0.382,
#   'home_draw_percentage': 0.301,
#   'home_loss_percentage': 0.316,
#   'home_goals_scored': 572,
#   'home_goals_against': 532,
#   'home_goals_difference': 40,
#   'home_avg_goals_scored': 1.257,
#   'home_avg_goals_against': 1.169,
#   'home_avg_goals_difference': 0.088,
#   'away_games': 456,
#   'away_wins': 125,
#   'away_draws': 114,
#   'away_losses': 217,
#   'away_win_percentage': 0.274,
#   'away_draw_percentage': 0.25,
#   'away_loss_percentage': 0.476,
#   'away_goals_scored': 503,
#   'away_goals_against': 698,
#   'away_goals_difference': -195,
#   'away_avg_goals_scored': 1.103,
#   'away_avg_goals_against': 1.531,
#   'away_avg_goals_difference': -0.428},
#  {'name': 'Tampa Bay Rowdies',
#   'total_games': 366,
#   'wins': 162,
#   'draws': 96,
#   'losses': 108,
#   'win_percentage': 0.443,
#   'draw_percentage': 0.262,
#   'loss_percentage': 0.295,
#   'goals_scored': 573,
#   'goals_against': 432,
#   'goals_difference': 141,
#   'avg_goals_scored': 1.566,
#   'avg_goals_against': 1.18,
#   'avg_goals_difference': 0.385,
#   'home_games': 187,
#   'home_wins': 100,
#   'home_draws': 49,
#   'home_losses': 38,
#   'home_win_percentage': 0.535,
#   'home_draw_percentage': 0.262,
#   'home_loss_percentage': 0.203,
#   'home_goals_scored': 339,
#   'home_goals_against': 190,
#   'home_goals_difference': 149,
#   'home_avg_goals_scored': 1.813,
#   'home_avg_goals_against': 1.016,
#   'home_avg_goals_difference': 0.797,
#   'away_games': 179,
#   'away_wins': 62,
#   'away_draws': 47,
#   'away_losses': 70,
#   'away_win_percentage': 0.346,
#   'away_draw_percentage': 0.263,
#   'away_loss_percentage': 0.391,
#   'away_goals_scored': 234,
#   'away_goals_against': 242,
#   'away_goals_difference': -8,
#   'away_avg_goals_scored': 1.307,
#   'away_avg_goals_against': 1.352,
#   'away_avg_goals_difference': -0.045},
#  {'name': 'FK Khimki',
#   'total_games': 416,
#   'wins': 122,
#   'draws': 119,
#   'losses': 175,
#   'win_percentage': 0.293,
#   'draw_percentage': 0.286,
#   'loss_percentage': 0.421,
#   'goals_scored': 449,
#   'goals_against': 580,
#   'goals_difference': -131,
#   'avg_goals_scored': 1.079,
#   'avg_goals_against': 1.394,
#   'avg_goals_difference': -0.315,
#   'home_games': 208,
#   'home_wins': 83,
#   'home_draws': 62,
#   'home_losses': 63,
#   'home_win_percentage': 0.399,
#   'home_draw_percentage': 0.298,
#   'home_loss_percentage': 0.303,
#   'home_goals_scored': 261,
#   'home_goals_against': 244,
#   'home_goals_difference': 17,
#   'home_avg_goals_scored': 1.255,
#   'home_avg_goals_against': 1.173,
#   'home_avg_goals_difference': 0.082,
#   'away_games': 208,
#   'away_wins': 39,
#   'away_draws': 57,
#   'away_losses': 112,
#   'away_win_percentage': 0.188,
#   'away_draw_percentage': 0.274,
#   'away_loss_percentage': 0.538,
#   'away_goals_scored': 188,
#   'away_goals_against': 336,
#   'away_goals_difference': -148,
#   'away_avg_goals_scored': 0.904,
#   'away_avg_goals_against': 1.615,
#   'away_avg_goals_difference': -0.712},
#  {'name': 'KAC de Kenitra',
#   'total_games': 300,
#   'wins': 71,
#   'draws': 104,
#   'losses': 125,
#   'win_percentage': 0.237,
#   'draw_percentage': 0.347,
#   'loss_percentage': 0.417,
#   'goals_scored': 239,
#   'goals_against': 343,
#   'goals_difference': -104,
#   'avg_goals_scored': 0.797,
#   'avg_goals_against': 1.143,
#   'avg_goals_difference': -0.347,
#   'home_games': 150,
#   'home_wins': 47,
#   'home_draws': 60,
#   'home_losses': 43,
#   'home_win_percentage': 0.313,
#   'home_draw_percentage': 0.4,
#   'home_loss_percentage': 0.287,
#   'home_goals_scored': 146,
#   'home_goals_against': 139,
#   'home_goals_difference': 7,
#   'home_avg_goals_scored': 0.973,
#   'home_avg_goals_against': 0.927,
#   'home_avg_goals_difference': 0.047,
#   'away_games': 150,
#   'away_wins': 24,
#   'away_draws': 44,
#   'away_losses': 82,
#   'away_win_percentage': 0.16,
#   'away_draw_percentage': 0.293,
#   'away_loss_percentage': 0.547,
#   'away_goals_scored': 93,
#   'away_goals_against': 204,
#   'away_goals_difference': -111,
#   'away_avg_goals_scored': 0.62,
#   'away_avg_goals_against': 1.36,
#   'away_avg_goals_difference': -0.74},
#  {'name': 'Alloa Athletic',
#   'total_games': 763,
#   'wins': 249,
#   'draws': 194,
#   'losses': 320,
#   'win_percentage': 0.326,
#   'draw_percentage': 0.254,
#   'loss_percentage': 0.419,
#   'goals_scored': 1007,
#   'goals_against': 1200,
#   'goals_difference': -193,
#   'avg_goals_scored': 1.32,
#   'avg_goals_against': 1.573,
#   'avg_goals_difference': -0.253,
#   'home_games': 382,
#   'home_wins': 138,
#   'home_draws': 95,
#   'home_losses': 149,
#   'home_win_percentage': 0.361,
#   'home_draw_percentage': 0.249,
#   'home_loss_percentage': 0.39,
#   'home_goals_scored': 546,
#   'home_goals_against': 580,
#   'home_goals_difference': -34,
#   'home_avg_goals_scored': 1.429,
#   'home_avg_goals_against': 1.518,
#   'home_avg_goals_difference': -0.089,
#   'away_games': 381,
#   'away_wins': 111,
#   'away_draws': 99,
#   'away_losses': 171,
#   'away_win_percentage': 0.291,
#   'away_draw_percentage': 0.26,
#   'away_loss_percentage': 0.449,
#   'away_goals_scored': 461,
#   'away_goals_against': 620,
#   'away_goals_difference': -159,
#   'away_avg_goals_scored': 1.21,
#   'away_avg_goals_against': 1.627,
#   'away_avg_goals_difference': -0.417},
#  {'name': 'Coquimbo Unido',
#   'total_games': 239,
#   'wins': 69,
#   'draws': 56,
#   'losses': 114,
#   'win_percentage': 0.289,
#   'draw_percentage': 0.234,
#   'loss_percentage': 0.477,
#   'goals_scored': 276,
#   'goals_against': 375,
#   'goals_difference': -99,
#   'avg_goals_scored': 1.155,
#   'avg_goals_against': 1.569,
#   'avg_goals_difference': -0.414,
#   'home_games': 120,
#   'home_wins': 46,
#   'home_draws': 33,
#   'home_losses': 41,
#   'home_win_percentage': 0.383,
#   'home_draw_percentage': 0.275,
#   'home_loss_percentage': 0.342,
#   'home_goals_scored': 169,
#   'home_goals_against': 162,
#   'home_goals_difference': 7,
#   'home_avg_goals_scored': 1.408,
#   'home_avg_goals_against': 1.35,
#   'home_avg_goals_difference': 0.058,
#   'away_games': 119,
#   'away_wins': 23,
#   'away_draws': 23,
#   'away_losses': 73,
#   'away_win_percentage': 0.193,
#   'away_draw_percentage': 0.193,
#   'away_loss_percentage': 0.613,
#   'away_goals_scored': 107,
#   'away_goals_against': 213,
#   'away_goals_difference': -106,
#   'away_avg_goals_scored': 0.899,
#   'away_avg_goals_against': 1.79,
#   'away_avg_goals_difference': -0.891},
#  {'name': 'Penafiel',
#   'total_games': 102,
#   'wins': 20,
#   'draws': 20,
#   'losses': 62,
#   'win_percentage': 0.196,
#   'draw_percentage': 0.196,
#   'loss_percentage': 0.608,
#   'goals_scored': 89,
#   'goals_against': 183,
#   'goals_difference': -94,
#   'avg_goals_scored': 0.873,
#   'avg_goals_against': 1.794,
#   'avg_goals_difference': -0.922,
#   'home_games': 51,
#   'home_wins': 12,
#   'home_draws': 11,
#   'home_losses': 28,
#   'home_win_percentage': 0.235,
#   'home_draw_percentage': 0.216,
#   'home_loss_percentage': 0.549,
#   'home_goals_scored': 46,
#   'home_goals_against': 81,
#   'home_goals_difference': -35,
#   'home_avg_goals_scored': 0.902,
#   'home_avg_goals_against': 1.588,
#   'home_avg_goals_difference': -0.686,
#   'away_games': 51,
#   'away_wins': 8,
#   'away_draws': 9,
#   'away_losses': 34,
#   'away_win_percentage': 0.157,
#   'away_draw_percentage': 0.176,
#   'away_loss_percentage': 0.667,
#   'away_goals_scored': 43,
#   'away_goals_against': 102,
#   'away_goals_difference': -59,
#   'away_avg_goals_scored': 0.843,
#   'away_avg_goals_against': 2.0,
#   'away_avg_goals_difference': -1.157},
#  {'name': 'Dumbarton',
#   'total_games': 791,
#   'wins': 283,
#   'draws': 163,
#   'losses': 345,
#   'win_percentage': 0.358,
#   'draw_percentage': 0.206,
#   'loss_percentage': 0.436,
#   'goals_scored': 1060,
#   'goals_against': 1241,
#   'goals_difference': -181,
#   'avg_goals_scored': 1.34,
#   'avg_goals_against': 1.569,
#   'avg_goals_difference': -0.229,
#   'home_games': 394,
#   'home_wins': 161,
#   'home_draws': 85,
#   'home_losses': 148,
#   'home_win_percentage': 0.409,
#   'home_draw_percentage': 0.216,
#   'home_loss_percentage': 0.376,
#   'home_goals_scored': 565,
#   'home_goals_against': 551,
#   'home_goals_difference': 14,
#   'home_avg_goals_scored': 1.434,
#   'home_avg_goals_against': 1.398,
#   'home_avg_goals_difference': 0.036,
#   'away_games': 397,
#   'away_wins': 122,
#   'away_draws': 78,
#   'away_losses': 197,
#   'away_win_percentage': 0.307,
#   'away_draw_percentage': 0.196,
#   'away_loss_percentage': 0.496,
#   'away_goals_scored': 495,
#   'away_goals_against': 690,
#   'away_goals_difference': -195,
#   'away_avg_goals_scored': 1.247,
#   'away_avg_goals_against': 1.738,
#   'away_avg_goals_difference': -0.491},
#  {'name': 'Mainz 05 II',
#   'total_games': 114,
#   'wins': 33,
#   'draws': 31,
#   'losses': 50,
#   'win_percentage': 0.289,
#   'draw_percentage': 0.272,
#   'loss_percentage': 0.439,
#   'goals_scored': 132,
#   'goals_against': 157,
#   'goals_difference': -25,
#   'avg_goals_scored': 1.158,
#   'avg_goals_against': 1.377,
#   'avg_goals_difference': -0.219,
#   'home_games': 57,
#   'home_wins': 19,
#   'home_draws': 18,
#   'home_losses': 20,
#   'home_win_percentage': 0.333,
#   'home_draw_percentage': 0.316,
#   'home_loss_percentage': 0.351,
#   'home_goals_scored': 71,
#   'home_goals_against': 67,
#   'home_goals_difference': 4,
#   'home_avg_goals_scored': 1.246,
#   'home_avg_goals_against': 1.175,
#   'home_avg_goals_difference': 0.07,
#   'away_games': 57,
#   'away_wins': 14,
#   'away_draws': 13,
#   'away_losses': 30,
#   'away_win_percentage': 0.246,
#   'away_draw_percentage': 0.228,
#   'away_loss_percentage': 0.526,
#   'away_goals_scored': 61,
#   'away_goals_against': 90,
#   'away_goals_difference': -29,
#   'away_avg_goals_scored': 1.07,
#   'away_avg_goals_against': 1.579,
#   'away_avg_goals_difference': -0.509},
#  {'name': 'Perth Glory',
#   'total_games': 554,
#   'wins': 229,
#   'draws': 124,
#   'losses': 201,
#   'win_percentage': 0.413,
#   'draw_percentage': 0.224,
#   'loss_percentage': 0.363,
#   'goals_scored': 876,
#   'goals_against': 787,
#   'goals_difference': 89,
#   'avg_goals_scored': 1.581,
#   'avg_goals_against': 1.421,
#   'avg_goals_difference': 0.161,
#   'home_games': 276,
#   'home_wins': 146,
#   'home_draws': 58,
#   'home_losses': 72,
#   'home_win_percentage': 0.529,
#   'home_draw_percentage': 0.21,
#   'home_loss_percentage': 0.261,
#   'home_goals_scored': 500,
#   'home_goals_against': 333,
#   'home_goals_difference': 167,
#   'home_avg_goals_scored': 1.812,
#   'home_avg_goals_against': 1.207,
#   'home_avg_goals_difference': 0.605,
#   'away_games': 278,
#   'away_wins': 83,
#   'away_draws': 66,
#   'away_losses': 129,
#   'away_win_percentage': 0.299,
#   'away_draw_percentage': 0.237,
#   'away_loss_percentage': 0.464,
#   'away_goals_scored': 376,
#   'away_goals_against': 454,
#   'away_goals_difference': -78,
#   'away_avg_goals_scored': 1.353,
#   'away_avg_goals_against': 1.633,
#   'away_avg_goals_difference': -0.281},
#  {'name': 'Jokerit Helsinki',
#   'total_games': 26,
#   'wins': 7,
#   'draws': 7,
#   'losses': 12,
#   'win_percentage': 0.269,
#   'draw_percentage': 0.269,
#   'loss_percentage': 0.462,
#   'goals_scored': 29,
#   'goals_against': 37,
#   'goals_difference': -8,
#   'avg_goals_scored': 1.115,
#   'avg_goals_against': 1.423,
#   'avg_goals_difference': -0.308,
#   'home_games': 13,
#   'home_wins': 4,
#   'home_draws': 5,
#   'home_losses': 4,
#   'home_win_percentage': 0.308,
#   'home_draw_percentage': 0.385,
#   'home_loss_percentage': 0.308,
#   'home_goals_scored': 18,
#   'home_goals_against': 13,
#   'home_goals_difference': 5,
#   'home_avg_goals_scored': 1.385,
#   'home_avg_goals_against': 1.0,
#   'home_avg_goals_difference': 0.385,
#   'away_games': 13,
#   'away_wins': 3,
#   'away_draws': 2,
#   'away_losses': 8,
#   'away_win_percentage': 0.231,
#   'away_draw_percentage': 0.154,
#   'away_loss_percentage': 0.615,
#   'away_goals_scored': 11,
#   'away_goals_against': 24,
#   'away_goals_difference': -13,
#   'away_avg_goals_scored': 0.846,
# ...
#   'home_wins': 125,
#   'home_draws': 66,
#   'home_losses': 104,
#   'home_win_percentage': 0.424,
#   'home_draw_percentage': 0.224,
#   'home_loss_percentage': 0.353,
#   'home_goals_scored': 434,
#   'home_goals_against': 381,
#   'home_goals_difference': 53,
#   'home_avg_goals_scored': 1.471,
#   'home_avg_goals_against': 1.292,
#   'home_avg_goals_difference': 0.18,
#   'away_games': 295,
#   'away_wins': 63,
#   'away_draws': 84,
#   'away_losses': 148,
#   'away_win_percentage': 0.214,
#   'away_draw_percentage': 0.285,
#   'away_loss_percentage': 0.502,
#   'away_goals_scored': 272,
#   'away_goals_against': 487,
#   'away_goals_difference': -215,
#   'away_avg_goals_scored': 0.922,
#   'away_avg_goals_against': 1.651,
#   'away_avg_goals_difference': -0.729},
#  {'name': 'GE Brasil Pelotas',
#   'total_games': 228,
#   'wins': 68,
#   'draws': 67,
#   'losses': 93,
#   'win_percentage': 0.298,
#   'draw_percentage': 0.294,
#   'loss_percentage': 0.408,
#   'goals_scored': 204,
#   'goals_against': 255,
#   'goals_difference': -51,
#   'avg_goals_scored': 0.895,
#   'avg_goals_against': 1.118,
#   'avg_goals_difference': -0.224,
#   'home_games': 114,
#   'home_wins': 47,
#   'home_draws': 35,
#   'home_losses': 32,
#   'home_win_percentage': 0.412,
#   'home_draw_percentage': 0.307,
#   'home_loss_percentage': 0.281,
#   'home_goals_scored': 123,
#   'home_goals_against': 93,
#   'home_goals_difference': 30,
#   'home_avg_goals_scored': 1.079,
#   'home_avg_goals_against': 0.816,
#   'home_avg_goals_difference': 0.263,
#   'away_games': 114,
#   'away_wins': 21,
#   'away_draws': 32,
#   'away_losses': 61,
#   'away_win_percentage': 0.184,
#   'away_draw_percentage': 0.281,
#   'away_loss_percentage': 0.535,
#   'away_goals_scored': 81,
#   'away_goals_against': 162,
#   'away_goals_difference': -81,
#   'away_avg_goals_scored': 0.711,
#   'away_avg_goals_against': 1.421,
#   'away_avg_goals_difference': -0.711},
#  {'name': 'Maritzburg Classic',
#   'total_games': 60,
#   'wins': 11,
#   'draws': 18,
#   'losses': 31,
#   'win_percentage': 0.183,
#   'draw_percentage': 0.3,
#   'loss_percentage': 0.517,
#   'goals_scored': 47,
#   'goals_against': 87,
#   'goals_difference': -40,
#   'avg_goals_scored': 0.783,
#   'avg_goals_against': 1.45,
#   'avg_goals_difference': -0.667,
#   'home_games': 30,
#   'home_wins': 8,
#   'home_draws': 10,
#   'home_losses': 12,
#   'home_win_percentage': 0.267,
#   'home_draw_percentage': 0.333,
#   'home_loss_percentage': 0.4,
#   'home_goals_scored': 26,
#   'home_goals_against': 35,
#   'home_goals_difference': -9,
#   'home_avg_goals_scored': 0.867,
#   'home_avg_goals_against': 1.167,
#   'home_avg_goals_difference': -0.3,
#   'away_games': 30,
#   'away_wins': 3,
#   'away_draws': 8,
#   'away_losses': 19,
#   'away_win_percentage': 0.1,
#   'away_draw_percentage': 0.267,
#   'away_loss_percentage': 0.633,
#   'away_goals_scored': 21,
#   'away_goals_against': 52,
#   'away_goals_difference': -31,
#   'away_avg_goals_scored': 0.7,
#   'away_avg_goals_against': 1.733,
#   'away_avg_goals_difference': -1.033},
#  {'name': 'Ajaccio GFCO',
#   'total_games': 324,
#   'wins': 106,
#   'draws': 91,
#   'losses': 127,
#   'win_percentage': 0.327,
#   'draw_percentage': 0.281,
#   'loss_percentage': 0.392,
#   'goals_scored': 349,
#   'goals_against': 405,
#   'goals_difference': -56,
#   'avg_goals_scored': 1.077,
#   'avg_goals_against': 1.25,
#   'avg_goals_difference': -0.173,
#   'home_games': 163,
#   'home_wins': 69,
#   'home_draws': 48,
#   'home_losses': 46,
#   'home_win_percentage': 0.423,
#   'home_draw_percentage': 0.294,
#   'home_loss_percentage': 0.282,
#   'home_goals_scored': 198,
#   'home_goals_against': 168,
#   'home_goals_difference': 30,
#   'home_avg_goals_scored': 1.215,
#   'home_avg_goals_against': 1.031,
#   'home_avg_goals_difference': 0.184,
#   'away_games': 161,
#   'away_wins': 37,
#   'away_draws': 43,
#   'away_losses': 81,
#   'away_win_percentage': 0.23,
#   'away_draw_percentage': 0.267,
#   'away_loss_percentage': 0.503,
#   'away_goals_scored': 151,
#   'away_goals_against': 237,
#   'away_goals_difference': -86,
#   'away_avg_goals_scored': 0.938,
#   'away_avg_goals_against': 1.472,
#   'away_avg_goals_difference': -0.534},
#  {'name': 'Brest',
#   'total_games': 696,
#   'wins': 241,
#   'draws': 208,
#   'losses': 247,
#   'win_percentage': 0.346,
#   'draw_percentage': 0.299,
#   'loss_percentage': 0.355,
#   'goals_scored': 798,
#   'goals_against': 807,
#   'goals_difference': -9,
#   'avg_goals_scored': 1.147,
#   'avg_goals_against': 1.159,
#   'avg_goals_difference': -0.013,
#   'home_games': 348,
#   'home_wins': 153,
#   'home_draws': 104,
#   'home_losses': 91,
#   'home_win_percentage': 0.44,
#   'home_draw_percentage': 0.299,
#   'home_loss_percentage': 0.261,
#   'home_goals_scored': 472,
#   'home_goals_against': 352,
#   'home_goals_difference': 120,
#   'home_avg_goals_scored': 1.356,
#   'home_avg_goals_against': 1.011,
#   'home_avg_goals_difference': 0.345,
#   'away_games': 348,
#   'away_wins': 88,
#   'away_draws': 104,
#   'away_losses': 156,
#   'away_win_percentage': 0.253,
#   'away_draw_percentage': 0.299,
#   'away_loss_percentage': 0.448,
#   'away_goals_scored': 326,
#   'away_goals_against': 455,
#   'away_goals_difference': -129,
#   'away_avg_goals_scored': 0.937,
#   'away_avg_goals_against': 1.307,
#   'away_avg_goals_difference': -0.371},
#  {'name': 'Latina',
#   'total_games': 168,
#   'wins': 45,
#   'draws': 68,
#   'losses': 55,
#   'win_percentage': 0.268,
#   'draw_percentage': 0.405,
#   'loss_percentage': 0.327,
#   'goals_scored': 164,
#   'goals_against': 178,
#   'goals_difference': -14,
#   'avg_goals_scored': 0.976,
#   'avg_goals_against': 1.06,
#   'avg_goals_difference': -0.083,
#   'home_games': 84,
#   'home_wins': 29,
#   'home_draws': 31,
#   'home_losses': 24,
#   'home_win_percentage': 0.345,
#   'home_draw_percentage': 0.369,
#   'home_loss_percentage': 0.286,
#   'home_goals_scored': 89,
#   'home_goals_against': 81,
#   'home_goals_difference': 8,
#   'home_avg_goals_scored': 1.06,
#   'home_avg_goals_against': 0.964,
#   'home_avg_goals_difference': 0.095,
#   'away_games': 84,
#   'away_wins': 16,
#   'away_draws': 37,
#   'away_losses': 31,
#   'away_win_percentage': 0.19,
#   'away_draw_percentage': 0.44,
#   'away_loss_percentage': 0.369,
#   'away_goals_scored': 75,
#   'away_goals_against': 97,
#   'away_goals_difference': -22,
#   'away_avg_goals_scored': 0.893,
#   'away_avg_goals_against': 1.155,
#   'away_avg_goals_difference': -0.262},
#  {'name': 'Bragantino',
#   'total_games': 380,
#   'wins': 141,
#   'draws': 92,
#   'losses': 147,
#   'win_percentage': 0.371,
#   'draw_percentage': 0.242,
#   'loss_percentage': 0.387,
#   'goals_scored': 496,
#   'goals_against': 486,
#   'goals_difference': 10,
#   'avg_goals_scored': 1.305,
#   'avg_goals_against': 1.279,
#   'avg_goals_difference': 0.026,
#   'home_games': 190,
#   'home_wins': 92,
#   'home_draws': 50,
#   'home_losses': 48,
#   'home_win_percentage': 0.484,
#   'home_draw_percentage': 0.263,
#   'home_loss_percentage': 0.253,
#   'home_goals_scored': 294,
#   'home_goals_against': 196,
#   'home_goals_difference': 98,
#   'home_avg_goals_scored': 1.547,
#   'home_avg_goals_against': 1.032,
#   'home_avg_goals_difference': 0.516,
#   'away_games': 190,
#   'away_wins': 49,
#   'away_draws': 42,
#   'away_losses': 99,
#   'away_win_percentage': 0.258,
#   'away_draw_percentage': 0.221,
#   'away_loss_percentage': 0.521,
#   'away_goals_scored': 202,
#   'away_goals_against': 290,
#   'away_goals_difference': -88,
#   'away_avg_goals_scored': 1.063,
#   'away_avg_goals_against': 1.526,
#   'away_avg_goals_difference': -0.463},
#  {'name': 'Deportivo La Guaira',
#   'total_games': 335,
#   'wins': 141,
#   'draws': 98,
#   'losses': 96,
#   'win_percentage': 0.421,
#   'draw_percentage': 0.293,
#   'loss_percentage': 0.287,
#   'goals_scored': 463,
#   'goals_against': 354,
#   'goals_difference': 109,
#   'avg_goals_scored': 1.382,
#   'avg_goals_against': 1.057,
#   'avg_goals_difference': 0.325,
#   'home_games': 169,
#   'home_wins': 86,
#   'home_draws': 48,
#   'home_losses': 35,
#   'home_win_percentage': 0.509,
#   'home_draw_percentage': 0.284,
#   'home_loss_percentage': 0.207,
#   'home_goals_scored': 259,
#   'home_goals_against': 151,
#   'home_goals_difference': 108,
#   'home_avg_goals_scored': 1.533,
#   'home_avg_goals_against': 0.893,
#   'home_avg_goals_difference': 0.639,
#   'away_games': 166,
#   'away_wins': 55,
#   'away_draws': 50,
#   'away_losses': 61,
#   'away_win_percentage': 0.331,
#   'away_draw_percentage': 0.301,
#   'away_loss_percentage': 0.367,
#   'away_goals_scored': 204,
#   'away_goals_against': 203,
#   'away_goals_difference': 1,
#   'away_avg_goals_scored': 1.229,
#   'away_avg_goals_against': 1.223,
#   'away_avg_goals_difference': 0.006},
#  {'name': 'Inter Miami',
#   'total_games': 90,
#   'wins': 33,
#   'draws': 14,
#   'losses': 43,
#   'win_percentage': 0.367,
#   'draw_percentage': 0.156,
#   'loss_percentage': 0.478,
#   'goals_scored': 106,
#   'goals_against': 145,
#   'goals_difference': -39,
#   'avg_goals_scored': 1.178,
#   'avg_goals_against': 1.611,
#   'avg_goals_difference': -0.433,
#   'home_games': 43,
#   'home_wins': 22,
#   'home_draws': 7,
#   'home_losses': 14,
#   'home_win_percentage': 0.512,
#   'home_draw_percentage': 0.163,
#   'home_loss_percentage': 0.326,
#   'home_goals_scored': 74,
#   'home_goals_against': 76,
#   'home_goals_difference': -2,
#   'home_avg_goals_scored': 1.721,
#   'home_avg_goals_against': 1.767,
#   'home_avg_goals_difference': -0.047,
#   'away_games': 47,
#   'away_wins': 11,
#   'away_draws': 7,
#   'away_losses': 29,
#   'away_win_percentage': 0.234,
#   'away_draw_percentage': 0.149,
#   'away_loss_percentage': 0.617,
#   'away_goals_scored': 32,
#   'away_goals_against': 69,
#   'away_goals_difference': -37,
#   'away_avg_goals_scored': 0.681,
#   'away_avg_goals_against': 1.468,
#   'away_avg_goals_difference': -0.787},
#  {'name': 'Peterhead',
#   'total_games': 757,
#   'wins': 327,
#   'draws': 165,
#   'losses': 265,
#   'win_percentage': 0.432,
#   'draw_percentage': 0.218,
#   'loss_percentage': 0.35,
#   'goals_scored': 1206,
#   'goals_against': 1009,
#   'goals_difference': 197,
#   'avg_goals_scored': 1.593,
#   'avg_goals_against': 1.333,
#   'avg_goals_difference': 0.26,
#   'home_games': 379,
#   'home_wins': 181,
#   'home_draws': 95,
#   'home_losses': 103,
#   'home_win_percentage': 0.478,
#   'home_draw_percentage': 0.251,
#   'home_loss_percentage': 0.272,
#   'home_goals_scored': 647,
#   'home_goals_against': 426,
#   'home_goals_difference': 221,
#   'home_avg_goals_scored': 1.707,
#   'home_avg_goals_against': 1.124,
#   'home_avg_goals_difference': 0.583,
#   'away_games': 378,
#   'away_wins': 146,
#   'away_draws': 70,
#   'away_losses': 162,
#   'away_win_percentage': 0.386,
#   'away_draw_percentage': 0.185,
#   'away_loss_percentage': 0.429,
#   'away_goals_scored': 559,
#   'away_goals_against': 583,
#   'away_goals_difference': -24,
#   'away_avg_goals_scored': 1.479,
#   'away_avg_goals_against': 1.542,
#   'away_avg_goals_difference': -0.063},
#  {'name': 'Deportivo Quito',
#   'total_games': 366,
#   'wins': 145,
#   'draws': 97,
#   'losses': 124,
#   'win_percentage': 0.396,
#   'draw_percentage': 0.265,
#   'loss_percentage': 0.339,
#   'goals_scored': 458,
#   'goals_against': 410,
#   'goals_difference': 48,
#   'avg_goals_scored': 1.251,
#   'avg_goals_against': 1.12,
#   'avg_goals_difference': 0.131,
#   'home_games': 183,
#   'home_wins': 94,
#   'home_draws': 48,
#   'home_losses': 41,
#   'home_win_percentage': 0.514,
#   'home_draw_percentage': 0.262,
#   'home_loss_percentage': 0.224,
#   'home_goals_scored': 280,
#   'home_goals_against': 170,
#   'home_goals_difference': 110,
#   'home_avg_goals_scored': 1.53,
#   'home_avg_goals_against': 0.929,
#   'home_avg_goals_difference': 0.601,
#   'away_games': 183,
#   'away_wins': 51,
#   'away_draws': 49,
#   'away_losses': 83,
#   'away_win_percentage': 0.279,
#   'away_draw_percentage': 0.268,
#   'away_loss_percentage': 0.454,
#   'away_goals_scored': 178,
#   'away_goals_against': 240,
#   'away_goals_difference': -62,
#   'away_avg_goals_scored': 0.973,
#   'away_avg_goals_against': 1.311,
#   'away_avg_goals_difference': -0.339},
#  {'name': 'AFC Fylde',
#   'total_games': 129,
#   'wins': 51,
#   'draws': 40,
#   'losses': 38,
#   'win_percentage': 0.395,
#   'draw_percentage': 0.31,
#   'loss_percentage': 0.295,
#   'goals_scored': 198,
#   'goals_against': 157,
#   'goals_difference': 41,
#   'avg_goals_scored': 1.535,
#   'avg_goals_against': 1.217,
#   'avg_goals_difference': 0.318,
#   'home_games': 65,
#   'home_wins': 31,
#   'home_draws': 19,
#   'home_losses': 15,
#   'home_win_percentage': 0.477,
#   'home_draw_percentage': 0.292,
#   'home_loss_percentage': 0.231,
#   'home_goals_scored': 116,
#   'home_goals_against': 74,
#   'home_goals_difference': 42,
#   'home_avg_goals_scored': 1.785,
#   'home_avg_goals_against': 1.138,
#   'home_avg_goals_difference': 0.646,
#   'away_games': 64,
#   'away_wins': 20,
#   'away_draws': 21,
#   'away_losses': 23,
#   'away_win_percentage': 0.312,
#   'away_draw_percentage': 0.328,
#   'away_loss_percentage': 0.359,
#   'away_goals_scored': 82,
#   'away_goals_against': 83,
#   'away_goals_difference': -1,
#   'away_avg_goals_scored': 1.281,
#   'away_avg_goals_against': 1.297,
#   'away_avg_goals_difference': -0.016},
#  {'name': 'Kalamaria',
#   'total_games': 120,
#   'wins': 33,
#   'draws': 33,
#   'losses': 54,
#   'win_percentage': 0.275,
#   'draw_percentage': 0.275,
#   'loss_percentage': 0.45,
#   'goals_scored': 118,
#   'goals_against': 175,
#   'goals_difference': -57,
#   'avg_goals_scored': 0.983,
#   'avg_goals_against': 1.458,
#   'avg_goals_difference': -0.475,
#   'home_games': 60,
#   'home_wins': 22,
#   'home_draws': 19,
#   'home_losses': 19,
#   'home_win_percentage': 0.367,
#   'home_draw_percentage': 0.317,
#   'home_loss_percentage': 0.317,
#   'home_goals_scored': 65,
#   'home_goals_against': 61,
#   'home_goals_difference': 4,
#   'home_avg_goals_scored': 1.083,
#   'home_avg_goals_against': 1.017,
#   'home_avg_goals_difference': 0.067,
#   'away_games': 60,
#   'away_wins': 11,
#   'away_draws': 14,
#   'away_losses': 35,
#   'away_win_percentage': 0.183,
#   'away_draw_percentage': 0.233,
#   'away_loss_percentage': 0.583,
#   'away_goals_scored': 53,
#   'away_goals_against': 114,
#   'away_goals_difference': -61,
#   'away_avg_goals_scored': 0.883,
#   'away_avg_goals_against': 1.9,
#   'away_avg_goals_difference': -1.017},
#  {'name': 'Charlotte Independence',
#   'total_games': 152,
#   'wins': 59,
#   'draws': 41,
#   'losses': 52,
#   'win_percentage': 0.388,
#   'draw_percentage': 0.27,
#   'loss_percentage': 0.342,
#   'goals_scored': 224,
#   'goals_against': 214,
#   'goals_difference': 10,
#   'avg_goals_scored': 1.474,
#   'avg_goals_against': 1.408,
#   'avg_goals_difference': 0.066,
#   'home_games': 77,
#   'home_wins': 37,
#   'home_draws': 20,
#   'home_losses': 20,
#   'home_win_percentage': 0.481,
#   'home_draw_percentage': 0.26,
#   'home_loss_percentage': 0.26,
#   'home_goals_scored': 131,
#   'home_goals_against': 97,
#   'home_goals_difference': 34,
#   'home_avg_goals_scored': 1.701,
#   'home_avg_goals_against': 1.26,
#   'home_avg_goals_difference': 0.442,
#   'away_games': 75,
#   'away_wins': 22,
#   'away_draws': 21,
#   'away_losses': 32,
#   'away_win_percentage': 0.293,
#   'away_draw_percentage': 0.28,
#   'away_loss_percentage': 0.427,
#   'away_goals_scored': 93,
#   'away_goals_against': 117,
#   'away_goals_difference': -24,
#   'away_avg_goals_scored': 1.24,
#   'away_avg_goals_against': 1.56,
#   'away_avg_goals_difference': -0.32},
#  {'name': 'Polokwane City',
#   'total_games': 239,
#   'wins': 62,
#   'draws': 73,
#   'losses': 104,
#   'win_percentage': 0.259,
#   'draw_percentage': 0.305,
#   'loss_percentage': 0.435,
#   'goals_scored': 259,
#   'goals_against': 349,
#   'goals_difference': -90,
#   'avg_goals_scored': 1.084,
#   'avg_goals_against': 1.46,
#   'avg_goals_difference': -0.377,
#   'home_games': 119,
#   'home_wins': 39,
#   'home_draws': 37,
#   'home_losses': 43,
#   'home_win_percentage': 0.328,
#   'home_draw_percentage': 0.311,
#   'home_loss_percentage': 0.361,
#   'home_goals_scored': 146,
#   'home_goals_against': 155,
#   'home_goals_difference': -9,
#   'home_avg_goals_scored': 1.227,
#   'home_avg_goals_against': 1.303,
#   'home_avg_goals_difference': -0.076,
#   'away_games': 120,
#   'away_wins': 23,
#   'away_draws': 36,
#   'away_losses': 61,
#   'away_win_percentage': 0.192,
#   'away_draw_percentage': 0.3,
#   'away_loss_percentage': 0.508,
#   'away_goals_scored': 113,
#   'away_goals_against': 194,
#   'away_goals_difference': -81,
#   'away_avg_goals_scored': 0.942,
#   'away_avg_goals_against': 1.617,
#   'away_avg_goals_difference': -0.675},
#  ...]

# %% [markdown]
# ### Function to search H2H games (team1 vs team2)

# %%
def search_H2H(team1, team2):
    
    condition_a = ((training_set["HT"] == team1) & (training_set["AT"] == team2))
    condition_b = ((training_set["HT"] == team2) & (training_set["AT"] == team1))
    
    h2h = training_set.loc[condition_a | condition_b]
    
    return h2h

# %%
search_H2H("Real Madrid", "Eibar")
# Out:
#           Sea   Lge       Date           HT           AT  HS  AS  GD WDL  \
# 174450  14-15  SPA1 2014-11-22        Eibar  Real Madrid   0   4  -4   L
# 174640  14-15  SPA1 2015-04-11  Real Madrid        Eibar   3   0   3   W
# 189935  15-16  SPA1 2015-11-29        Eibar  Real Madrid   0   2  -2   L
# 190122  15-16  SPA1 2016-04-09  Real Madrid        Eibar   4   0   4   W
# 212361  16-17  SPA1 2016-10-02  Real Madrid        Eibar   1   1   0   D
# 212545  16-17  SPA1 2017-03-04        Eibar  Real Madrid   1   4  -3   L
# 219409  17-18  SPA1 2017-10-22  Real Madrid        Eibar   3   0   3   W
# 219593  17-18  SPA1 2018-03-10        Eibar  Real Madrid   1   2  -1   L
# 224852  18-19  SPA1 2018-11-24        Eibar  Real Madrid   3   0   3   W
# 225032  18-19  SPA1 2019-04-06  Real Madrid        Eibar   2   1   1   W
# 230296  19-20  SPA1 2019-11-09        Eibar  Real Madrid   0   4  -4   L
# 230451  19-20  SPA1 2020-06-14  Real Madrid        Eibar   3   1   2   W
# 236090  20-21  SPA1 2020-12-20        Eibar  Real Madrid   1   3  -2   L
# 236238  20-21  SPA1 2021-04-03  Real Madrid        Eibar   2   0   2   W
#
#         Goals
# 174450      4
# 174640      3
# 189935      2
# 190122      4
# 212361      2
# 212545      5
# 219409      3
# 219593      3
# 224852      3
# 225032      3
# 230296      4
# 230451      4
# 236090      4
# 236238      2

# %% [markdown]
# ### Function to get last N games of specific team

# %%
def get_last_matches(team_name, n_previous_matches):

    team_df, _, _= extract_team_df(team_name)
    last_n_games_df = team_df[-n_previous_matches:]

    return last_n_games_df

# %%
get_last_matches("Real Madrid", 900)
# Out:
#           Sea   Lge       Date               HT               AT  HS  AS  GD  \
# 4104    00-01  SPA1 2000-09-09      Real Madrid         Valencia   2   1   1
# 4113    00-01  SPA1 2000-09-16           Malaga      Real Madrid   3   3   0
# 4124    00-01  SPA1 2000-09-23      Real Madrid  Athletic Bilbao   4   1   3
# 4132    00-01  SPA1 2000-09-30        Santander      Real Madrid   0   0   0
# 4143    00-01  SPA1 2000-10-14      Real Madrid        La Coruna   3   0   3
# ...       ...   ...        ...              ...              ...  ..  ..  ..
# 298599  22-23  SPA1 2023-01-07       Villarreal      Real Madrid   2   1   1
# 298623  22-23  SPA1 2023-01-22  Athletic Bilbao      Real Madrid   0   2  -2
# 298633  22-23  SPA1 2023-01-29      Real Madrid    Real Sociedad   0   0   0
# 298636  22-23  SPA1 2023-02-02      Real Madrid         Valencia   2   0   2
# 298642  22-23  SPA1 2023-02-05         Mallorca      Real Madrid   1   0   1
#
#        WDL  Goals
# 4104     W      3
# 4113     D      6
# 4124     W      5
# 4132     D      0
# 4143     W      3
# ...     ..    ...
# 298599   W      3
# 298623   L      2
# 298633   D      0
# 298636   W      2
# 298642   W      1
#
# [856 rows x 10 columns]

# %% [markdown]
# ------------------

# %% [markdown]
# ### **Load teams file from pickle**

# %%
with open("teams.pickle", "rb") as teams_file:
    teams = pickle.load(teams_file)
