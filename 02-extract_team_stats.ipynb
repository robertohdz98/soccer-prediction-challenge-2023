# %% [markdown]
# # 02. Extract team statistics

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load processed training dataset

# %%
training_set = pd.read_parquet("datasets/processed/training_set_processed.parquet")

# %% [markdown]
# ### Extract all teams in training set

# %%
home_teams_list = training_set["HT"].unique().tolist()
away_teams_list = training_set["AT"].unique().tolist()
teams_list = list(set(home_teams_list + away_teams_list))
print("Number of teams in training set:",len(teams_list))
# Out:
# Number of teams in training set: 1637

# %%
teams_list
# Out:
# ['Assyriska',
#  'Sagamihara',
#  'Halmstads BK',
#  'Espanyol Barcelona',
#  'Kuban Krasnodar',
#  'Ponte Preta',
#  'Forfar Athletic',
#  'Vallecano',
#  'Yaracuyanos FC',
#  'Zenit St Petersburg',
#  'FC Thun',
#  'TSV Hartberg',
#  'Werder Bremen',
#  'Olympique Marseille',
#  'FC Lugano',
#  'Brisbane Roar',
#  'Chengdu Blades',
#  'Atletico Celaya',
#  'Sanfrecce',
#  'Strasbourg',
#  'Celta de Vigo',
#  'Detroit City FC',
#  'AS Lyon-Duchere',
#  'Grimsby',
#  'Dordrecht',
#  'Sandefjord Fotball',
#  'Gyeongnam FC',
#  'Gillingham',
#  'Viktoria Koln',
#  'Venezia',
#  'Lobos',
#  'SCR Altach',
#  'CD Provincial Osorno',
#  'Blaublitz',
#  'Rochester Rhinos',
#  'Pacos Ferreira',
#  'Neuchatel Xamax',
#  'Cordoba',
#  'USM Bel Abbes',
#  'Universidad Central FC',
#  'Eastern Pride',
#  'FC Basel',
#  'Queensland Roar',
#  'YoungHeart Manawatu',
#  'Sheffield Wednesday',
#  'Manchester City',
#  'Pontevedra',
#  'Tacoma Defiance',
#  'Maritzburg United',
#  'HJK Helsinki',
#  'Bath City',
#  'Mainz 05 II',
#  'Chiapas FC',
#  'Wolverhampton',
#  'Nizhny Novgorod',
#  'New England Revolution',
#  'Cape Town City FC',
#  'Bragantino',
#  'Nancy',
#  'Fakel Voronezh',
#  'Stabia',
#  'Xanthi',
#  'Changchun Yatai',
#  'San Lorenzo',
#  'FC Aarau',
#  'Union La Calera',
#  'Club Tijuana',
#  'Fuerza Amarilla Machala',
#  'ADO Den Haag',
#  'FC Superfund',
#  'Leonesa',
#  'Sochi',
#  'Aris',
#  'Liverpool',
#  'Barnsley',
#  'Oostende',
#  'Vendee Lucon',
#  'Melbourne City FC',
#  'Tigre',
#  'SO Cholet',
#  'FC Kobenhavn',
#  'Northampton Town',
#  'Nosta Novotroitsk',
#  'Falkenbergs',
#  'Blackpool',
#  'Stuttgarter Kickers',
#  'Walsall',
#  'Carl Zeiss Jena',
#  'Valencia',
#  'Lubeck',
#  'Changsha Ginde',
#  'SC Imbabura',
#  'Alfreton Town',
#  'Wycombe Wanderers',
#  'Chesterfield',
#  'Khenchela',
#  'Hapoel Rishon',
#  'AZ Alkmaar',
#  'Yiannina',
#  'Hebei China Fortune FC',
#  'FC Cincinnati',
#  'Palermo',
#  'Leeds United',
#  'Heracles',
#  'RW Erfurt',
#  'Waasland-Beveren',
#  'Entente SSG',
#  'Lommel',
#  'MC Alger',
#  'WaiBOP United',
#  'Biskra',
#  'Dumbarton',
#  'Eupen',
#  'Austin Bold',
#  'Sokol Saratov',
#  'Bradford',
#  'Elche',
#  'MC El Eulma',
#  'Molenbeek',
#  'Jiangsu Suning',
#  'Kemi Kings',
#  'Deportes Temuco',
#  'AS Cherbourg',
#  'Catanzaro',
#  'USM Blida',
#  'Highlands Park',
#  'Panathinaikos',
#  'East Stirling',
#  'Adelaide United',
#  'Cove Rangers',
#  'Santos Laguna',
#  'Las Vegas Lights FC',
#  'Salisbury',
#  'Club Africain',
#  'SR Colmar',
#  'FK Amkar Perm',
#  'Sedan',
#  'Atlanta United FC',
#  'NEC Nijmegen',
#  'Vastra Frolunda',
#  'Kataller Toyama',
#  'Bari 1908',
#  'Union Espanola',
#  'Charlotte FC',
#  'Hamburger SV',
#  'Charlotte Independence',
#  'Ceara SC',
#  'Vestsjalland',
#  'Zhejiang Yiteng',
#  'Tombense - MG',
#  'Chunnam Dragons',
#  'Jeonnam Dragons',
#  'Ostersunds FK',
#  'Real Madrid',
#  'Malaga',
#  'SKA-Energia Khabarovsk',
#  'Ironi Ramat HaSharon',
#  'Auxerre',
#  'Seinajoki',
#  'JS Kasba Tadla',
#  'Crawley Town',
#  'Istres',
#  'Andorra',
#  'Wasquehal',
#  'Sabadell',
#  'Southampton',
#  'Paradou AC',
#  'Torpedo Moscow',
#  'Avispa',
#  'Fredrikstad FK',
#  'RC Strasbourg',
#  'Asteras Tripolis',
#  'Stade de Reims',
#  'FC Orenburg',
#  'CD Veracruz',
#  'Atletico Clube Goianiense',
#  'FC Honka',
#  'Oulu',
#  'Lokomotiv Moscow',
#  'Renaissance de Berkane',
#  'Leones Negros',
#  'Raith Rovers',
#  'Erzgebirge Aue',
#  'America MG',
#  'Hapoel Petach-Tikva',
#  'Esperance Zarzis',
#  'AC Ajaccio',
#  'Tampere United',
#  'Espoli',
#  'Ajaccio GFCO',
#  'Mamelodi Sundowns',
#  'Chemnitzer FC',
#  'Reutlingen',
#  'Wanderers SC',
#  'Monterey Bay FC',
#  'Guimaraes',
#  'Hertha Berlin',
#  'Brighton',
#  'Como',
#  'AS Djerba',
#  'JEF United',
#  'Sporting Lyon',
#  'Tampa Bay Rowdies',
#  'Maccabi Petach-Tikva',
#  'Minnesota',
#  'Shijiazhuang Ever Bright',
#  'Maidenhead United',
#  'Ittihad Tanger',
#  'Atletico El Vigia',
#  'Lens',
#  'Deportivo Lara',
#  'Syrianska FC',
#  'Sarmiento de Junin',
#  'Drancy',
#  'Pohang Steelers',
#  'Mechelen',
#  'York City',
#  'Apollon',
#  'Thespakusatsu',
#  'Jaguares Chiapas',
#  'Ionikos',
#  'JS Kabylie',
#  'Algeciras',
#  'FK Zhemchuzhina',
#  'FC Schaffhausen',
#  'Annan Athletic',
#  'Dender',
#  'Rosenborg Trondheim',
#  'Bourg Peronnas',
#  'Elversberg',
#  'Genk',
#  'Sturm Graz',
#  'Montrose',
#  'Wuhan Optics Valley',
#  'Parana Clube',
#  'Sporting Kansas City 2',
#  'Stockport',
#  'Napoli',
#  'Qingdao',
#  'Terrassa',
#  'Coventry City',
#  'GAIS Goteborg',
#  'Newport County',
#  'Augsburg',
#  'Velez Sarsfield',
#  'FC Pau',
#  'FC Sudtirol',
#  'Estudiantes Tecos',
#  'Mogi Mirim',
#  'RB Salzburg',
#  'Accrington',
#  'Reggiana',
#  'Standard',
#  'Akron',
#  'Ergotelis',
#  'Soliman',
#  'Fuenlabrada',
#  'Manta FC',
#  'VfB Stuttgart II',
#  'San Jose Earthquakes',
#  'Defensa y Justicia',
#  'Sydney United Pumas',
#  'Kalamata',
#  'Burgos',
#  'Red Star',
#  'Alemannia Aachen',
#  'WA Tlemcen',
#  'Kidderminster',
#  'Hapoel Ramat Gan',
#  'Youssoufia Berrechid',
#  'Platinum Stars',
#  'Gap FC',
#  'Tuks FC',
#  'Aviron Bayonnais',
#  'Incheon United',
#  'Beijing Hyundai',
#  'Olympique de Khouribga',
#  'FC Sion',
#  'Roosendaal',
#  'Feyenoord Rotterdam',
#  'Millwall',
#  'Arouca',
#  'Real Sociedad',
#  'Stranraer',
#  'Rubin Kazan',
#  'Krylia Sovetov',
#  'CR Belouizdad',
#  'Sarpsborg 08',
#  'Varese',
#  'Salford City',
#  'JS Kairouan',
#  'ESTAC Troyes',
#  'Rouen',
#  'Icasa',
#  'ABC FC',
#  'CA San Martin',
#  'Marignane Gignac',
#  'Eastbourne Borough',
#  'Llagostera',
#  'Atletico Paranaense',
#  'Chabab Atlas Khenifra',
#  'Vicenza',
#  'Perugia',
#  'Hassania US Agadir',
#  'FC Barcelona B',
#  'Canterbury United',
#  'Crystal Palace',
#  'FC Barcelona',
#  'Brann Bergen',
#  'Dalian Haichang',
#  'Freiburg',
#  'Colorado Rapids',
#  'HB Koge',
#  'Xiamen Xiaxin',
#  'GyE Jujuy',
#  'Xiamen Lanshi',
#  'IK Start',
#  'Halifax',
#  'Zaragoza',
#  'Exeter City',
#  'TP47 Tornio',
#  'FC Innsbruck',
#  'D.C. United',
#  'Osasuna',
#  'Ittihad Khemisset',
#  'Gremio Prudente',
#  'Arminia Bielefeld',
#  'Grazer AK',
#  'Frem Kobenhavn',
#  'Perth Glory',
#  'Kickers Offenbach',
#  'Orgryte IS',
#  'Bloemfontein Celtic',
#  'Scarborough',
#  'Carpi',
#  'Sao Paulo FC',
#  'Atletico Venezuela',
#  'Moreirense',
#  'Hawkes Bay United FC',
#  'Otago United',
#  'Rotor Volgograd',
#  'Mouscron',
#  'Huracan',
#  'Karlsruher SC',
#  'Marconi-Fairfield Stallions',
#  'Rio Grande Valley FC',
#  'Santos FC',
#  'Munich 1860',
#  'Waalwijk',
#  'EO Sidi Bouzid',
#  'Richmond Kickers',
#  'Boston',
#  'Santander',
#  'Hyeres FC',
#  'CD Chivas',
#  'Luverdense',
#  'Deportivo Italia',
#  'Daejeon Citizen',
#  'Santo Andre Esporte Clube',
#  'St Albans',
#  'Wollongong City Wolves',
#  'USM Alger',
#  'Delemont',
#  'Willem II',
#  'Auckland City FC',
#  'Rodina Moskva',
#  'GIF Sundsvall',
#  'Rosario Central',
#  'Iraklis',
#  'Ancona 1905',
#  'FK Tom Tomsk',
#  'Louhans-Cuiseaux',
#  'Herfolge',
#  'CF Monterrey',
#  'Montedio Yamagata',
#  'Brentford',
#  'Kapfenberger SV',
#  'Farsley',
#  'Las Palmas',
#  'Genoa',
#  'Nueva Chicago',
#  'Chester',
#  'Greuther Furth',
#  'Esbjerg fB',
#  'Higgins',
#  'Guangzhou Evergrande',
#  'Cowdenbeath',
#  'Groningen',
#  'Joinville Esporte Clube',
#  'Vitesse',
#  'Salamanca',
#  'US Boulogne',
#  'AS Ain Mlila',
#  'Lierse',
#  'Girona',
#  'Team Wellington',
#  'RW Essen',
#  'NA Hussein Dey',
#  'Gallos Blancos Queretaro FC',
#  'UJA Alfortville',
#  'Cannes',
#  'Burton',
#  'Vancouver Whitecaps 2',
#  'Bnei Yehuda Tel Aviv',
#  'Portogruaro',
#  'Nashville SC',
#  'Nuneaton Town',
#  'Torino',
#  'Llaneros de Guanare',
#  'Atromitos',
#  'Dortmund II',
#  'Brechin City',
#  'Swansea City',
#  'Mineros de Guayana',
#  'Kortrijk',
#  'Toulouse',
#  'Hamilton Academical',
#  'Gubbio',
#  'Sevilla FC B',
#  'Valladolid',
#  'Verl',
#  'Monagas',
#  'Lille',
#  'Guingamp',
#  'Libourne',
#  'FC Versailles',
#  'AFC Wimbledon',
#  'Tupi FC',
#  'Granada',
#  'CR Vasco da Gama',
#  'Lorca',
#  'Rennes',
#  'Athletic Bilbao B',
#  'Paris Saint-Germain',
#  'Sportfreunde Lotte',
#  'Vecindario',
#  'Grays',
#  'August First Football Team',
#  'Magra',
#  'CR Al Hoceima',
#  'Austin FC',
#  'FC Gifu',
#  'Kaizer Chiefs',
#  'Olympique Beja',
#  'Almeria',
#  'Lokeren',
#  'USM El Harrach',
#  'Arsenal',
#  'Guaratingueta',
#  'FSV Frankfurt',
#  'Young Boys',
#  'Benfica',
#  'Dagenham and Redbridge',
#  'Arsenal Tula',
#  'Estoril',
#  'Skikda',
#  'Panetolikos',
#  'Stirling Albion',
#  'Atletico Rafaela',
#  'All Boys',
#  'New York Red Bulls',
#  'DRB Tadjenanet',
#  'Canvey Island',
#  'AFC Fylde',
#  'Scunthorpe United',
#  'JS Saoura',
#  'FK Chita',
#  'Orense',
#  'Cheltenham',
#  'Schweinfurt',
#  'Volga Nizhniy Novgorod',
#  'Viktoria Berlin',
#  'Sichuan Guancheng',
#  'Greenock Morton',
#  'CD Clan Juvenil',
#  'Brusque - SC',
#  'Dunfermline Athletic',
#  'Vannes OC',
#  'Unterhaching',
#  'Nimes Olympique',
#  'Parramatta Power',
#  'Ranheim IL',
#  'Uerdingen',
#  'Figueirense',
#  'Gremio Barueri',
#  'FAR de Rabat',
#  'Panthrakikos',
#  'Nurnberg',
#  'CF Atlante',
#  'US Monastir',
#  'Hyde United',
#  'Hercules',
#  'EGS Gafsa',
#  'CA Batna',
#  'AS Marsa',
#  'Deportivo Quevedo',
#  'Randers FC',
#  'Holstein Kiel',
#  'Lokomotiv Nizhni Novgorod',
#  'Bolton',
#  'Sassuolo',
#  'Zweigen',
#  'Anjalankoski',
#  'Silver Stars',
#  'FC Wil',
#  'Lyngby',
#  'Burnley',
#  'Viborg',
#  'Quilmes AC',
#  'Koblenz',
#  'Jubilo Iwata',
#  'Lausanne Sport',
#  'San Marcos de Arica',
#  'Universidad de Concepcion',
#  'FC Neftekhimik',
#  'Havre AC',
#  'Orlando City B',
#  'KooTeePee',
#  'Lugo',
#  'Virtus Lanciano',
#  'AEK',
#  'Martigues',
#  'Valerenga IF',
#  'Nantes',
#  'Aragua FC',
#  'Hull City',
#  'Chongqing Lifan',
#  'Clermont',
#  'Watford',
#  'Telford United',
#  'Vila Nova FC GO',
#  'Annecy',
#  'Newcastle United Jets',
#  'Ventforet Kofu',
#  'Real Salt Lake',
#  'Portuguesa',
#  'Deportivo Quito',
#  'Cuernavaca',
#  'Sporting Braga',
#  'Tasman United',
#  'Shanghai SIPG',
#  'Zwickau',
#  'Waregem',
#  'SuperSport United',
#  'Brasiliense',
#  'Alverca',
#  'Cerezo Osaka',
#  'Gimcheon Sangmu',
#  'Saint Louis FC',
#  'Farense',
#  'Hapoel Acre FC',
#  'Urena Sport Club',
#  'Gangwon FC',
#  'Briochin',
#  'Pittsburgh Riverhounds',
#  'Kokkola',
#  'Derby County',
#  'Sandhausen',
#  'Ayr United',
#  'Esporte Clube Juventude',
#  'Portsmouth',
#  'Coquimbo Unido',
#  'Sao Caetano',
#  'Atlanta Silverbacks',
#  'Goias Esporte Clube',
#  'Brescia',
#  'Stoke City',
#  'Birmingham Legion',
#  'Macara',
#  'Babelsberg',
#  'CRB Ain Fakroun',
#  'Levante',
#  'Tottenham Hotspur',
#  'Stromsgodset IF',
#  'Bonnyrigg Rose',
#  'Antwerp',
#  'Celtic Glasgow',
#  'Tim Sukazi Galaxy',
#  'Colo Colo',
#  'AS Beziers',
#  'Chelghoum Laid',
#  'Alloa Athletic',
#  'Caroni FC',
#  'Reno 1868 FC',
#  'FC Rouen',
#  'FK Torpedo Armavir',
#  'Dynamo Dresden',
#  'Barcelona SC',
#  'Jazz Pori',
#  'Bournemouth',
#  'Airdrie United',
#  'Renofa Yamaguchi',
#  'GyE La Plata',
#  'Tondela',
#  'Clube de Regatas Brasil',
#  'AS Kasserine',
#  'Triestina',
#  'Excelsior',
#  'Siegen',
#  'US Avranches',
#  'Lincoln',
#  'Start Kristiansand',
#  'Austria Wien',
#  'Saturn-REN TV',
#  'Ilves Tampere',
#  'Alessandria',
#  'Hallescher FC',
#  'Carolina RailHawks',
#  'Sevilla Atletico',
#  'Central Cordoba',
#  'Queens Park Rangers',
#  'AIK Solna',
#  'Club Necaxa',
#  'Crotone',
#  'Sporting Gijon',
#  'EOG Kram',
#  'Inverness CT',
#  'Bologna',
#  'Fortaleza',
#  'Angers SCO',
#  'Vancouver Whitecaps',
#  'Caracas FC',
#  'MO Bejaia',
#  'Club Leon',
#  'Club Sportif Sfaxien',
#  'Estrella Roja',
#  'Polokwane City',
#  'Le Havre',
#  'Olimpo',
#  'Internazionale Milano',
#  'El Nacional',
#  'Monaco',
#  'Parma',
#  'Philadelphia Union 2',
#  'Real Union',
#  'Gravesend',
#  'Maccabi Ahi Nazareth',
#  'Tokyo Verdy',
#  'Twente Enschede',
#  'FC Martigues',
#  'Union de Santa Fe',
#  'Dartford',
#  'Recreativo',
#  'Olympique Medea',
#  'Le Poire-sur-Vie',
#  'Ross County',
#  'Sao Bento',
#  'Fort Lauderdale Strikers',
#  'Tecnico Universitario',
#  'Avai FC',
#  'Moroka Swallows',
#  'Los Angeles Galaxy II',
#  'Valence',
#  'Logrones',
#  'Rimini',
#  'Darmstadt 98',
#  'Gateshead',
#  'AS Cannes',
#  'Beveren',
#  'Varbergs BoIS',
#  'Gainare Tottori',
#  'Benevento',
#  'Mushuc Runa',
#  'New Zealand Knights',
#  'Salernitana',
#  'Gwangju FC',
#  'Murcia',
#  'Mirandes',
#  'HollyHock',
#  'Leyton Orient',
#  'PAOK',
#  'Gamba Osaka',
#  'FC Edmonton',
#  'St Pauli',
#  'Rotherham United',
#  'TPS Turku',
#  'Stockport County',
#  'Allianssi',
#  'Doncaster Rovers',
#  'Maccabi Tel Aviv',
#  'Granada 74',
#  'Avangard Kursk',
#  'Braunschweig',
#  'Kouvola',
#  'LDU Portoviejo',
#  'Kallithea',
#  'Ironi Kiryat Shmona',
#  'Louisville City FC',
#  'Veracruz Sporting Club',
#  'Compostela',
#  'Alcoyano',
#  'FK Tosno',
#  'Caen',
#  'Phoenix Rising',
#  'Kelty Hearts',
#  'Cadiz',
#  'Jendouba Sport',
#  'Kilmarnock',
#  'Mjallby AIF',
#  'Maccabi Herzliya',
#  'LDU Loja',
#  'Mallorca',
#  'Orebro SK',
#  'Mannheim',
#  'Landskrona BoIS',
#  'Sunderland',
#  'Rio Ave',
#  'Racing de Casablanca',
#  'Havant and Waterlooville',
#  'FK Kamaz',
#  'FC Tambov',
#  'Degerfors',
#  'Maghrib de Fes',
#  'Middlesbrough',
#  'Corinthians Paulista',
#  'Troyes',
#  'Sydney FC',
#  'MSP Batna',
#  'Salyut-Energiya Belgorod',
#  'BidVest Wits',
#  'Barrow',
#  'Eibar',
#  'Nacional',
#  'ASM Belfort',
#  'Deportes Concepcion',
#  'Beijing Sanyaun',
#  'Trujillanos FC',
#  'Shaanxi Lijun Guoli',
#  'Central Coast Mariners',
#  'Carabobo FC',
#  'Giannina',
#  'Deportes Melipilla',
#  'Thanda Royal Zulu',
#  'Fleetwood Town',
#  'Giravanz',
#  'Virtus Entella',
#  'Omiya Ardija',
#  'Club Irapuato',
#  'Les Herbiers VF',
#  'US Creteil',
#  'Velves',
#  'Deportivo Guadalajara',
#  'FC Zurich',
#  'Proodeftiki',
#  'Ascoli',
#  'MVD Rossii',
#  'Bristol Rovers',
#  'Cassis-Carnoux',
#  'Oeste FC',
#  'FC St Gallen',
#  'Kerkyra',
#  'Notts County',
#  'Stade Plabennec',
#  'FC Luzern',
#  'For Sittard',
#  'US Quevilly',
#  'Kagoshima',
#  'FC Ashdod',
#  'Khemis Zemamra',
#  'Maccabi Netanya',
#  'Shanghai United',
#  'Olympic Sharks',
#  'Hameenlinna',
#  'LB Chateauroux',
#  'Orange County SC',
#  'Udinese',
#  'SV Meppen',
#  'Sporting Kansas City',
#  'Huddersfield Town',
#  'Jokerit Helsinki',
#  'SC Ashdod',
#  'Moghreb de Tetouan',
#  'Chernomorets Novorossisk',
#  'Odd Grenland',
#  'Canberra Cosmos',
#  'Dinamo Bryansk',
#  'Akratitos',
#  'Kickers Emden',
#  'Estudiantes',
#  'Luch-Energia',
#  'Albirex',
#  'Irtysh Omsk',
#  'Amorebieta',
#  'Portimonense',
#  'Argentinos Juniors',
#  'Port Vale',
#  'Coritiba FC',
#  'Clube do Remo',
#  'Esporte Clube Vitoria BA',
#  'Cittadella',
#  'CD Cobresal',
#  'Droylsden',
#  'Odense',
#  'Everton',
#  'Reading',
#  'FK Moscow',
#  'Confianca',
#  'Boca Juniors',
#  'Loudoun United',
#  'Roma',
#  'Cuiaba Esporte Clube',
#  'FK Nizhniy Novgorod',
#  'Platanias',
#  'RFC Seraing',
#  'Northwich',
#  'Histon',
#  'Dorados de Sinaloa',
#  'Eintracht Trier',
#  'CA Temperley',
#  'Anzhi Makhachkala',
#  'SonderjyskE',
#  'FK Angusht Nazran',
#  'Brommapojkarna',
#  'IF Elfsborg',
#  'Independiente del Valle',
#  'Barnet',
#  'Frosinone',
#  'Inter Miami',
#  'Liaoning',
#  'Volendam',
#  'Go Ahead Eagles',
#  'Club Almagro',
#  'Paysandu SC',
#  'Besancon',
#  'Hoffenheim',
#  'Den Bosch',
#  'Deportivo Petare',
#  'Oxford United',
#  'Westerlo',
#  'Portland Timbers 2',
#  'Nice',
#  'Harelbeke',
#  'Ferrol',
#  'Deportivo Zulia',
#  'Malmo FF',
#  'MC Saida',
#  'Fulham',
#  'COD Meknes',
#  'Kyoto Sanga',
#  'Santa Clara',
#  'Deportivo Toluca',
#  'Juventus',
#  'Aldosivi',
#  'Shinnik Yaroslavl',
#  'Rapid Wien',
#  'Orlando Pirates',
#  'Woking',
#  'South Melbourne Lakers',
#  'St Truiden',
#  'Feirense',
#  'Evian Thonon Gaillard',
#  'Wellington Phoenix R',
#  'Fortuna Koln',
#  'River Ecuador',
#  'Esperance Tunis',
#  'Sampdoria',
#  'West Bromwich Albion',
#  'Pordenone',
#  'Platense',
#  'Hapoel Beer Sheva',
#  'St Raphael FC',
#  'Chertanovo',
#  'Tuerkgucu',
#  'San Luis FC',
#  'FC Volgar Astrakhan',
#  'FC Sakhalin',
#  'Schwarz Weiss Bregenz',
#  'Aalst',
#  'Mazatlan',
#  'Lorient',
#  'Marseille Consolat',
#  'Haka Valkeakoski',
#  'Trofense',
#  'Santa Cruz FC',
#  'CD Olmedo',
#  'Kavala',
#  'Gremio Novorizontino',
#  'Havelse',
#  'Peterborough United',
#  'Hobro',
#  'Centro Italo',
#  'Heidenheim',
#  'Shrewsbury Town',
#  'Bordeaux',
#  'Elgin City',
#  'Shanghai East Asia',
#  'Metallurg-Kuzbass Novokuznetsk',
#  'Vegalta Sendai',
#  'IFK Mariehamn',
#  'Saarbrucken',
#  'RW Ahlen',
#  'CA Colon',
#  'Pumas de la UNAM',
#  'Wydad AC',
#  'LDU Quito',
#  'Uniao Madeira',
#  'San Martin Tucuman',
#  'AS Sale',
#  'Western United',
#  'Louvieroise',
#  'Sporting Club de Lyon',
#  'FC Karnten',
#  'Empoli',
#  'Zwolle',
#  'CD Huachipato',
#  'Jeonbuk FC',
#  'Ternana',
#  'Gefle IF',
#  'Casa Pia AC',
#  'Kashiwa Reysol',
#  'Wealdstone',
#  'Nagoya Grampus',
#  'VfB Oldenburg',
#  'Daegu FC',
#  'Carlisle',
#  'Panserraikos',
#  'Jahn Regensburg',
#  'Yeovil Town',
#  'Grasshoppers Zurich',
#  'Wiener Neustadt',
#  'Pacy Vallee',
#  'Grombalia Sports',
#  'Bastia-Borgo',
#  'Vityaz Podolsk',
#  'Enisey Krasnoyarsk',
#  'Wolfsburg',
#  'Arles',
#  'FC Istres',
#  'CF Montreal',
#  'Lillestrom SK',
#  'Los Andes',
#  'Jacksonville Armada',
#  'VfB Stuttgart',
#  'Ibiza',
#  'Silkeborg',
#  'Tamworth',
#  'Crewe Alexandra',
#  'Panionios',
#  'Leganes',
#  'Audax Italiano',
#  'Independiente',
#  'Hapoel Ashkelon',
#  'CS Constantine',
#  'Colorado Springs Switchbacks',
#  'OMR El Annasser',
#  'Hibernian',
#  'Tromso IL',
#  'JS El Massira',
#  'Estudiantes de Merida',
#  'OFI Heraklion',
#  'Shenzhen FC',
#  'America RN',
#  'Deportivo Tachira',
#  'Aberdeen',
#  'Difaa Jadida',
#  'Chalkidona',
#  'Estrela Amadora',
#  'SV Ried',
#  'Sibir Novosibirsk',
#  'FC Brussels',
#  'Egaleo',
#  'San Martin de San Juan',
#  'Stade Tunisien',
#  'Gold Coast United',
#  'FF Jaro',
#  'Macclesfield',
#  'Leixoes',
#  'Beira Mar',
#  'ES Hammam Sousse',
#  'St Johnstone',
#  'FC Seoul',
#  'Dijon',
#  'Athletic Bilbao',
#  'Messina',
#  'Catania',
#  'RC Kouba',
#  'Winterthur',
#  'Boavista',
#  'Treviso',
#  'Vendsyssel',
#  'Deportes Copiapo',
#  'Crucero del Norte',
#  'Union Saint-Gilloise',
#  'Columbus Crew',
#  'Brondby',
#  'Paris FC',
#  'Hartford Athletic',
#  'Paris 13 Atletico',
#  'Wolfsberger AC',
#  'Consadole Sapporo',
#  'Clyde',
#  'Niki Volou FC',
#  'Chippa United',
#  'Rayo Oklahoma City',
#  'FC Ufa',
#  'Inter Turku',
#  'Alcorcon',
#  'Hapoel Raanana',
#  'Southport',
#  'Shanghai Greenland',
#  ...]

# %% [markdown]
# ### Functions to gather each team statistics

# %%
def extract_team_df(team_name):
    ''' Extracts games of a specific team from whole training set.
    '''
    
    home_team_df = training_set[training_set["HT"] == team_name]
    away_team_df = training_set[training_set["AT"] == team_name]
        
    team_df = pd.concat([home_team_df, away_team_df]).sort_values(by="Date")
    
    return team_df, home_team_df, away_team_df

# %%
def get_stats(df, local=True):
    '''Fills in team statistics dictionary.
    '''
    team_stats = dict()
    if local is True:
        prefix = "home"
        goals_scored_col = "HS"
        goals_against_col = "AS"
        win, loss = "W", "L"
        goals_difference = df["GD"].sum()
        try:
            avg_goals_difference = round(df["GD"].sum() / df.shape[0], 3)
        except ZeroDivisionError:
            avg_goals_difference = np.nan
    else:
        prefix = "away"
        goals_scored_col = "AS"
        goals_against_col = "HS"
        win, loss = "L", "W"
        goals_difference = - df["GD"].sum()
        try:
            avg_goals_difference = - round(df["GD"].sum() / df.shape[0], 3)
        except ZeroDivisionError:
            avg_goals_difference = np.nan

    team_stats[f"{prefix}_games"] = df.shape[0]
    
    team_stats[f"{prefix}_wins"] = df["WDL"].value_counts().get(win, 0)
    team_stats[f"{prefix}_draws"] = df["WDL"].value_counts().get("D", 0)
    team_stats[f"{prefix}_losses"] = df["WDL"].value_counts().get(loss, 0)
    
    try:
        team_stats[f"{prefix}_win_percentage"] = round(df["WDL"].value_counts().get(win, 0) / df.shape[0], 3)
    except ZeroDivisionError:
        team_stats[f"{prefix}_win_percentage"] = np.nan
    try:
        team_stats[f"{prefix}_draw_percentage"] = round(df["WDL"].value_counts().get("D", 0) / df.shape[0], 3)
    except ZeroDivisionError:
        team_stats[f"{prefix}_draw_percentage"] = np.nan
    try:
        team_stats[f"{prefix}_loss_percentage"] = round(df["WDL"].value_counts().get(loss, 0) / df.shape[0], 3)
    except ZeroDivisionError:
        team_stats[f"{prefix}_loss_percentage"] = np.nan
    team_stats[f"{prefix}_goals_scored"] = df[goals_scored_col].sum()
    team_stats[f"{prefix}_goals_against"] = df[goals_against_col].sum()
    team_stats[f"{prefix}_goals_difference"] = goals_difference
    try:
        team_stats[f"{prefix}_avg_goals_scored"] = round(df[goals_scored_col].sum() / df.shape[0], 3)
    except ZeroDivisionError:
        team_stats[f"{prefix}_avg_goals_scored"] = np.nan
    try:
        team_stats[f"{prefix}_avg_goals_against"] = round(df[goals_against_col].sum() / df.shape[0], 3)
    except ZeroDivisionError:
        team_stats[f"{prefix}_avg_goals_against"] = np.nan
    team_stats[f"{prefix}_avg_goals_difference"] = avg_goals_difference

    return team_stats

# %% [markdown]
# ### Basic function to fill in each team dict with specific data

# %%
def complete_team_info(team_name):

    # Filter games only of specified team
    team_df, home_team_df, away_team_df = extract_team_df(team_name)
        
    # Create team dict
    team_stats = dict()

    # Recover home and away teams separately
    home_stats = get_stats(home_team_df, local=True)
    away_stats = get_stats(away_team_df, local=False)

    # Add home and away stats
    team_stats_temp = home_stats | away_stats

    # Add general stats
    team_stats["name"] = team_name
    team_stats["total_games"] = team_df.shape[0]
    team_stats["wins"] = team_stats_temp["home_wins"] + team_stats_temp["away_wins"]
    team_stats["draws"] = team_stats_temp["home_draws"] + team_stats_temp["away_draws"]
    team_stats["losses"] = team_stats_temp["home_losses"] + team_stats_temp["away_losses"]
    team_stats["win_percentage"] = round(team_stats["wins"] / team_df.shape[0], 3)
    team_stats["draw_percentage"] = round(team_stats["draws"] / team_df.shape[0], 3)
    team_stats["loss_percentage"] = round(team_stats["losses"] / team_df.shape[0], 3)
    team_stats["goals_scored"] = team_stats_temp["home_goals_scored"] + team_stats_temp["away_goals_scored"]
    team_stats["goals_against"] = team_stats_temp["home_goals_against"] + team_stats_temp["away_goals_against"]
    team_stats["goals_difference"] = team_stats["goals_scored"] - team_stats["goals_against"]
    team_stats["avg_goals_scored"] = round(team_stats["goals_scored"] / team_df.shape[0], 3)
    team_stats["avg_goals_against"] = round(team_stats["goals_against"] / team_df.shape[0], 3)
    team_stats["avg_goals_difference"] = round(team_stats["goals_difference"] / team_df.shape[0], 3)
    
    team_stats = team_stats | home_stats | away_stats
       
    return team_stats

# %% [markdown]
# ### Complete each team info

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
teams = list()

# For each team, complete its info...
for team in teams_list:
    team_stats = complete_team_info(team_name=team)
    teams.append(team_stats)

# %% [markdown]
# ### Check list with all teams dicts info isolated

# %%
teams

# with open("teams.pickle") as teams_file:
#    pickle.dump(teams, teams_file)
# Out:
# [{'name': 'Assyriska',
#   'total_games': 26,
#   'wins': 4,
#   'draws': 2,
#   'losses': 20,
#   'win_percentage': 0.154,
#   'draw_percentage': 0.077,
#   'loss_percentage': 0.769,
#   'goals_scored': 17,
#   'goals_against': 52,
#   'goals_difference': -35,
#   'avg_goals_scored': 0.654,
#   'avg_goals_against': 2.0,
#   'avg_goals_difference': -1.346,
#   'home_games': 13,
#   'home_wins': 1,
#   'home_draws': 1,
#   'home_losses': 11,
#   'home_win_percentage': 0.077,
#   'home_draw_percentage': 0.077,
#   'home_loss_percentage': 0.846,
#   'home_goals_scored': 5,
#   'home_goals_against': 25,
#   'home_goals_difference': -20,
#   'home_avg_goals_scored': 0.385,
#   'home_avg_goals_against': 1.923,
#   'home_avg_goals_difference': -1.538,
#   'away_games': 13,
#   'away_wins': 3,
#   'away_draws': 1,
#   'away_losses': 9,
#   'away_win_percentage': 0.231,
#   'away_draw_percentage': 0.077,
#   'away_loss_percentage': 0.692,
#   'away_goals_scored': 12,
#   'away_goals_against': 27,
#   'away_goals_difference': -15,
#   'away_avg_goals_scored': 0.923,
#   'away_avg_goals_against': 2.077,
#   'away_avg_goals_difference': -1.154},
#  {'name': 'Sagamihara',
#   'total_games': 42,
#   'wins': 8,
#   'draws': 14,
#   'losses': 20,
#   'win_percentage': 0.19,
#   'draw_percentage': 0.333,
#   'loss_percentage': 0.476,
#   'goals_scored': 33,
#   'goals_against': 54,
#   'goals_difference': -21,
#   'avg_goals_scored': 0.786,
#   'avg_goals_against': 1.286,
#   'avg_goals_difference': -0.5,
#   'home_games': 21,
#   'home_wins': 4,
#   'home_draws': 8,
#   'home_losses': 9,
#   'home_win_percentage': 0.19,
#   'home_draw_percentage': 0.381,
#   'home_loss_percentage': 0.429,
#   'home_goals_scored': 20,
#   'home_goals_against': 29,
#   'home_goals_difference': -9,
#   'home_avg_goals_scored': 0.952,
#   'home_avg_goals_against': 1.381,
#   'home_avg_goals_difference': -0.429,
#   'away_games': 21,
#   'away_wins': 4,
#   'away_draws': 6,
#   'away_losses': 11,
#   'away_win_percentage': 0.19,
#   'away_draw_percentage': 0.286,
#   'away_loss_percentage': 0.524,
#   'away_goals_scored': 13,
#   'away_goals_against': 25,
#   'away_goals_difference': -12,
#   'away_avg_goals_scored': 0.619,
#   'away_avg_goals_against': 1.19,
#   'away_avg_goals_difference': -0.571},
#  {'name': 'Halmstads BK',
#   'total_games': 478,
#   'wins': 147,
#   'draws': 135,
#   'losses': 196,
#   'win_percentage': 0.308,
#   'draw_percentage': 0.282,
#   'loss_percentage': 0.41,
#   'goals_scored': 591,
#   'goals_against': 648,
#   'goals_difference': -57,
#   'avg_goals_scored': 1.236,
#   'avg_goals_against': 1.356,
#   'avg_goals_difference': -0.119,
#   'home_games': 239,
#   'home_wins': 85,
#   'home_draws': 77,
#   'home_losses': 77,
#   'home_win_percentage': 0.356,
#   'home_draw_percentage': 0.322,
#   'home_loss_percentage': 0.322,
#   'home_goals_scored': 332,
#   'home_goals_against': 291,
#   'home_goals_difference': 41,
#   'home_avg_goals_scored': 1.389,
#   'home_avg_goals_against': 1.218,
#   'home_avg_goals_difference': 0.172,
#   'away_games': 239,
#   'away_wins': 62,
#   'away_draws': 58,
#   'away_losses': 119,
#   'away_win_percentage': 0.259,
#   'away_draw_percentage': 0.243,
#   'away_loss_percentage': 0.498,
#   'away_goals_scored': 259,
#   'away_goals_against': 357,
#   'away_goals_difference': -98,
#   'away_avg_goals_scored': 1.084,
#   'away_avg_goals_against': 1.494,
#   'away_avg_goals_difference': -0.41},
#  {'name': 'Espanyol Barcelona',
#   'total_games': 860,
#   'wins': 283,
#   'draws': 225,
#   'losses': 352,
#   'win_percentage': 0.329,
#   'draw_percentage': 0.262,
#   'loss_percentage': 0.409,
#   'goals_scored': 1001,
#   'goals_against': 1171,
#   'goals_difference': -170,
#   'avg_goals_scored': 1.164,
#   'avg_goals_against': 1.362,
#   'avg_goals_difference': -0.198,
#   'home_games': 430,
#   'home_wins': 193,
#   'home_draws': 104,
#   'home_losses': 133,
#   'home_win_percentage': 0.449,
#   'home_draw_percentage': 0.242,
#   'home_loss_percentage': 0.309,
#   'home_goals_scored': 594,
#   'home_goals_against': 499,
#   'home_goals_difference': 95,
#   'home_avg_goals_scored': 1.381,
#   'home_avg_goals_against': 1.16,
#   'home_avg_goals_difference': 0.221,
#   'away_games': 430,
#   'away_wins': 90,
#   'away_draws': 121,
#   'away_losses': 219,
#   'away_win_percentage': 0.209,
#   'away_draw_percentage': 0.281,
#   'away_loss_percentage': 0.509,
#   'away_goals_scored': 407,
#   'away_goals_against': 672,
#   'away_goals_difference': -265,
#   'away_avg_goals_scored': 0.947,
#   'away_avg_goals_against': 1.563,
#   'away_avg_goals_difference': -0.616},
#  {'name': 'Kuban Krasnodar',
#   'total_games': 412,
#   'wins': 138,
#   'draws': 126,
#   'losses': 148,
#   'win_percentage': 0.335,
#   'draw_percentage': 0.306,
#   'loss_percentage': 0.359,
#   'goals_scored': 473,
#   'goals_against': 482,
#   'goals_difference': -9,
#   'avg_goals_scored': 1.148,
#   'avg_goals_against': 1.17,
#   'avg_goals_difference': -0.022,
#   'home_games': 206,
#   'home_wins': 82,
#   'home_draws': 70,
#   'home_losses': 54,
#   'home_win_percentage': 0.398,
#   'home_draw_percentage': 0.34,
#   'home_loss_percentage': 0.262,
#   'home_goals_scored': 273,
#   'home_goals_against': 216,
#   'home_goals_difference': 57,
#   'home_avg_goals_scored': 1.325,
#   'home_avg_goals_against': 1.049,
#   'home_avg_goals_difference': 0.277,
#   'away_games': 206,
#   'away_wins': 56,
#   'away_draws': 56,
#   'away_losses': 94,
#   'away_win_percentage': 0.272,
#   'away_draw_percentage': 0.272,
#   'away_loss_percentage': 0.456,
#   'away_goals_scored': 200,
#   'away_goals_against': 266,
#   'away_goals_difference': -66,
#   'away_avg_goals_scored': 0.971,
#   'away_avg_goals_against': 1.291,
#   'away_avg_goals_difference': -0.32},
#  {'name': 'Ponte Preta',
#   'total_games': 582,
#   'wins': 206,
#   'draws': 158,
#   'losses': 218,
#   'win_percentage': 0.354,
#   'draw_percentage': 0.271,
#   'loss_percentage': 0.375,
#   'goals_scored': 685,
#   'goals_against': 738,
#   'goals_difference': -53,
#   'avg_goals_scored': 1.177,
#   'avg_goals_against': 1.268,
#   'avg_goals_difference': -0.091,
#   'home_games': 291,
#   'home_wins': 140,
#   'home_draws': 73,
#   'home_losses': 78,
#   'home_win_percentage': 0.481,
#   'home_draw_percentage': 0.251,
#   'home_loss_percentage': 0.268,
#   'home_goals_scored': 410,
#   'home_goals_against': 312,
#   'home_goals_difference': 98,
#   'home_avg_goals_scored': 1.409,
#   'home_avg_goals_against': 1.072,
#   'home_avg_goals_difference': 0.337,
#   'away_games': 291,
#   'away_wins': 66,
#   'away_draws': 85,
#   'away_losses': 140,
#   'away_win_percentage': 0.227,
#   'away_draw_percentage': 0.292,
#   'away_loss_percentage': 0.481,
#   'away_goals_scored': 275,
#   'away_goals_against': 426,
#   'away_goals_difference': -151,
#   'away_avg_goals_scored': 0.945,
#   'away_avg_goals_against': 1.464,
#   'away_avg_goals_difference': -0.519},
#  {'name': 'Forfar Athletic',
#   'total_games': 792,
#   'wins': 288,
#   'draws': 175,
#   'losses': 329,
#   'win_percentage': 0.364,
#   'draw_percentage': 0.221,
#   'loss_percentage': 0.415,
#   'goals_scored': 1109,
#   'goals_against': 1222,
#   'goals_difference': -113,
#   'avg_goals_scored': 1.4,
#   'avg_goals_against': 1.543,
#   'avg_goals_difference': -0.143,
#   'home_games': 397,
#   'home_wins': 163,
#   'home_draws': 83,
#   'home_losses': 151,
#   'home_win_percentage': 0.411,
#   'home_draw_percentage': 0.209,
#   'home_loss_percentage': 0.38,
#   'home_goals_scored': 619,
#   'home_goals_against': 571,
#   'home_goals_difference': 48,
#   'home_avg_goals_scored': 1.559,
#   'home_avg_goals_against': 1.438,
#   'home_avg_goals_difference': 0.121,
#   'away_games': 395,
#   'away_wins': 125,
#   'away_draws': 92,
#   'away_losses': 178,
#   'away_win_percentage': 0.316,
#   'away_draw_percentage': 0.233,
#   'away_loss_percentage': 0.451,
#   'away_goals_scored': 490,
#   'away_goals_against': 651,
#   'away_goals_difference': -161,
#   'away_avg_goals_scored': 1.241,
#   'away_avg_goals_against': 1.648,
#   'away_avg_goals_difference': -0.408},
#  {'name': 'Vallecano',
#   'total_games': 736,
#   'wins': 256,
#   'draws': 189,
#   'losses': 291,
#   'win_percentage': 0.348,
#   'draw_percentage': 0.257,
#   'loss_percentage': 0.395,
#   'goals_scored': 950,
#   'goals_against': 1074,
#   'goals_difference': -124,
#   'avg_goals_scored': 1.291,
#   'avg_goals_against': 1.459,
#   'avg_goals_difference': -0.168,
#   'home_games': 368,
#   'home_wins': 165,
#   'home_draws': 88,
#   'home_losses': 115,
#   'home_win_percentage': 0.448,
#   'home_draw_percentage': 0.239,
#   'home_loss_percentage': 0.312,
#   'home_goals_scored': 563,
#   'home_goals_against': 459,
#   'home_goals_difference': 104,
#   'home_avg_goals_scored': 1.53,
#   'home_avg_goals_against': 1.247,
#   'home_avg_goals_difference': 0.283,
#   'away_games': 368,
#   'away_wins': 91,
#   'away_draws': 101,
#   'away_losses': 176,
#   'away_win_percentage': 0.247,
#   'away_draw_percentage': 0.274,
#   'away_loss_percentage': 0.478,
#   'away_goals_scored': 387,
#   'away_goals_against': 615,
#   'away_goals_difference': -228,
#   'away_avg_goals_scored': 1.052,
#   'away_avg_goals_against': 1.671,
#   'away_avg_goals_difference': -0.62},
#  {'name': 'Yaracuyanos FC',
#   'total_games': 216,
#   'wins': 56,
#   'draws': 60,
#   'losses': 100,
#   'win_percentage': 0.259,
#   'draw_percentage': 0.278,
#   'loss_percentage': 0.463,
#   'goals_scored': 219,
#   'goals_against': 291,
#   'goals_difference': -72,
#   'avg_goals_scored': 1.014,
#   'avg_goals_against': 1.347,
#   'avg_goals_difference': -0.333,
#   'home_games': 108,
#   'home_wins': 35,
#   'home_draws': 33,
#   'home_losses': 40,
#   'home_win_percentage': 0.324,
#   'home_draw_percentage': 0.306,
#   'home_loss_percentage': 0.37,
#   'home_goals_scored': 117,
#   'home_goals_against': 123,
#   'home_goals_difference': -6,
#   'home_avg_goals_scored': 1.083,
#   'home_avg_goals_against': 1.139,
#   'home_avg_goals_difference': -0.056,
#   'away_games': 108,
#   'away_wins': 21,
#   'away_draws': 27,
#   'away_losses': 60,
#   'away_win_percentage': 0.194,
#   'away_draw_percentage': 0.25,
#   'away_loss_percentage': 0.556,
#   'away_goals_scored': 102,
#   'away_goals_against': 168,
#   'away_goals_difference': -66,
#   'away_avg_goals_scored': 0.944,
#   'away_avg_goals_against': 1.556,
#   'away_avg_goals_difference': -0.611},
#  {'name': 'Zenit St Petersburg',
#   'total_games': 715,
#   'wins': 390,
#   'draws': 192,
#   'losses': 133,
#   'win_percentage': 0.545,
#   'draw_percentage': 0.269,
#   'loss_percentage': 0.186,
#   'goals_scored': 1300,
#   'goals_against': 680,
#   'goals_difference': 620,
#   'avg_goals_scored': 1.818,
#   'avg_goals_against': 0.951,
#   'avg_goals_difference': 0.867,
#   'home_games': 357,
#   'home_wins': 224,
#   'home_draws': 86,
#   'home_losses': 47,
#   'home_win_percentage': 0.627,
#   'home_draw_percentage': 0.241,
#   'home_loss_percentage': 0.132,
#   'home_goals_scored': 745,
#   'home_goals_against': 306,
#   'home_goals_difference': 439,
#   'home_avg_goals_scored': 2.087,
#   'home_avg_goals_against': 0.857,
#   'home_avg_goals_difference': 1.23,
#   'away_games': 358,
#   'away_wins': 166,
#   'away_draws': 106,
#   'away_losses': 86,
#   'away_win_percentage': 0.464,
#   'away_draw_percentage': 0.296,
#   'away_loss_percentage': 0.24,
#   'away_goals_scored': 555,
#   'away_goals_against': 374,
#   'away_goals_difference': 181,
#   'away_avg_goals_scored': 1.55,
#   'away_avg_goals_against': 1.045,
#   'away_avg_goals_difference': 0.506},
#  {'name': 'FC Thun',
#   'total_games': 557,
#   'wins': 185,
#   'draws': 147,
#   'losses': 225,
#   'win_percentage': 0.332,
#   'draw_percentage': 0.264,
#   'loss_percentage': 0.404,
#   'goals_scored': 752,
#   'goals_against': 851,
#   'goals_difference': -99,
#   'avg_goals_scored': 1.35,
#   'avg_goals_against': 1.528,
#   'avg_goals_difference': -0.178,
#   'home_games': 279,
#   'home_wins': 111,
#   'home_draws': 81,
#   'home_losses': 87,
#   'home_win_percentage': 0.398,
#   'home_draw_percentage': 0.29,
#   'home_loss_percentage': 0.312,
#   'home_goals_scored': 435,
#   'home_goals_against': 380,
#   'home_goals_difference': 55,
#   'home_avg_goals_scored': 1.559,
#   'home_avg_goals_against': 1.362,
#   'home_avg_goals_difference': 0.197,
#   'away_games': 278,
#   'away_wins': 74,
#   'away_draws': 66,
#   'away_losses': 138,
#   'away_win_percentage': 0.266,
#   'away_draw_percentage': 0.237,
#   'away_loss_percentage': 0.496,
#   'away_goals_scored': 317,
#   'away_goals_against': 471,
#   'away_goals_difference': -154,
#   'away_avg_goals_scored': 1.14,
#   'away_avg_goals_against': 1.694,
#   'away_avg_goals_difference': -0.554},
#  {'name': 'TSV Hartberg',
#   'total_games': 137,
#   'wins': 43,
#   'draws': 32,
#   'losses': 62,
#   'win_percentage': 0.314,
#   'draw_percentage': 0.234,
#   'loss_percentage': 0.453,
#   'goals_scored': 186,
#   'goals_against': 261,
#   'goals_difference': -75,
#   'avg_goals_scored': 1.358,
#   'avg_goals_against': 1.905,
#   'avg_goals_difference': -0.547,
#   'home_games': 69,
#   'home_wins': 22,
#   'home_draws': 19,
#   'home_losses': 28,
#   'home_win_percentage': 0.319,
#   'home_draw_percentage': 0.275,
#   'home_loss_percentage': 0.406,
#   'home_goals_scored': 89,
#   'home_goals_against': 114,
#   'home_goals_difference': -25,
#   'home_avg_goals_scored': 1.29,
#   'home_avg_goals_against': 1.652,
#   'home_avg_goals_difference': -0.362,
#   'away_games': 68,
#   'away_wins': 21,
#   'away_draws': 13,
#   'away_losses': 34,
#   'away_win_percentage': 0.309,
#   'away_draw_percentage': 0.191,
#   'away_loss_percentage': 0.5,
#   'away_goals_scored': 97,
#   'away_goals_against': 147,
#   'away_goals_difference': -50,
#   'away_avg_goals_scored': 1.426,
#   'away_avg_goals_against': 2.162,
#   'away_avg_goals_difference': -0.735},
#  {'name': 'Werder Bremen',
#   'total_games': 767,
#   'wins': 316,
#   'draws': 183,
#   'losses': 268,
#   'win_percentage': 0.412,
#   'draw_percentage': 0.239,
#   'loss_percentage': 0.349,
#   'goals_scored': 1288,
#   'goals_against': 1168,
#   'goals_difference': 120,
#   'avg_goals_scored': 1.679,
#   'avg_goals_against': 1.523,
#   'avg_goals_difference': 0.156,
#   'home_games': 384,
#   'home_wins': 182,
#   'home_draws': 89,
#   'home_losses': 113,
#   'home_win_percentage': 0.474,
#   'home_draw_percentage': 0.232,
#   'home_loss_percentage': 0.294,
#   'home_goals_scored': 692,
#   'home_goals_against': 520,
#   'home_goals_difference': 172,
#   'home_avg_goals_scored': 1.802,
#   'home_avg_goals_against': 1.354,
#   'home_avg_goals_difference': 0.448,
#   'away_games': 383,
#   'away_wins': 134,
#   'away_draws': 94,
#   'away_losses': 155,
#   'away_win_percentage': 0.35,
#   'away_draw_percentage': 0.245,
#   'away_loss_percentage': 0.405,
#   'away_goals_scored': 596,
#   'away_goals_against': 648,
#   'away_goals_difference': -52,
#   'away_avg_goals_scored': 1.556,
#   'away_avg_goals_against': 1.692,
#   'away_avg_goals_difference': -0.136},
#  {'name': 'Olympique Marseille',
#   'total_games': 840,
#   'wins': 392,
#   'draws': 223,
#   'losses': 225,
#   'win_percentage': 0.467,
#   'draw_percentage': 0.265,
#   'loss_percentage': 0.268,
#   'goals_scored': 1219,
#   'goals_against': 905,
#   'goals_difference': 314,
#   'avg_goals_scored': 1.451,
#   'avg_goals_against': 1.077,
#   'avg_goals_difference': 0.374,
#   'home_games': 421,
#   'home_wins': 237,
#   'home_draws': 104,
#   'home_losses': 80,
#   'home_win_percentage': 0.563,
#   'home_draw_percentage': 0.247,
#   'home_loss_percentage': 0.19,
#   'home_goals_scored': 702,
#   'home_goals_against': 402,
#   'home_goals_difference': 300,
#   'home_avg_goals_scored': 1.667,
#   'home_avg_goals_against': 0.955,
#   'home_avg_goals_difference': 0.713,
#   'away_games': 419,
#   'away_wins': 155,
#   'away_draws': 119,
#   'away_losses': 145,
#   'away_win_percentage': 0.37,
#   'away_draw_percentage': 0.284,
#   'away_loss_percentage': 0.346,
#   'away_goals_scored': 517,
#   'away_goals_against': 503,
#   'away_goals_difference': 14,
#   'away_avg_goals_scored': 1.234,
#   'away_avg_goals_against': 1.2,
#   'away_avg_goals_difference': 0.033},
#  {'name': 'FC Lugano',
#   'total_games': 315,
#   'wins': 116,
#   'draws': 85,
#   'losses': 114,
#   'win_percentage': 0.368,
#   'draw_percentage': 0.27,
#   'loss_percentage': 0.362,
#   'goals_scored': 424,
#   'goals_against': 461,
#   'goals_difference': -37,
#   'avg_goals_scored': 1.346,
#   'avg_goals_against': 1.463,
#   'avg_goals_difference': -0.117,
#   'home_games': 157,
#   'home_wins': 66,
#   'home_draws': 43,
#   'home_losses': 48,
#   'home_win_percentage': 0.42,
#   'home_draw_percentage': 0.274,
#   'home_loss_percentage': 0.306,
#   'home_goals_scored': 216,
#   'home_goals_against': 194,
#   'home_goals_difference': 22,
#   'home_avg_goals_scored': 1.376,
#   'home_avg_goals_against': 1.236,
#   'home_avg_goals_difference': 0.14,
#   'away_games': 158,
#   'away_wins': 50,
#   'away_draws': 42,
#   'away_losses': 66,
#   'away_win_percentage': 0.316,
#   'away_draw_percentage': 0.266,
#   'away_loss_percentage': 0.418,
#   'away_goals_scored': 208,
#   'away_goals_against': 267,
#   'away_goals_difference': -59,
#   'away_avg_goals_scored': 1.316,
#   'away_avg_goals_against': 1.69,
#   'away_avg_goals_difference': -0.373},
#  {'name': 'Brisbane Roar',
#   'total_games': 369,
#   'wins': 147,
#   'draws': 89,
#   'losses': 133,
#   'win_percentage': 0.398,
#   'draw_percentage': 0.241,
#   'loss_percentage': 0.36,
#   'goals_scored': 527,
#   'goals_against': 497,
#   'goals_difference': 30,
#   'avg_goals_scored': 1.428,
#   'avg_goals_against': 1.347,
#   'avg_goals_difference': 0.081,
#   'home_games': 185,
#   'home_wins': 87,
#   'home_draws': 40,
#   'home_losses': 58,
#   'home_win_percentage': 0.47,
#   'home_draw_percentage': 0.216,
#   'home_loss_percentage': 0.314,
#   'home_goals_scored': 289,
#   'home_goals_against': 223,
#   'home_goals_difference': 66,
#   'home_avg_goals_scored': 1.562,
#   'home_avg_goals_against': 1.205,
#   'home_avg_goals_difference': 0.357,
#   'away_games': 184,
#   'away_wins': 60,
#   'away_draws': 49,
#   'away_losses': 75,
#   'away_win_percentage': 0.326,
#   'away_draw_percentage': 0.266,
#   'away_loss_percentage': 0.408,
#   'away_goals_scored': 238,
#   'away_goals_against': 274,
#   'away_goals_difference': -36,
#   'away_avg_goals_scored': 1.293,
#   'away_avg_goals_against': 1.489,
#   'away_avg_goals_difference': -0.196},
#  {'name': 'Chengdu Blades',
#   'total_games': 90,
#   'wins': 23,
#   'draws': 29,
#   'losses': 38,
#   'win_percentage': 0.256,
#   'draw_percentage': 0.322,
#   'loss_percentage': 0.422,
#   'goals_scored': 89,
#   'goals_against': 123,
#   'goals_difference': -34,
#   'avg_goals_scored': 0.989,
#   'avg_goals_against': 1.367,
#   'avg_goals_difference': -0.378,
#   'home_games': 45,
#   'home_wins': 14,
#   'home_draws': 15,
#   'home_losses': 16,
#   'home_win_percentage': 0.311,
#   'home_draw_percentage': 0.333,
#   'home_loss_percentage': 0.356,
#   'home_goals_scored': 51,
#   'home_goals_against': 59,
#   'home_goals_difference': -8,
#   'home_avg_goals_scored': 1.133,
#   'home_avg_goals_against': 1.311,
#   'home_avg_goals_difference': -0.178,
#   'away_games': 45,
#   'away_wins': 9,
#   'away_draws': 14,
#   'away_losses': 22,
#   'away_win_percentage': 0.2,
#   'away_draw_percentage': 0.311,
#   'away_loss_percentage': 0.489,
#   'away_goals_scored': 38,
#   'away_goals_against': 64,
#   'away_goals_difference': -26,
#   'away_avg_goals_scored': 0.844,
#   'away_avg_goals_against': 1.422,
#   'away_avg_goals_difference': -0.578},
#  {'name': 'Atletico Celaya',
#   'total_games': 19,
#   'wins': 5,
#   'draws': 6,
#   'losses': 8,
#   'win_percentage': 0.263,
#   'draw_percentage': 0.316,
#   'loss_percentage': 0.421,
#   'goals_scored': 24,
#   'goals_against': 32,
#   'goals_difference': -8,
#   'avg_goals_scored': 1.263,
#   'avg_goals_against': 1.684,
#   'avg_goals_difference': -0.421,
#   'home_games': 10,
#   'home_wins': 3,
#   'home_draws': 4,
#   'home_losses': 3,
#   'home_win_percentage': 0.3,
#   'home_draw_percentage': 0.4,
#   'home_loss_percentage': 0.3,
#   'home_goals_scored': 11,
#   'home_goals_against': 12,
#   'home_goals_difference': -1,
#   'home_avg_goals_scored': 1.1,
#   'home_avg_goals_against': 1.2,
#   'home_avg_goals_difference': -0.1,
#   'away_games': 9,
#   'away_wins': 2,
#   'away_draws': 2,
#   'away_losses': 5,
#   'away_win_percentage': 0.222,
#   'away_draw_percentage': 0.222,
#   'away_loss_percentage': 0.556,
#   'away_goals_scored': 13,
#   'away_goals_against': 20,
#   'away_goals_difference': -7,
#   'away_avg_goals_scored': 1.444,
#   'away_avg_goals_against': 2.222,
#   'away_avg_goals_difference': -0.778},
#  {'name': 'Sanfrecce',
#   'total_games': 612,
#   'wins': 253,
#   'draws': 159,
#   'losses': 200,
#   'win_percentage': 0.413,
#   'draw_percentage': 0.26,
#   'loss_percentage': 0.327,
#   'goals_scored': 885,
#   'goals_against': 745,
#   'goals_difference': 140,
#   'avg_goals_scored': 1.446,
#   'avg_goals_against': 1.217,
#   'avg_goals_difference': 0.229,
#   'home_games': 306,
#   'home_wins': 136,
#   'home_draws': 78,
#   'home_losses': 92,
#   'home_win_percentage': 0.444,
#   'home_draw_percentage': 0.255,
#   'home_loss_percentage': 0.301,
#   'home_goals_scored': 468,
#   'home_goals_against': 344,
#   'home_goals_difference': 124,
#   'home_avg_goals_scored': 1.529,
#   'home_avg_goals_against': 1.124,
#   'home_avg_goals_difference': 0.405,
#   'away_games': 306,
#   'away_wins': 117,
#   'away_draws': 81,
#   'away_losses': 108,
#   'away_win_percentage': 0.382,
#   'away_draw_percentage': 0.265,
#   'away_loss_percentage': 0.353,
#   'away_goals_scored': 417,
#   'away_goals_against': 401,
#   'away_goals_difference': 16,
#   'away_avg_goals_scored': 1.363,
#   'away_avg_goals_against': 1.31,
#   'away_avg_goals_difference': 0.052},
#  {'name': 'Strasbourg',
#   'total_games': 376,
#   'wins': 119,
#   'draws': 117,
#   'losses': 140,
#   'win_percentage': 0.316,
#   'draw_percentage': 0.311,
#   'loss_percentage': 0.372,
#   'goals_scored': 413,
#   'goals_against': 473,
#   'goals_difference': -60,
#   'avg_goals_scored': 1.098,
#   'avg_goals_against': 1.258,
#   'avg_goals_difference': -0.16,
#   'home_games': 188,
#   'home_wins': 85,
#   'home_draws': 55,
#   'home_losses': 48,
#   'home_win_percentage': 0.452,
#   'home_draw_percentage': 0.293,
#   'home_loss_percentage': 0.255,
#   'home_goals_scored': 245,
#   'home_goals_against': 191,
#   'home_goals_difference': 54,
#   'home_avg_goals_scored': 1.303,
#   'home_avg_goals_against': 1.016,
#   'home_avg_goals_difference': 0.287,
#   'away_games': 188,
#   'away_wins': 34,
#   'away_draws': 62,
#   'away_losses': 92,
#   'away_win_percentage': 0.181,
#   'away_draw_percentage': 0.33,
#   'away_loss_percentage': 0.489,
#   'away_goals_scored': 168,
#   'away_goals_against': 282,
#   'away_goals_difference': -114,
#   'away_avg_goals_scored': 0.894,
#   'away_avg_goals_against': 1.5,
#   'away_avg_goals_difference': -0.606},
#  {'name': 'Celta de Vigo',
#   'total_games': 880,
#   'wins': 319,
#   'draws': 239,
#   'losses': 322,
#   'win_percentage': 0.362,
#   'draw_percentage': 0.272,
#   'loss_percentage': 0.366,
#   'goals_scored': 1142,
#   'goals_against': 1143,
#   'goals_difference': -1,
#   'avg_goals_scored': 1.298,
#   'avg_goals_against': 1.299,
#   'avg_goals_difference': -0.001,
#   'home_games': 440,
#   'home_wins': 187,
#   'home_draws': 125,
#   'home_losses': 128,
#   'home_win_percentage': 0.425,
#   'home_draw_percentage': 0.284,
#   'home_loss_percentage': 0.291,
#   'home_goals_scored': 629,
#   'home_goals_against': 510,
#   'home_goals_difference': 119,
#   'home_avg_goals_scored': 1.43,
#   'home_avg_goals_against': 1.159,
#   'home_avg_goals_difference': 0.27,
#   'away_games': 440,
#   'away_wins': 132,
#   'away_draws': 114,
#   'away_losses': 194,
#   'away_win_percentage': 0.3,
#   'away_draw_percentage': 0.259,
#   'away_loss_percentage': 0.441,
#   'away_goals_scored': 513,
#   'away_goals_against': 633,
#   'away_goals_difference': -120,
#   'away_avg_goals_scored': 1.166,
#   'away_avg_goals_against': 1.439,
#   'away_avg_goals_difference': -0.273},
#  {'name': 'Detroit City FC',
#   'total_games': 35,
#   'wins': 14,
#   'draws': 12,
#   'losses': 9,
#   'win_percentage': 0.4,
#   'draw_percentage': 0.343,
#   'loss_percentage': 0.257,
#   'goals_scored': 45,
#   'goals_against': 33,
#   'goals_difference': 12,
#   'avg_goals_scored': 1.286,
#   'avg_goals_against': 0.943,
#   'avg_goals_difference': 0.343,
#   'home_games': 17,
#   'home_wins': 6,
#   'home_draws': 8,
#   'home_losses': 3,
#   'home_win_percentage': 0.353,
#   'home_draw_percentage': 0.471,
#   'home_loss_percentage': 0.176,
#   'home_goals_scored': 21,
#   'home_goals_against': 16,
#   'home_goals_difference': 5,
#   'home_avg_goals_scored': 1.235,
#   'home_avg_goals_against': 0.941,
#   'home_avg_goals_difference': 0.294,
#   'away_games': 18,
#   'away_wins': 8,
#   'away_draws': 4,
#   'away_losses': 6,
#   'away_win_percentage': 0.444,
#   'away_draw_percentage': 0.222,
#   'away_loss_percentage': 0.333,
#   'away_goals_scored': 24,
#   'away_goals_against': 17,
#   'away_goals_difference': 7,
#   'away_avg_goals_scored': 1.333,
#   'away_avg_goals_against': 0.944,
#   'away_avg_goals_difference': 0.389},
#  {'name': 'AS Lyon-Duchere',
#   'total_games': 100,
#   'wins': 37,
#   'draws': 31,
#   'losses': 32,
#   'win_percentage': 0.37,
#   'draw_percentage': 0.31,
#   'loss_percentage': 0.32,
#   'goals_scored': 113,
#   'goals_against': 112,
#   'goals_difference': 1,
#   'avg_goals_scored': 1.13,
#   'avg_goals_against': 1.12,
#   'avg_goals_difference': 0.01,
#   'home_games': 50,
#   'home_wins': 20,
#   'home_draws': 18,
#   'home_losses': 12,
#   'home_win_percentage': 0.4,
#   'home_draw_percentage': 0.36,
#   'home_loss_percentage': 0.24,
#   'home_goals_scored': 61,
#   'home_goals_against': 48,
#   'home_goals_difference': 13,
#   'home_avg_goals_scored': 1.22,
#   'home_avg_goals_against': 0.96,
#   'home_avg_goals_difference': 0.26,
#   'away_games': 50,
#   'away_wins': 17,
#   'away_draws': 13,
#   'away_losses': 20,
#   'away_win_percentage': 0.34,
#   'away_draw_percentage': 0.26,
#   'away_loss_percentage': 0.4,
#   'away_goals_scored': 52,
#   'away_goals_against': 64,
#   'away_goals_difference': -12,
#   'away_avg_goals_scored': 1.04,
#   'away_avg_goals_against': 1.28,
#   'away_avg_goals_difference': -0.24},
#  {'name': 'Grimsby',
#   'total_games': 1026,
#   'wins': 360,
#   'draws': 274,
#   'losses': 392,
#   'win_percentage': 0.351,
#   'draw_percentage': 0.267,
#   'loss_percentage': 0.382,
#   'goals_scored': 1286,
#   'goals_against': 1349,
#   'goals_difference': -63,
#   'avg_goals_scored': 1.253,
#   'avg_goals_against': 1.315,
#   'avg_goals_difference': -0.061,
#   'home_games': 512,
#   'home_wins': 206,
#   'home_draws': 137,
#   'home_losses': 169,
#   'home_win_percentage': 0.402,
#   'home_draw_percentage': 0.268,
#   'home_loss_percentage': 0.33,
#   'home_goals_scored': 720,
#   'home_goals_against': 594,
#   'home_goals_difference': 126,
#   'home_avg_goals_scored': 1.406,
#   'home_avg_goals_against': 1.16,
#   'home_avg_goals_difference': 0.246,
#   'away_games': 514,
#   'away_wins': 154,
#   'away_draws': 137,
#   'away_losses': 223,
#   'away_win_percentage': 0.3,
#   'away_draw_percentage': 0.267,
#   'away_loss_percentage': 0.434,
#   'away_goals_scored': 566,
#   'away_goals_against': 755,
#   'away_goals_difference': -189,
#   'away_avg_goals_scored': 1.101,
#   'away_avg_goals_against': 1.469,
#   'away_avg_goals_difference': -0.368},
#  {'name': 'Dordrecht',
#   'total_games': 34,
#   'wins': 4,
#   'draws': 8,
#   'losses': 22,
#   'win_percentage': 0.118,
#   'draw_percentage': 0.235,
#   'loss_percentage': 0.647,
#   'goals_scored': 24,
#   'goals_against': 76,
#   'goals_difference': -52,
#   'avg_goals_scored': 0.706,
#   'avg_goals_against': 2.235,
#   'avg_goals_difference': -1.529,
#   'home_games': 17,
#   'home_wins': 3,
#   'home_draws': 4,
#   'home_losses': 10,
#   'home_win_percentage': 0.176,
#   'home_draw_percentage': 0.235,
#   'home_loss_percentage': 0.588,
#   'home_goals_scored': 15,
#   'home_goals_against': 34,
#   'home_goals_difference': -19,
#   'home_avg_goals_scored': 0.882,
#   'home_avg_goals_against': 2.0,
#   'home_avg_goals_difference': -1.118,
#   'away_games': 17,
#   'away_wins': 1,
#   'away_draws': 4,
#   'away_losses': 12,
#   'away_win_percentage': 0.059,
#   'away_draw_percentage': 0.235,
#   'away_loss_percentage': 0.706,
#   'away_goals_scored': 9,
#   'away_goals_against': 42,
#   'away_goals_difference': -33,
#   'away_avg_goals_scored': 0.529,
#   'away_avg_goals_against': 2.471,
#   'away_avg_goals_difference': -1.941},
#  {'name': 'Sandefjord Fotball',
#   'total_games': 210,
#   'wins': 50,
#   'draws': 48,
#   'losses': 112,
#   'win_percentage': 0.238,
#   'draw_percentage': 0.229,
#   'loss_percentage': 0.533,
#   'goals_scored': 242,
#   'goals_against': 373,
#   'goals_difference': -131,
#   'avg_goals_scored': 1.152,
#   'avg_goals_against': 1.776,
#   'avg_goals_difference': -0.624,
#   'home_games': 105,
#   'home_wins': 32,
#   'home_draws': 28,
#   'home_losses': 45,
#   'home_win_percentage': 0.305,
#   'home_draw_percentage': 0.267,
#   'home_loss_percentage': 0.429,
#   'home_goals_scored': 131,
#   'home_goals_against': 147,
#   'home_goals_difference': -16,
#   'home_avg_goals_scored': 1.248,
#   'home_avg_goals_against': 1.4,
#   'home_avg_goals_difference': -0.152,
#   'away_games': 105,
#   'away_wins': 18,
#   'away_draws': 20,
#   'away_losses': 67,
#   'away_win_percentage': 0.171,
#   'away_draw_percentage': 0.19,
#   'away_loss_percentage': 0.638,
#   'away_goals_scored': 111,
#   'away_goals_against': 226,
#   'away_goals_difference': -115,
#   'away_avg_goals_scored': 1.057,
#   'away_avg_goals_against': 2.152,
#   'away_avg_goals_difference': -1.095},
#  {'name': 'Gyeongnam FC',
#   'total_games': 360,
#   'wins': 118,
#   'draws': 103,
#   'losses': 139,
#   'win_percentage': 0.328,
#   'draw_percentage': 0.286,
#   'loss_percentage': 0.386,
#   'goals_scored': 442,
#   'goals_against': 479,
#   'goals_difference': -37,
#   'avg_goals_scored': 1.228,
#   'avg_goals_against': 1.331,
#   'avg_goals_difference': -0.103,
#   'home_games': 181,
#   'home_wins': 72,
#   'home_draws': 54,
#   'home_losses': 55,
#   'home_win_percentage': 0.398,
#   'home_draw_percentage': 0.298,
#   'home_loss_percentage': 0.304,
#   'home_goals_scored': 242,
#   'home_goals_against': 207,
#   'home_goals_difference': 35,
#   'home_avg_goals_scored': 1.337,
#   'home_avg_goals_against': 1.144,
#   'home_avg_goals_difference': 0.193,
#   'away_games': 179,
#   'away_wins': 46,
#   'away_draws': 49,
#   'away_losses': 84,
#   'away_win_percentage': 0.257,
#   'away_draw_percentage': 0.274,
#   'away_loss_percentage': 0.469,
#   'away_goals_scored': 200,
#   'away_goals_against': 272,
#   'away_goals_difference': -72,
#   'away_avg_goals_scored': 1.117,
#   'away_avg_goals_against': 1.52,
#   'away_avg_goals_difference': -0.402},
#  {'name': 'Gillingham',
#   'total_games': 1028,
#   'wins': 344,
#   'draws': 288,
#   'losses': 396,
#   'win_percentage': 0.335,
#   'draw_percentage': 0.28,
#   'loss_percentage': 0.385,
#   'goals_scored': 1263,
#   'goals_against': 1423,
#   'goals_difference': -160,
#   'avg_goals_scored': 1.229,
#   'avg_goals_against': 1.384,
#   'avg_goals_difference': -0.156,
#   'home_games': 513,
#   'home_wins': 227,
#   'home_draws': 129,
#   'home_losses': 157,
#   'home_win_percentage': 0.442,
#   'home_draw_percentage': 0.251,
#   'home_loss_percentage': 0.306,
#   'home_goals_scored': 698,
#   'home_goals_against': 588,
#   'home_goals_difference': 110,
#   'home_avg_goals_scored': 1.361,
#   'home_avg_goals_against': 1.146,
#   'home_avg_goals_difference': 0.214,
#   'away_games': 515,
#   'away_wins': 117,
#   'away_draws': 159,
#   'away_losses': 239,
#   'away_win_percentage': 0.227,
#   'away_draw_percentage': 0.309,
#   'away_loss_percentage': 0.464,
#   'away_goals_scored': 565,
#   'away_goals_against': 835,
#   'away_goals_difference': -270,
#   'away_avg_goals_scored': 1.097,
#   'away_avg_goals_against': 1.621,
#   'away_avg_goals_difference': -0.524},
#  {'name': 'Viktoria Koln',
#   'total_games': 133,
#   'wins': 46,
#   'draws': 37,
#   'losses': 50,
#   'win_percentage': 0.346,
#   'draw_percentage': 0.278,
#   'loss_percentage': 0.376,
#   'goals_scored': 186,
#   'goals_against': 212,
#   'goals_difference': -26,
#   'avg_goals_scored': 1.398,
#   'avg_goals_against': 1.594,
#   'avg_goals_difference': -0.195,
#   'home_games': 66,
#   'home_wins': 25,
#   'home_draws': 16,
#   'home_losses': 25,
#   'home_win_percentage': 0.379,
#   'home_draw_percentage': 0.242,
#   'home_loss_percentage': 0.379,
#   'home_goals_scored': 97,
#   'home_goals_against': 100,
#   'home_goals_difference': -3,
#   'home_avg_goals_scored': 1.47,
#   'home_avg_goals_against': 1.515,
#   'home_avg_goals_difference': -0.045,
#   'away_games': 67,
#   'away_wins': 21,
#   'away_draws': 21,
#   'away_losses': 25,
#   'away_win_percentage': 0.313,
#   'away_draw_percentage': 0.313,
#   'away_loss_percentage': 0.373,
#   'away_goals_scored': 89,
#   'away_goals_against': 112,
#   'away_goals_difference': -23,
#   'away_avg_goals_scored': 1.328,
#   'away_avg_goals_against': 1.672,
#   'away_avg_goals_difference': -0.343},
#  {'name': 'Venezia',
#   'total_games': 418,
#   'wins': 119,
#   'draws': 137,
#   'losses': 162,
#   'win_percentage': 0.285,
#   'draw_percentage': 0.328,
#   'loss_percentage': 0.388,
#   'goals_scored': 450,
#   'goals_against': 540,
#   'goals_difference': -90,
#   'avg_goals_scored': 1.077,
#   'avg_goals_against': 1.292,
#   'avg_goals_difference': -0.215,
#   'home_games': 210,
#   'home_wins': 76,
#   'home_draws': 65,
#   'home_losses': 69,
#   'home_win_percentage': 0.362,
#   'home_draw_percentage': 0.31,
#   'home_loss_percentage': 0.329,
#   'home_goals_scored': 257,
#   'home_goals_against': 257,
#   'home_goals_difference': 0,
#   'home_avg_goals_scored': 1.224,
#   'home_avg_goals_against': 1.224,
#   'home_avg_goals_difference': 0.0,
#   'away_games': 208,
#   'away_wins': 43,
#   'away_draws': 72,
#   'away_losses': 93,
#   'away_win_percentage': 0.207,
#   'away_draw_percentage': 0.346,
#   'away_loss_percentage': 0.447,
#   'away_goals_scored': 193,
#   'away_goals_against': 283,
#   'away_goals_difference': -90,
#   'away_avg_goals_scored': 0.928,
#   'away_avg_goals_against': 1.361,
#   'away_avg_goals_difference': -0.433},
#  {'name': 'Lobos',
#   'total_games': 68,
#   'wins': 20,
#   'draws': 11,
#   'losses': 37,
#   'win_percentage': 0.294,
#   'draw_percentage': 0.162,
#   'loss_percentage': 0.544,
#   'goals_scored': 82,
#   'goals_against': 123,
#   'goals_difference': -41,
#   'avg_goals_scored': 1.206,
#   'avg_goals_against': 1.809,
#   'avg_goals_difference': -0.603,
#   'home_games': 34,
#   'home_wins': 12,
#   'home_draws': 6,
#   'home_losses': 16,
#   'home_win_percentage': 0.353,
#   'home_draw_percentage': 0.176,
#   'home_loss_percentage': 0.471,
#   'home_goals_scored': 47,
#   'home_goals_against': 50,
#   'home_goals_difference': -3,
#   'home_avg_goals_scored': 1.382,
#   'home_avg_goals_against': 1.471,
#   'home_avg_goals_difference': -0.088,
#   'away_games': 34,
#   'away_wins': 8,
#   'away_draws': 5,
#   'away_losses': 21,
#   'away_win_percentage': 0.235,
#   'away_draw_percentage': 0.147,
#   'away_loss_percentage': 0.618,
#   'away_goals_scored': 35,
#   'away_goals_against': 73,
#   'away_goals_difference': -38,
#   'away_avg_goals_scored': 1.029,
#   'away_avg_goals_against': 2.147,
#   'away_avg_goals_difference': -1.118},
#  {'name': 'SCR Altach',
#   'total_games': 387,
#   'wins': 115,
#   'draws': 86,
#   'losses': 186,
#   'win_percentage': 0.297,
#   'draw_percentage': 0.222,
#   'loss_percentage': 0.481,
#   'goals_scored': 464,
#   'goals_against': 641,
#   'goals_difference': -177,
#   'avg_goals_scored': 1.199,
#   'avg_goals_against': 1.656,
#   'avg_goals_difference': -0.457,
#   'home_games': 193,
#   'home_wins': 73,
#   'home_draws': 45,
#   'home_losses': 75,
#   'home_win_percentage': 0.378,
#   'home_draw_percentage': 0.233,
#   'home_loss_percentage': 0.389,
#   'home_goals_scored': 271,
#   'home_goals_against': 269,
#   'home_goals_difference': 2,
#   'home_avg_goals_scored': 1.404,
#   'home_avg_goals_against': 1.394,
#   'home_avg_goals_difference': 0.01,
#   'away_games': 194,
#   'away_wins': 42,
#   'away_draws': 41,
#   'away_losses': 111,
#   'away_win_percentage': 0.216,
#   'away_draw_percentage': 0.211,
#   'away_loss_percentage': 0.572,
#   'away_goals_scored': 193,
#   'away_goals_against': 372,
#   'away_goals_difference': -179,
#   'away_avg_goals_scored': 0.995,
#   'away_avg_goals_against': 1.918,
#   'away_avg_goals_difference': -0.923},
#  {'name': 'CD Provincial Osorno',
#   'total_games': 37,
#   'wins': 8,
#   'draws': 2,
#   'losses': 27,
#   'win_percentage': 0.216,
#   'draw_percentage': 0.054,
#   'loss_percentage': 0.73,
#   'goals_scored': 38,
#   'goals_against': 77,
#   'goals_difference': -39,
#   'avg_goals_scored': 1.027,
#   'avg_goals_against': 2.081,
#   'avg_goals_difference': -1.054,
#   'home_games': 19,
#   'home_wins': 6,
#   'home_draws': 1,
#   'home_losses': 12,
#   'home_win_percentage': 0.316,
#   'home_draw_percentage': 0.053,
#   'home_loss_percentage': 0.632,
#   'home_goals_scored': 25,
#   'home_goals_against': 35,
#   'home_goals_difference': -10,
#   'home_avg_goals_scored': 1.316,
#   'home_avg_goals_against': 1.842,
#   'home_avg_goals_difference': -0.526,
#   'away_games': 18,
#   'away_wins': 2,
#   'away_draws': 1,
#   'away_losses': 15,
#   'away_win_percentage': 0.111,
#   'away_draw_percentage': 0.056,
#   'away_loss_percentage': 0.833,
#   'away_goals_scored': 13,
#   'away_goals_against': 42,
#   'away_goals_difference': -29,
#   'away_avg_goals_scored': 0.722,
#   'away_avg_goals_against': 2.333,
#   'away_avg_goals_difference': -1.611},
#  {'name': 'Blaublitz',
#   'total_games': 84,
#   'wins': 26,
#   'draws': 25,
#   'losses': 33,
#   'win_percentage': 0.31,
#   'draw_percentage': 0.298,
#   'loss_percentage': 0.393,
#   'goals_scored': 80,
#   'goals_against': 99,
#   'goals_difference': -19,
#   'avg_goals_scored': 0.952,
#   'avg_goals_against': 1.179,
#   'avg_goals_difference': -0.226,
#   'home_games': 42,
#   'home_wins': 9,
#   'home_draws': 17,
#   'home_losses': 16,
#   'home_win_percentage': 0.214,
#   'home_draw_percentage': 0.405,
#   'home_loss_percentage': 0.381,
#   'home_goals_scored': 34,
#   'home_goals_against': 49,
#   'home_goals_difference': -15,
#   'home_avg_goals_scored': 0.81,
#   'home_avg_goals_against': 1.167,
#   'home_avg_goals_difference': -0.357,
#   'away_games': 42,
#   'away_wins': 17,
#   'away_draws': 8,
#   'away_losses': 17,
#   'away_win_percentage': 0.405,
#   'away_draw_percentage': 0.19,
#   'away_loss_percentage': 0.405,
#   'away_goals_scored': 46,
#   'away_goals_against': 50,
#   'away_goals_difference': -4,
#   'away_avg_goals_scored': 1.095,
#   'away_avg_goals_against': 1.19,
#   'away_avg_goals_difference': -0.095},
#  {'name': 'Rochester Rhinos',
#   'total_games': 34,
#   'wins': 15,
#   'draws': 11,
#   'losses': 8,
#   'win_percentage': 0.441,
#   'draw_percentage': 0.324,
#   'loss_percentage': 0.235,
#   'goals_scored': 38,
#   'goals_against': 30,
#   'goals_difference': 8,
#   'avg_goals_scored': 1.118,
#   'avg_goals_against': 0.882,
#   'avg_goals_difference': 0.235,
#   'home_games': 17,
#   'home_wins': 10,
#   'home_draws': 5,
#   'home_losses': 2,
#   'home_win_percentage': 0.588,
#   'home_draw_percentage': 0.294,
#   'home_loss_percentage': 0.118,
#   'home_goals_scored': 21,
#   'home_goals_against': 9,
#   'home_goals_difference': 12,
#   'home_avg_goals_scored': 1.235,
#   'home_avg_goals_against': 0.529,
#   'home_avg_goals_difference': 0.706,
#   'away_games': 17,
#   'away_wins': 5,
#   'away_draws': 6,
#   'away_losses': 6,
#   'away_win_percentage': 0.294,
#   'away_draw_percentage': 0.353,
#   'away_loss_percentage': 0.353,
#   'away_goals_scored': 17,
#   'away_goals_against': 21,
#   'away_goals_difference': -4,
#   'away_avg_goals_scored': 1.0,
#   'away_avg_goals_against': 1.235,
#   'away_avg_goals_difference': -0.235},
#  {'name': 'Pacos Ferreira',
#   'total_games': 668,
#   'wins': 203,
#   'draws': 187,
#   'losses': 278,
#   'win_percentage': 0.304,
#   'draw_percentage': 0.28,
#   'loss_percentage': 0.416,
#   'goals_scored': 729,
#   'goals_against': 943,
#   'goals_difference': -214,
#   'avg_goals_scored': 1.091,
#   'avg_goals_against': 1.412,
#   'avg_goals_difference': -0.32,
#   'home_games': 335,
#   'home_wins': 131,
#   'home_draws': 100,
#   'home_losses': 104,
#   'home_win_percentage': 0.391,
#   'home_draw_percentage': 0.299,
#   'home_loss_percentage': 0.31,
#   'home_goals_scored': 414,
#   'home_goals_against': 406,
#   'home_goals_difference': 8,
#   'home_avg_goals_scored': 1.236,
#   'home_avg_goals_against': 1.212,
#   'home_avg_goals_difference': 0.024,
#   'away_games': 333,
#   'away_wins': 72,
#   'away_draws': 87,
#   'away_losses': 174,
#   'away_win_percentage': 0.216,
#   'away_draw_percentage': 0.261,
#   'away_loss_percentage': 0.523,
#   'away_goals_scored': 315,
#   'away_goals_against': 537,
#   'away_goals_difference': -222,
#   'away_avg_goals_scored': 0.946,
#   'away_avg_goals_against': 1.613,
#   'away_avg_goals_difference': -0.667},
#  {'name': 'Neuchatel Xamax',
#   'total_games': 406,
#   'wins': 109,
#   'draws': 100,
#   'losses': 197,
#   'win_percentage': 0.268,
#   'draw_percentage': 0.246,
#   'loss_percentage': 0.485,
#   'goals_scored': 498,
#   'goals_against': 694,
#   'goals_difference': -196,
#   'avg_goals_scored': 1.227,
#   'avg_goals_against': 1.709,
#   'avg_goals_difference': -0.483,
#   'home_games': 203,
#   'home_wins': 74,
#   'home_draws': 50,
#   'home_losses': 79,
#   'home_win_percentage': 0.365,
#   'home_draw_percentage': 0.246,
#   'home_loss_percentage': 0.389,
#   'home_goals_scored': 302,
#   'home_goals_against': 303,
#   'home_goals_difference': -1,
#   'home_avg_goals_scored': 1.488,
#   'home_avg_goals_against': 1.493,
#   'home_avg_goals_difference': -0.005,
#   'away_games': 203,
#   'away_wins': 35,
#   'away_draws': 50,
#   'away_losses': 118,
#   'away_win_percentage': 0.172,
#   'away_draw_percentage': 0.246,
#   'away_loss_percentage': 0.581,
#   'away_goals_scored': 196,
#   'away_goals_against': 391,
#   'away_goals_difference': -195,
#   'away_avg_goals_scored': 0.966,
#   'away_avg_goals_against': 1.926,
#   'away_avg_goals_difference': -0.961},
#  {'name': 'Cordoba',
#   'total_games': 709,
#   'wins': 223,
#   'draws': 203,
#   'losses': 283,
#   'win_percentage': 0.315,
#   'draw_percentage': 0.286,
#   'loss_percentage': 0.399,
#   'goals_scored': 777,
#   'goals_against': 902,
#   'goals_difference': -125,
#   'avg_goals_scored': 1.096,
#   'avg_goals_against': 1.272,
#   'avg_goals_difference': -0.176,
#   'home_games': 354,
#   'home_wins': 143,
#   'home_draws': 103,
#   'home_losses': 108,
#   'home_win_percentage': 0.404,
#   'home_draw_percentage': 0.291,
#   'home_loss_percentage': 0.305,
#   'home_goals_scored': 465,
#   'home_goals_against': 391,
#   'home_goals_difference': 74,
#   'home_avg_goals_scored': 1.314,
#   'home_avg_goals_against': 1.105,
#   'home_avg_goals_difference': 0.209,
#   'away_games': 355,
#   'away_wins': 80,
#   'away_draws': 100,
#   'away_losses': 175,
#   'away_win_percentage': 0.225,
#   'away_draw_percentage': 0.282,
#   'away_loss_percentage': 0.493,
#   'away_goals_scored': 312,
#   'away_goals_against': 511,
#   'away_goals_difference': -199,
#   'away_avg_goals_scored': 0.879,
#   'away_avg_goals_against': 1.439,
#   'away_avg_goals_difference': -0.561},
#  {'name': 'USM Bel Abbes',
#   'total_games': 209,
#   'wins': 65,
#   'draws': 50,
#   'losses': 94,
#   'win_percentage': 0.311,
#   'draw_percentage': 0.239,
#   'loss_percentage': 0.45,
#   'goals_scored': 184,
#   'goals_against': 265,
#   'goals_difference': -81,
#   'avg_goals_scored': 0.88,
#   'avg_goals_against': 1.268,
#   'avg_goals_difference': -0.388,
#   'home_games': 104,
#   'home_wins': 48,
#   'home_draws': 26,
#   'home_losses': 30,
#   'home_win_percentage': 0.462,
#   'home_draw_percentage': 0.25,
#   'home_loss_percentage': 0.288,
#   'home_goals_scored': 117,
#   'home_goals_against': 100,
#   'home_goals_difference': 17,
#   'home_avg_goals_scored': 1.125,
#   'home_avg_goals_against': 0.962,
#   'home_avg_goals_difference': 0.163,
#   'away_games': 105,
#   'away_wins': 17,
#   'away_draws': 24,
#   'away_losses': 64,
#   'away_win_percentage': 0.162,
#   'away_draw_percentage': 0.229,
#   'away_loss_percentage': 0.61,
#   'away_goals_scored': 67,
#   'away_goals_against': 165,
#   'away_goals_difference': -98,
#   'away_avg_goals_scored': 0.638,
#   'away_avg_goals_against': 1.571,
#   'away_avg_goals_difference': -0.933},
#  {'name': 'Universidad Central FC',
#   'total_games': 55,
#   'wins': 14,
#   'draws': 17,
#   'losses': 24,
#   'win_percentage': 0.255,
#   'draw_percentage': 0.309,
#   'loss_percentage': 0.436,
#   'goals_scored': 52,
#   'goals_against': 71,
#   'goals_difference': -19,
#   'avg_goals_scored': 0.945,
#   'avg_goals_against': 1.291,
#   'avg_goals_difference': -0.345,
#   'home_games': 27,
#   'home_wins': 10,
#   'home_draws': 9,
#   'home_losses': 8,
#   'home_win_percentage': 0.37,
#   'home_draw_percentage': 0.333,
#   'home_loss_percentage': 0.296,
#   'home_goals_scored': 34,
#   'home_goals_against': 26,
#   'home_goals_difference': 8,
#   'home_avg_goals_scored': 1.259,
#   'home_avg_goals_against': 0.963,
#   'home_avg_goals_difference': 0.296,
#   'away_games': 28,
#   'away_wins': 4,
#   'away_draws': 8,
#   'away_losses': 16,
#   'away_win_percentage': 0.143,
#   'away_draw_percentage': 0.286,
#   'away_loss_percentage': 0.571,
#   'away_goals_scored': 18,
#   'away_goals_against': 45,
#   'away_goals_difference': -27,
#   'away_avg_goals_scored': 0.643,
#   'away_avg_goals_against': 1.607,
#   'away_avg_goals_difference': -0.964},
#  {'name': 'Eastern Pride',
#   'total_games': 28,
#   'wins': 3,
#   'draws': 5,
#   'losses': 20,
#   'win_percentage': 0.107,
#   'draw_percentage': 0.179,
#   'loss_percentage': 0.714,
#   'goals_scored': 26,
#   'goals_against': 61,
#   'goals_difference': -35,
#   'avg_goals_scored': 0.929,
#   'avg_goals_against': 2.179,
#   'avg_goals_difference': -1.25,
#   'home_games': 14,
#   'home_wins': 2,
#   'home_draws': 5,
#   'home_losses': 7,
#   'home_win_percentage': 0.143,
#   'home_draw_percentage': 0.357,
#   'home_loss_percentage': 0.5,
#   'home_goals_scored': 14,
#   'home_goals_against': 25,
#   'home_goals_difference': -11,
#   'home_avg_goals_scored': 1.0,
#   'home_avg_goals_against': 1.786,
#   'home_avg_goals_difference': -0.786,
#   'away_games': 14,
#   'away_wins': 1,
#   'away_draws': 0,
#   'away_losses': 13,
#   'away_win_percentage': 0.071,
#   'away_draw_percentage': 0.0,
#   'away_loss_percentage': 0.929,
#   'away_goals_scored': 12,
#   'away_goals_against': 36,
#   'away_goals_difference': -24,
#   'away_avg_goals_scored': 0.857,
#   'away_avg_goals_against': 2.571,
#   'away_avg_goals_difference': -1.714},
#  {'name': 'FC Basel',
#   'total_games': 765,
#   'wins': 450,
#   'draws': 184,
#   'losses': 131,
#   'win_percentage': 0.588,
#   'draw_percentage': 0.241,
#   'loss_percentage': 0.171,
#   'goals_scored': 1637,
#   'goals_against': 878,
#   'goals_difference': 759,
#   'avg_goals_scored': 2.14,
#   'avg_goals_against': 1.148,
#   'avg_goals_difference': 0.992,
#   'home_games': 382,
#   'home_wins': 263,
#   'home_draws': 82,
#   'home_losses': 37,
#   'home_win_percentage': 0.688,
#   'home_draw_percentage': 0.215,
#   'home_loss_percentage': 0.097,
#   'home_goals_scored': 930,
#   'home_goals_against': 373,
#   'home_goals_difference': 557,
#   'home_avg_goals_scored': 2.435,
#   'home_avg_goals_against': 0.976,
#   'home_avg_goals_difference': 1.458,
#   'away_games': 383,
#   'away_wins': 187,
#   'away_draws': 102,
#   'away_losses': 94,
#   'away_win_percentage': 0.488,
#   'away_draw_percentage': 0.266,
#   'away_loss_percentage': 0.245,
#   'away_goals_scored': 707,
#   'away_goals_against': 505,
#   'away_goals_difference': 202,
#   'away_avg_goals_scored': 1.846,
#   'away_avg_goals_against': 1.319,
#   'away_avg_goals_difference': 0.527},
#  {'name': 'Queensland Roar',
#   'total_games': 84,
#   'wins': 33,
#   'draws': 25,
#   'losses': 26,
#   'win_percentage': 0.393,
#   'draw_percentage': 0.298,
#   'loss_percentage': 0.31,
#   'goals_scored': 113,
#   'goals_against': 95,
#   'goals_difference': 18,
#   'avg_goals_scored': 1.345,
#   'avg_goals_against': 1.131,
#   'avg_goals_difference': 0.214,
#   'home_games': 42,
#   'home_wins': 14,
#   'home_draws': 12,
#   'home_losses': 16,
#   'home_win_percentage': 0.333,
#   'home_draw_percentage': 0.286,
#   'home_loss_percentage': 0.381,
#   'home_goals_scored': 55,
#   'home_goals_against': 49,
#   'home_goals_difference': 6,
#   'home_avg_goals_scored': 1.31,
#   'home_avg_goals_against': 1.167,
#   'home_avg_goals_difference': 0.143,
#   'away_games': 42,
#   'away_wins': 19,
#   'away_draws': 13,
#   'away_losses': 10,
#   'away_win_percentage': 0.452,
#   'away_draw_percentage': 0.31,
#   'away_loss_percentage': 0.238,
#   'away_goals_scored': 58,
#   'away_goals_against': 46,
#   'away_goals_difference': 12,
#   'away_avg_goals_scored': 1.381,
#   'away_avg_goals_against': 1.095,
#   'away_avg_goals_difference': 0.286},
#  {'name': 'YoungHeart Manawatu',
#   'total_games': 112,
#   'wins': 33,
#   'draws': 15,
#   'losses': 64,
#   'win_percentage': 0.295,
#   'draw_percentage': 0.134,
#   'loss_percentage': 0.571,
#   'goals_scored': 177,
#   'goals_against': 279,
#   'goals_difference': -102,
#   'avg_goals_scored': 1.58,
#   'avg_goals_against': 2.491,
#   'avg_goals_difference': -0.911,
#   'home_games': 56,
#   'home_wins': 17,
#   'home_draws': 5,
#   'home_losses': 34,
#   'home_win_percentage': 0.304,
#   'home_draw_percentage': 0.089,
#   'home_loss_percentage': 0.607,
#   'home_goals_scored': 87,
#   'home_goals_against': 139,
#   'home_goals_difference': -52,
#   'home_avg_goals_scored': 1.554,
#   'home_avg_goals_against': 2.482,
#   'home_avg_goals_difference': -0.929,
#   'away_games': 56,
#   'away_wins': 16,
#   'away_draws': 10,
#   'away_losses': 30,
#   'away_win_percentage': 0.286,
#   'away_draw_percentage': 0.179,
#   'away_loss_percentage': 0.536,
#   'away_goals_scored': 90,
#   'away_goals_against': 140,
#   'away_goals_difference': -50,
#   'away_avg_goals_scored': 1.607,
#   'away_avg_goals_against': 2.5,
# ...
#   'home_wins': 109,
#   'home_draws': 77,
#   'home_losses': 60,
#   'home_win_percentage': 0.443,
#   'home_draw_percentage': 0.313,
#   'home_loss_percentage': 0.244,
#   'home_goals_scored': 313,
#   'home_goals_against': 238,
#   'home_goals_difference': 75,
#   'home_avg_goals_scored': 1.272,
#   'home_avg_goals_against': 0.967,
#   'home_avg_goals_difference': 0.305,
#   'away_games': 250,
#   'away_wins': 71,
#   'away_draws': 86,
#   'away_losses': 93,
#   'away_win_percentage': 0.284,
#   'away_draw_percentage': 0.344,
#   'away_loss_percentage': 0.372,
#   'away_goals_scored': 233,
#   'away_goals_against': 272,
#   'away_goals_difference': -39,
#   'away_avg_goals_scored': 0.932,
#   'away_avg_goals_against': 1.088,
#   'away_avg_goals_difference': -0.156},
#  {'name': 'Hartford Athletic',
#   'total_games': 117,
#   'wins': 41,
#   'draws': 18,
#   'losses': 58,
#   'win_percentage': 0.35,
#   'draw_percentage': 0.154,
#   'loss_percentage': 0.496,
#   'goals_scored': 177,
#   'goals_against': 212,
#   'goals_difference': -35,
#   'avg_goals_scored': 1.513,
#   'avg_goals_against': 1.812,
#   'avg_goals_difference': -0.299,
#   'home_games': 60,
#   'home_wins': 27,
#   'home_draws': 9,
#   'home_losses': 24,
#   'home_win_percentage': 0.45,
#   'home_draw_percentage': 0.15,
#   'home_loss_percentage': 0.4,
#   'home_goals_scored': 110,
#   'home_goals_against': 93,
#   'home_goals_difference': 17,
#   'home_avg_goals_scored': 1.833,
#   'home_avg_goals_against': 1.55,
#   'home_avg_goals_difference': 0.283,
#   'away_games': 57,
#   'away_wins': 14,
#   'away_draws': 9,
#   'away_losses': 34,
#   'away_win_percentage': 0.246,
#   'away_draw_percentage': 0.158,
#   'away_loss_percentage': 0.596,
#   'away_goals_scored': 67,
#   'away_goals_against': 119,
#   'away_goals_difference': -52,
#   'away_avg_goals_scored': 1.175,
#   'away_avg_goals_against': 2.088,
#   'away_avg_goals_difference': -0.912},
#  {'name': 'Paris 13 Atletico',
#   'total_games': 19,
#   'wins': 3,
#   'draws': 8,
#   'losses': 8,
#   'win_percentage': 0.158,
#   'draw_percentage': 0.421,
#   'loss_percentage': 0.421,
#   'goals_scored': 15,
#   'goals_against': 20,
#   'goals_difference': -5,
#   'avg_goals_scored': 0.789,
#   'avg_goals_against': 1.053,
#   'avg_goals_difference': -0.263,
#   'home_games': 9,
#   'home_wins': 1,
#   'home_draws': 6,
#   'home_losses': 2,
#   'home_win_percentage': 0.111,
#   'home_draw_percentage': 0.667,
#   'home_loss_percentage': 0.222,
#   'home_goals_scored': 9,
#   'home_goals_against': 8,
#   'home_goals_difference': 1,
#   'home_avg_goals_scored': 1.0,
#   'home_avg_goals_against': 0.889,
#   'home_avg_goals_difference': 0.111,
#   'away_games': 10,
#   'away_wins': 2,
#   'away_draws': 2,
#   'away_losses': 6,
#   'away_win_percentage': 0.2,
#   'away_draw_percentage': 0.2,
#   'away_loss_percentage': 0.6,
#   'away_goals_scored': 6,
#   'away_goals_against': 12,
#   'away_goals_difference': -6,
#   'away_avg_goals_scored': 0.6,
#   'away_avg_goals_against': 1.2,
#   'away_avg_goals_difference': -0.6},
#  {'name': 'Wolfsberger AC',
#   'total_games': 362,
#   'wins': 128,
#   'draws': 82,
#   'losses': 152,
#   'win_percentage': 0.354,
#   'draw_percentage': 0.227,
#   'loss_percentage': 0.42,
#   'goals_scored': 497,
#   'goals_against': 565,
#   'goals_difference': -68,
#   'avg_goals_scored': 1.373,
#   'avg_goals_against': 1.561,
#   'avg_goals_difference': -0.188,
#   'home_games': 181,
#   'home_wins': 70,
#   'home_draws': 48,
#   'home_losses': 63,
#   'home_win_percentage': 0.387,
#   'home_draw_percentage': 0.265,
#   'home_loss_percentage': 0.348,
#   'home_goals_scored': 266,
#   'home_goals_against': 260,
#   'home_goals_difference': 6,
#   'home_avg_goals_scored': 1.47,
#   'home_avg_goals_against': 1.436,
#   'home_avg_goals_difference': 0.033,
#   'away_games': 181,
#   'away_wins': 58,
#   'away_draws': 34,
#   'away_losses': 89,
#   'away_win_percentage': 0.32,
#   'away_draw_percentage': 0.188,
#   'away_loss_percentage': 0.492,
#   'away_goals_scored': 231,
#   'away_goals_against': 305,
#   'away_goals_difference': -74,
#   'away_avg_goals_scored': 1.276,
#   'away_avg_goals_against': 1.685,
#   'away_avg_goals_difference': -0.409},
#  {'name': 'Consadole Sapporo',
#   'total_games': 274,
#   'wins': 103,
#   'draws': 56,
#   'losses': 115,
#   'win_percentage': 0.376,
#   'draw_percentage': 0.204,
#   'loss_percentage': 0.42,
#   'goals_scored': 330,
#   'goals_against': 359,
#   'goals_difference': -29,
#   'avg_goals_scored': 1.204,
#   'avg_goals_against': 1.31,
#   'avg_goals_difference': -0.106,
#   'home_games': 137,
#   'home_wins': 62,
#   'home_draws': 29,
#   'home_losses': 46,
#   'home_win_percentage': 0.453,
#   'home_draw_percentage': 0.212,
#   'home_loss_percentage': 0.336,
#   'home_goals_scored': 193,
#   'home_goals_against': 153,
#   'home_goals_difference': 40,
#   'home_avg_goals_scored': 1.409,
#   'home_avg_goals_against': 1.117,
#   'home_avg_goals_difference': 0.292,
#   'away_games': 137,
#   'away_wins': 41,
#   'away_draws': 27,
#   'away_losses': 69,
#   'away_win_percentage': 0.299,
#   'away_draw_percentage': 0.197,
#   'away_loss_percentage': 0.504,
#   'away_goals_scored': 137,
#   'away_goals_against': 206,
#   'away_goals_difference': -69,
#   'away_avg_goals_scored': 1.0,
#   'away_avg_goals_against': 1.504,
#   'away_avg_goals_difference': -0.504},
#  {'name': 'Clyde',
#   'total_games': 756,
#   'wins': 276,
#   'draws': 184,
#   'losses': 296,
#   'win_percentage': 0.365,
#   'draw_percentage': 0.243,
#   'loss_percentage': 0.392,
#   'goals_scored': 993,
#   'goals_against': 1070,
#   'goals_difference': -77,
#   'avg_goals_scored': 1.313,
#   'avg_goals_against': 1.415,
#   'avg_goals_difference': -0.102,
#   'home_games': 378,
#   'home_wins': 160,
#   'home_draws': 89,
#   'home_losses': 129,
#   'home_win_percentage': 0.423,
#   'home_draw_percentage': 0.235,
#   'home_loss_percentage': 0.341,
#   'home_goals_scored': 555,
#   'home_goals_against': 509,
#   'home_goals_difference': 46,
#   'home_avg_goals_scored': 1.468,
#   'home_avg_goals_against': 1.347,
#   'home_avg_goals_difference': 0.122,
#   'away_games': 378,
#   'away_wins': 116,
#   'away_draws': 95,
#   'away_losses': 167,
#   'away_win_percentage': 0.307,
#   'away_draw_percentage': 0.251,
#   'away_loss_percentage': 0.442,
#   'away_goals_scored': 438,
#   'away_goals_against': 561,
#   'away_goals_difference': -123,
#   'away_avg_goals_scored': 1.159,
#   'away_avg_goals_against': 1.484,
#   'away_avg_goals_difference': -0.325},
#  {'name': 'Niki Volou FC',
#   'total_games': 33,
#   'wins': 2,
#   'draws': 1,
#   'losses': 30,
#   'win_percentage': 0.061,
#   'draw_percentage': 0.03,
#   'loss_percentage': 0.909,
#   'goals_scored': 7,
#   'goals_against': 84,
#   'goals_difference': -77,
#   'avg_goals_scored': 0.212,
#   'avg_goals_against': 2.545,
#   'avg_goals_difference': -2.333,
#   'home_games': 16,
#   'home_wins': 2,
#   'home_draws': 1,
#   'home_losses': 13,
#   'home_win_percentage': 0.125,
#   'home_draw_percentage': 0.062,
#   'home_loss_percentage': 0.812,
#   'home_goals_scored': 4,
#   'home_goals_against': 37,
#   'home_goals_difference': -33,
#   'home_avg_goals_scored': 0.25,
#   'home_avg_goals_against': 2.312,
#   'home_avg_goals_difference': -2.062,
#   'away_games': 17,
#   'away_wins': 0,
#   'away_draws': 0,
#   'away_losses': 17,
#   'away_win_percentage': 0.0,
#   'away_draw_percentage': 0.0,
#   'away_loss_percentage': 1.0,
#   'away_goals_scored': 3,
#   'away_goals_against': 47,
#   'away_goals_difference': -44,
#   'away_avg_goals_scored': 0.176,
#   'away_avg_goals_against': 2.765,
#   'away_avg_goals_difference': -2.588},
#  {'name': 'Chippa United',
#   'total_games': 290,
#   'wins': 70,
#   'draws': 102,
#   'losses': 118,
#   'win_percentage': 0.241,
#   'draw_percentage': 0.352,
#   'loss_percentage': 0.407,
#   'goals_scored': 260,
#   'goals_against': 333,
#   'goals_difference': -73,
#   'avg_goals_scored': 0.897,
#   'avg_goals_against': 1.148,
#   'avg_goals_difference': -0.252,
#   'home_games': 144,
#   'home_wins': 41,
#   'home_draws': 60,
#   'home_losses': 43,
#   'home_win_percentage': 0.285,
#   'home_draw_percentage': 0.417,
#   'home_loss_percentage': 0.299,
#   'home_goals_scored': 146,
#   'home_goals_against': 142,
#   'home_goals_difference': 4,
#   'home_avg_goals_scored': 1.014,
#   'home_avg_goals_against': 0.986,
#   'home_avg_goals_difference': 0.028,
#   'away_games': 146,
#   'away_wins': 29,
#   'away_draws': 42,
#   'away_losses': 75,
#   'away_win_percentage': 0.199,
#   'away_draw_percentage': 0.288,
#   'away_loss_percentage': 0.514,
#   'away_goals_scored': 114,
#   'away_goals_against': 191,
#   'away_goals_difference': -77,
#   'away_avg_goals_scored': 0.781,
#   'away_avg_goals_against': 1.308,
#   'away_avg_goals_difference': -0.527},
#  {'name': 'Rayo Oklahoma City',
#   'total_games': 32,
#   'wins': 12,
#   'draws': 11,
#   'losses': 9,
#   'win_percentage': 0.375,
#   'draw_percentage': 0.344,
#   'loss_percentage': 0.281,
#   'goals_scored': 39,
#   'goals_against': 33,
#   'goals_difference': 6,
#   'avg_goals_scored': 1.219,
#   'avg_goals_against': 1.031,
#   'avg_goals_difference': 0.188,
#   'home_games': 16,
#   'home_wins': 6,
#   'home_draws': 6,
#   'home_losses': 4,
#   'home_win_percentage': 0.375,
#   'home_draw_percentage': 0.375,
#   'home_loss_percentage': 0.25,
#   'home_goals_scored': 25,
#   'home_goals_against': 20,
#   'home_goals_difference': 5,
#   'home_avg_goals_scored': 1.562,
#   'home_avg_goals_against': 1.25,
#   'home_avg_goals_difference': 0.312,
#   'away_games': 16,
#   'away_wins': 6,
#   'away_draws': 5,
#   'away_losses': 5,
#   'away_win_percentage': 0.375,
#   'away_draw_percentage': 0.312,
#   'away_loss_percentage': 0.312,
#   'away_goals_scored': 14,
#   'away_goals_against': 13,
#   'away_goals_difference': 1,
#   'away_avg_goals_scored': 0.875,
#   'away_avg_goals_against': 0.812,
#   'away_avg_goals_difference': 0.062},
#  {'name': 'FC Ufa',
#   'total_games': 328,
#   'wins': 95,
#   'draws': 105,
#   'losses': 128,
#   'win_percentage': 0.29,
#   'draw_percentage': 0.32,
#   'loss_percentage': 0.39,
#   'goals_scored': 301,
#   'goals_against': 375,
#   'goals_difference': -74,
#   'avg_goals_scored': 0.918,
#   'avg_goals_against': 1.143,
#   'avg_goals_difference': -0.226,
#   'home_games': 163,
#   'home_wins': 60,
#   'home_draws': 45,
#   'home_losses': 58,
#   'home_win_percentage': 0.368,
#   'home_draw_percentage': 0.276,
#   'home_loss_percentage': 0.356,
#   'home_goals_scored': 183,
#   'home_goals_against': 178,
#   'home_goals_difference': 5,
#   'home_avg_goals_scored': 1.123,
#   'home_avg_goals_against': 1.092,
#   'home_avg_goals_difference': 0.031,
#   'away_games': 165,
#   'away_wins': 35,
#   'away_draws': 60,
#   'away_losses': 70,
#   'away_win_percentage': 0.212,
#   'away_draw_percentage': 0.364,
#   'away_loss_percentage': 0.424,
#   'away_goals_scored': 118,
#   'away_goals_against': 197,
#   'away_goals_difference': -79,
#   'away_avg_goals_scored': 0.715,
#   'away_avg_goals_against': 1.194,
#   'away_avg_goals_difference': -0.479},
#  {'name': 'Inter Turku',
#   'total_games': 546,
#   'wins': 218,
#   'draws': 145,
#   'losses': 183,
#   'win_percentage': 0.399,
#   'draw_percentage': 0.266,
#   'loss_percentage': 0.335,
#   'goals_scored': 784,
#   'goals_against': 658,
#   'goals_difference': 126,
#   'avg_goals_scored': 1.436,
#   'avg_goals_against': 1.205,
#   'avg_goals_difference': 0.231,
#   'home_games': 274,
#   'home_wins': 129,
#   'home_draws': 76,
#   'home_losses': 69,
#   'home_win_percentage': 0.471,
#   'home_draw_percentage': 0.277,
#   'home_loss_percentage': 0.252,
#   'home_goals_scored': 441,
#   'home_goals_against': 284,
#   'home_goals_difference': 157,
#   'home_avg_goals_scored': 1.609,
#   'home_avg_goals_against': 1.036,
#   'home_avg_goals_difference': 0.573,
#   'away_games': 272,
#   'away_wins': 89,
#   'away_draws': 69,
#   'away_losses': 114,
#   'away_win_percentage': 0.327,
#   'away_draw_percentage': 0.254,
#   'away_loss_percentage': 0.419,
#   'away_goals_scored': 343,
#   'away_goals_against': 374,
#   'away_goals_difference': -31,
#   'away_avg_goals_scored': 1.261,
#   'away_avg_goals_against': 1.375,
#   'away_avg_goals_difference': -0.114},
#  {'name': 'Alcorcon',
#   'total_games': 503,
#   'wins': 175,
#   'draws': 137,
#   'losses': 191,
#   'win_percentage': 0.348,
#   'draw_percentage': 0.272,
#   'loss_percentage': 0.38,
#   'goals_scored': 535,
#   'goals_against': 572,
#   'goals_difference': -37,
#   'avg_goals_scored': 1.064,
#   'avg_goals_against': 1.137,
#   'avg_goals_difference': -0.074,
#   'home_games': 252,
#   'home_wins': 113,
#   'home_draws': 70,
#   'home_losses': 69,
#   'home_win_percentage': 0.448,
#   'home_draw_percentage': 0.278,
#   'home_loss_percentage': 0.274,
#   'home_goals_scored': 307,
#   'home_goals_against': 221,
#   'home_goals_difference': 86,
#   'home_avg_goals_scored': 1.218,
#   'home_avg_goals_against': 0.877,
#   'home_avg_goals_difference': 0.341,
#   'away_games': 251,
#   'away_wins': 62,
#   'away_draws': 67,
#   'away_losses': 122,
#   'away_win_percentage': 0.247,
#   'away_draw_percentage': 0.267,
#   'away_loss_percentage': 0.486,
#   'away_goals_scored': 228,
#   'away_goals_against': 351,
#   'away_goals_difference': -123,
#   'away_avg_goals_scored': 0.908,
#   'away_avg_goals_against': 1.398,
#   'away_avg_goals_difference': -0.49},
#  {'name': 'Hapoel Raanana',
#   'total_games': 134,
#   'wins': 36,
#   'draws': 36,
#   'losses': 62,
#   'win_percentage': 0.269,
#   'draw_percentage': 0.269,
#   'loss_percentage': 0.463,
#   'goals_scored': 114,
#   'goals_against': 173,
#   'goals_difference': -59,
#   'avg_goals_scored': 0.851,
#   'avg_goals_against': 1.291,
#   'avg_goals_difference': -0.44,
#   'home_games': 67,
#   'home_wins': 20,
#   'home_draws': 15,
#   'home_losses': 32,
#   'home_win_percentage': 0.299,
#   'home_draw_percentage': 0.224,
#   'home_loss_percentage': 0.478,
#   'home_goals_scored': 59,
#   'home_goals_against': 90,
#   'home_goals_difference': -31,
#   'home_avg_goals_scored': 0.881,
#   'home_avg_goals_against': 1.343,
#   'home_avg_goals_difference': -0.463,
#   'away_games': 67,
#   'away_wins': 16,
#   'away_draws': 21,
#   'away_losses': 30,
#   'away_win_percentage': 0.239,
#   'away_draw_percentage': 0.313,
#   'away_loss_percentage': 0.448,
#   'away_goals_scored': 55,
#   'away_goals_against': 83,
#   'away_goals_difference': -28,
#   'away_avg_goals_scored': 0.821,
#   'away_avg_goals_against': 1.239,
#   'away_avg_goals_difference': -0.418},
#  {'name': 'Southport',
#   'total_games': 410,
#   'wins': 118,
#   'draws': 107,
#   'losses': 185,
#   'win_percentage': 0.288,
#   'draw_percentage': 0.261,
#   'loss_percentage': 0.451,
#   'goals_scored': 497,
#   'goals_against': 673,
#   'goals_difference': -176,
#   'avg_goals_scored': 1.212,
#   'avg_goals_against': 1.641,
#   'avg_goals_difference': -0.429,
#   'home_games': 205,
#   'home_wins': 70,
#   'home_draws': 48,
#   'home_losses': 87,
#   'home_win_percentage': 0.341,
#   'home_draw_percentage': 0.234,
#   'home_loss_percentage': 0.424,
#   'home_goals_scored': 280,
#   'home_goals_against': 325,
#   'home_goals_difference': -45,
#   'home_avg_goals_scored': 1.366,
#   'home_avg_goals_against': 1.585,
#   'home_avg_goals_difference': -0.22,
#   'away_games': 205,
#   'away_wins': 48,
#   'away_draws': 59,
#   'away_losses': 98,
#   'away_win_percentage': 0.234,
#   'away_draw_percentage': 0.288,
#   'away_loss_percentage': 0.478,
#   'away_goals_scored': 217,
#   'away_goals_against': 348,
#   'away_goals_difference': -131,
#   'away_avg_goals_scored': 1.059,
#   'away_avg_goals_against': 1.698,
#   'away_avg_goals_difference': -0.639},
#  {'name': 'Shanghai Greenland',
#   'total_games': 482,
#   'wins': 205,
#   'draws': 141,
#   'losses': 136,
#   'win_percentage': 0.425,
#   'draw_percentage': 0.293,
#   'loss_percentage': 0.282,
#   'goals_scored': 678,
#   'goals_against': 565,
#   'goals_difference': 113,
#   'avg_goals_scored': 1.407,
#   'avg_goals_against': 1.172,
#   'avg_goals_difference': 0.234,
#   'home_games': 241,
#   'home_wins': 140,
#   'home_draws': 66,
#   'home_losses': 35,
#   'home_win_percentage': 0.581,
#   'home_draw_percentage': 0.274,
#   'home_loss_percentage': 0.145,
#   'home_goals_scored': 414,
#   'home_goals_against': 230,
#   'home_goals_difference': 184,
#   'home_avg_goals_scored': 1.718,
#   'home_avg_goals_against': 0.954,
#   'home_avg_goals_difference': 0.763,
#   'away_games': 241,
#   'away_wins': 65,
#   'away_draws': 75,
#   'away_losses': 101,
#   'away_win_percentage': 0.27,
#   'away_draw_percentage': 0.311,
#   'away_loss_percentage': 0.419,
#   'away_goals_scored': 264,
#   'away_goals_against': 335,
#   'away_goals_difference': -71,
#   'away_avg_goals_scored': 1.095,
#   'away_avg_goals_against': 1.39,
#   'away_avg_goals_difference': -0.295},
#  ...]

# %% [markdown]
# ### Function to search H2H games (team1 vs team2)

# %%
def search_H2H(team1, team2):
    
    condition_a = ((training_set["HT"] == team1) & (training_set["AT"] == team2))
    condition_b = ((training_set["HT"] == team2) & (training_set["AT"] == team1))
    
    h2h = training_set.loc[condition_a | condition_b]
    
    return h2h

# %%
search_H2H("Real Madrid", "Eibar")
# Out:
#           Sea   Lge       Date           HT           AT  HS  AS  GD WDL  \
# 174450  14-15  SPA1 2014-11-22        Eibar  Real Madrid   0   4  -4   L
# 174640  14-15  SPA1 2015-04-11  Real Madrid        Eibar   3   0   3   W
# 189935  15-16  SPA1 2015-11-29        Eibar  Real Madrid   0   2  -2   L
# 190122  15-16  SPA1 2016-04-09  Real Madrid        Eibar   4   0   4   W
# 212361  16-17  SPA1 2016-10-02  Real Madrid        Eibar   1   1   0   D
# 212545  16-17  SPA1 2017-03-04        Eibar  Real Madrid   1   4  -3   L
# 219409  17-18  SPA1 2017-10-22  Real Madrid        Eibar   3   0   3   W
# 219593  17-18  SPA1 2018-03-10        Eibar  Real Madrid   1   2  -1   L
# 224852  18-19  SPA1 2018-11-24        Eibar  Real Madrid   3   0   3   W
# 225032  18-19  SPA1 2019-04-06  Real Madrid        Eibar   2   1   1   W
# 230296  19-20  SPA1 2019-11-09        Eibar  Real Madrid   0   4  -4   L
# 230451  19-20  SPA1 2020-06-14  Real Madrid        Eibar   3   1   2   W
# 236090  20-21  SPA1 2020-12-20        Eibar  Real Madrid   1   3  -2   L
# 236238  20-21  SPA1 2021-04-03  Real Madrid        Eibar   2   0   2   W
#
#         Goals
# 174450      4
# 174640      3
# 189935      2
# 190122      4
# 212361      2
# 212545      5
# 219409      3
# 219593      3
# 224852      3
# 225032      3
# 230296      4
# 230451      4
# 236090      4
# 236238      2

# %% [markdown]
# ### Function to get last N games of specific team (streak)

# %%
def get_last_matches_info(team_name, n_previous_matches=5):
    ''' Retrieves info of last N games of a team: last games,
    WDL streak of the team in that games and points (5 last games by default)
    '''

    team_df, _, _= extract_team_df(team_name)
    last_n_games_df = team_df[-n_previous_matches:]
    
    # Print team streak in last n games
    streak = list()
    for i, game in last_n_games_df.iterrows():
        if (game["WDL"] == "W" and game["HT"] == team_name) or (game["WDL"] == "L" and game["AT"] == team_name):
            streak.append("W")
        elif game["WDL"] == "D":
            streak.append("D")
        else:
            streak.append("L")
    
    # Get points in that streak
    points = streak.count("W") * 3 + streak.count("D") 

    return last_n_games_df, streak, points

# %%
last_n_matches, streak, points = get_last_matches_info("Real Madrid", 5)
print(f"Streak: {streak}. Points: {points}")
last_n_matches
# Out:
# Streak: ['L', 'W', 'D', 'W', 'L']. Points: 7
#           Sea   Lge       Date               HT             AT  HS  AS  GD  \
# 298599  22-23  SPA1 2023-01-07       Villarreal    Real Madrid   2   1   1
# 298623  22-23  SPA1 2023-01-22  Athletic Bilbao    Real Madrid   0   2  -2
# 298633  22-23  SPA1 2023-01-29      Real Madrid  Real Sociedad   0   0   0
# 298636  22-23  SPA1 2023-02-02      Real Madrid       Valencia   2   0   2
# 298642  22-23  SPA1 2023-02-05         Mallorca    Real Madrid   1   0   1
#
#        WDL  Goals
# 298599   W      3
# 298623   L      2
# 298633   D      0
# 298636   W      2
# 298642   W      1

# %% [markdown]
# ### Get WDL in the current season for a team

# %%
def get_season_points(team_name, season="22-23"):
    ''' Computes points of the team in a specific season. If season
    is not provided, computes points from current season (22-23).
    '''
    
    seasons = training_set["Sea"].value_counts().index.tolist()
    
    if season in seasons:
        team_df, _, _ = extract_team_df(team_name)   
        season_team_df = team_df[team_df["Sea"] == season]
        season_games = season_team_df.shape[0]
        
        wins = len(season_team_df[(season_team_df['HT'] == team) & (season_team_df['WDL']=="W")]) + \
            len(season_team_df[(season_team_df['AT'] == team) & (season_team_df['WDL']=="L")])
        draws = len(season_team_df[season_team_df['WDL'] == "D"])

        season_points = 3 * wins + draws
        avg_points_season = round(season_points / season_games, 3)
        
        return season_points, avg_points_season
    
    else:
        raise ValueError("Invalid season.")

# %%
season_points, avg_points_season = get_season_points("Real Madrid", "22-23")
print(f"Total points of the team in season: {season_points} (average points: {avg_points_season})")
# Out:
# Total points of the team in season: 45 (average points: 2.25)

# %% [markdown]
# ------------------

# %% [markdown]
# ### **Load teams file from pickle**

# %%
with open("teams.pickle", "rb") as teams_file:
    teams = pickle.load(teams_file)
